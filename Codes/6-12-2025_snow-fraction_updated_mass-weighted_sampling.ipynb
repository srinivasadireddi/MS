# %%
#6-12-25
#qs/(qr+qg+qs) prediction
#12 inputs and 1 output
#Mass-weighted random sampling
#data fraction from every height = 0.001 (0.1%) before mass-weighted random sampling #0.01% after mass-weighted rand sampling
#for ht in range(31, 91, 5) 
# start_time = 1979-01-12T00:00:00 
# end_time = 1979-01-12T00:00:00 


import time
overall_start_time = time.time()
import os
import sys

import numpy as np
import pandas as pd
#%matplotlib inline  #won't work for .py
import matplotlib.pyplot as plt
import xarray as xr

# import json_file_editer as JFE
from File_management import json_file_editer as JFE
from Calculation import job_manager 
from Tools import dataset_init
from Log_management import Log

import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

#random forest
import warnings
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

warnings.filterwarnings('ignore')

#ISLP
from matplotlib.pyplot import subplots
from statsmodels.datasets import get_rdataset
import sklearn.model_selection as skm
from ISLP import load_data, confusion_table
from ISLP.models import ModelSpec as MS

from sklearn.tree import (DecisionTreeClassifier as DTC,
 DecisionTreeRegressor as DTR,
 plot_tree,
 export_text)
from sklearn.metrics import (accuracy_score,
 log_loss)
from sklearn.ensemble import \
 (RandomForestRegressor as RF,
 GradientBoostingRegressor as GBR)
from ISLP.bart import BART

#################################################################
Log.init_log(os.path.join('./output'), filename=f"Log_ML.txt")
Log.add_to_log("Log nicely initialized ")

options_json=JFE.get_json_data("options.json")
options_json["Header"]["status"]
chunks = {}
myJob = job_manager.JobManager(options_json)
ds = dataset_init.ds_init_3d(myJob, chunks={})
# Out:
# The job folder path : ./output/Log_ML.txt
# 2025 Dec 06 16:47:27 > Log nicely initialized
# 2025 Dec 06 16:47:27 > (DI0010) making data from P-O files requires small differences in the code, hardly automisable.
# 2025 Dec 06 16:47:27 > (DI0020) Starting PO dataset creation from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0001
# 2025 Dec 06 16:47:27 > (DI0021) Found 8 time-varying files in date range
# 2025 Dec 06 16:47:27 > (DI0022) Loading vertical grid data from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0001/pod0001_atm_vgrid_ml.nc
# 2025 Dec 06 16:47:27 > (DI0023) Grid variables available: ['clon_bnds', 'clat_bnds', 'height_bnds', 'height_2_bnds', 'zghalf', 'zg', 'dzghalf', 'clon', 'clat', 'height', 'height_2']
# 2025 Dec 06 16:47:27 > (DI0024) Dimensions in vgrid: FrozenMappingWarningOnValuesAccess({'ncells': 20971520, 'vertices': 3, 'height': 60, 'bnds': 2, 'height_2': 60})
# 2025 Dec 06 16:47:27 > (DI0037) Loading horizontal grid data from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2025 Dec 06 16:47:28 > (DI0039) Successfully loaded cell areas from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2025 Dec 06 16:47:28 > (DI0019) Combining 5 time-varying datasets
# 2025 Dec 06 16:47:31 > (DI0018) Merging time-varying data with vertical grid data
# 2025 Dec 06 16:47:31 > (DI0017) Common dimensions: {'height_2', 'bnds', 'height', 'ncells'}
# 2025 Dec 06 16:47:32 > (DI0016) Successfully merged with vertical grid data
# 2025 Dec 06 16:47:32 > (DI0044) Merging with horizontal grid data (cell areas)
# 2025 Dec 06 16:47:32 > (DI0049) Renamed 'cell' dimension to 'ncells'
# 2025 Dec 06 16:47:32 > (DI0050) After renaming - common dimensions: {'height_2', 'bnds', 'height', 'ncells'}
# 2025 Dec 06 16:47:33 > (DI0046) Successfully merged cell area data
# 2025 Dec 06 16:47:33 > (DI0033) Selected variables: ['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi', 'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'ta', 'wa', 'rho', 'dzghalf', 'ua', 'va', 'pfull']
# 2025 Dec 06 16:47:33 > (DI0035) Final dataset shape: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2025 Dec 06 16:47:33 > (DI0036) Final dataset variables: ['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi', 'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'ta', 'wa', 'rho', 'dzghalf', 'ua', 'va', 'pfull', 'time', 'height', 'height_2']
# 2025 Dec 06 16:47:33 > (DI0100) ========== Final Dataset for scheme_comparison Information ==========
# 2025 Dec 06 16:47:33 > (DI0101) Dimensions: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2025 Dec 06 16:47:33 > (DI0102) Coordinates:
# 2025 Dec 06 16:47:33 >   clon: (20971520,) float64
# 2025 Dec 06 16:47:33 >   clat: (20971520,) float64
# 2025 Dec 06 16:47:33 >   time: (1,) datetime64[ns]
# 2025 Dec 06 16:47:33 >   height: (61,) float64
# 2025 Dec 06 16:47:33 >   height_2: (61,) float64
# 2025 Dec 06 16:47:33 > (DI0103) Data Variables:
# 2025 Dec 06 16:47:33 >   cell_area: (20971520,) float64 (ncells)
# 2025 Dec 06 16:47:33 >     Units: m2
# 2025 Dec 06 16:47:33 >     Description: area of grid cell
# 2025 Dec 06 16:47:33 >   pr: (1, 20971520) float32 (time, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg m-2 s-1
# 2025 Dec 06 16:47:33 >     Description: precipitation flux
# 2025 Dec 06 16:47:33 >   tas: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: K
# 2025 Dec 06 16:47:33 >     Description: temperature in 2m
# 2025 Dec 06 16:47:33 >   clivi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg m-2
# 2025 Dec 06 16:47:33 >     Description: cloud ice path
# 2025 Dec 06 16:47:33 >   cllvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg m-2
# 2025 Dec 06 16:47:33 >     Description: cloud liquid water path
# 2025 Dec 06 16:47:33 >   qgvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg m-2
# 2025 Dec 06 16:47:33 >     Description: graupel path
# 2025 Dec 06 16:47:33 >   qrvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg m-2
# 2025 Dec 06 16:47:33 >     Description: rain path
# 2025 Dec 06 16:47:33 >   qsvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg m-2
# 2025 Dec 06 16:47:33 >     Description: snow path
# 2025 Dec 06 16:47:33 >   clw: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg kg-1
# 2025 Dec 06 16:47:33 >     Description: specific cloud water content
# 2025 Dec 06 16:47:33 >   cli: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg kg-1
# 2025 Dec 06 16:47:33 >     Description: specific cloud ice content
# 2025 Dec 06 16:47:33 >   qr: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg kg-1
# 2025 Dec 06 16:47:33 >     Description: specific rain content
# 2025 Dec 06 16:47:33 >   qg: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg kg-1
# 2025 Dec 06 16:47:33 >     Description: specific graupel content
# 2025 Dec 06 16:47:33 >   qs: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg kg-1
# 2025 Dec 06 16:47:33 >     Description: specific snow content
# 2025 Dec 06 16:47:33 >   hus: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg kg-1
# 2025 Dec 06 16:47:33 >     Description: Specific humidity
# 2025 Dec 06 16:47:33 >   ta: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: K
# 2025 Dec 06 16:47:33 >     Description: Temperature
# 2025 Dec 06 16:47:33 >   wa: (1, 61, 20971520) float32 (time, height_2, ncells)
# 2025 Dec 06 16:47:33 >     Units: m s-1
# 2025 Dec 06 16:47:33 >     Description: Vertical velocity
# 2025 Dec 06 16:47:33 >   rho: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: kg m-3
# 2025 Dec 06 16:47:33 >     Description: density
# 2025 Dec 06 16:47:33 >   dzghalf: (61, 20971520) float32 (height, ncells)
# 2025 Dec 06 16:47:33 >     Units: -
# 2025 Dec 06 16:47:33 >     Description: metrics functional determinant
# 2025 Dec 06 16:47:33 >   ua: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: m s-1
# 2025 Dec 06 16:47:33 >     Description: Zonal wind
# 2025 Dec 06 16:47:33 >   va: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: m s-1
# 2025 Dec 06 16:47:33 >     Description: Meridional wind
# 2025 Dec 06 16:47:33 >   pfull: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 06 16:47:33 >     Units: Pa
# 2025 Dec 06 16:47:33 >     Description: Pressure
# 2025 Dec 06 16:47:33 > (DI0104) Estimated memory usage: 67.66 GB
# 2025 Dec 06 16:47:33 > (DI0105) Time range: 1979-01-12T00:00:00.000000000 to 1979-01-12T00:00:00.000000000 (1 steps)
# 2025 Dec 06 16:47:33 > (DI0107) ========== End Final Dataset for scheme_comparison Information ==========

# %%
seed = 1
sample_frac = 0.001

ht=31
data=ds.sel(height=ht, height_2=ht) 

total = data['clw'] + data['cli']
data['clw/(clw+cli)'] = data['clw'].where(total != 0, 0) / total.where(total != 0, 1)
data['cli/(clw+cli)'] = data['cli'].where(total != 0, 0) / total.where(total != 0, 1)

total_precipitates = data['qr'] + data['qs']+ data['qg']
data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

# %%
df = data.to_dataframe() #.sample(frac=1, random_state=seed) #frac=sample_frac

# %%
# df = data.to_dataframe().sample(frac=sample_frac, random_state=seed)

dfs = [df]  
# for ht in range(32, 91, 5): #(32, 91, 5)
for ht in range(36, 91, 5): #(32, 91, 5)
    data = ds.sel(height=ht, height_2=ht)

    total = data['clw'] + data['cli']
    data['clw/(clw+cli)'] = data['clw'].where(total != 0, 0) / total.where(total != 0, 1)
    data['cli/(clw+cli)'] = data['cli'].where(total != 0, 0) / total.where(total != 0, 1)

    total_precipitates = data['qr'] + data['qs']+ data['qg']
    data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

    df_sampled=data.to_dataframe() #.sample(frac=1, random_state= seed+ht) #frac=sample_frac
    dfs.append(df_sampled) 
    print(f"Last value of clon in df with height {ht} is", df_sampled['clon'].iloc[-1])

df = pd.concat(dfs, ignore_index=True)

# print('length of dfs: ',len(dfs))
# print('len of dfs[0]: ', len(dfs[0]))
prod= len(dfs[0]) * len(dfs)
print("Expected length of df: ", prod)
print('Final length of df: ', len(df))
# Out:
# Last value of clon in df with height 36 is 1.3343108942333097
# Last value of clon in df with height 41 is 1.3343108942333097
# Last value of clon in df with height 46 is 1.3343108942333097
# Last value of clon in df with height 51 is 1.3343108942333097
# Last value of clon in df with height 56 is 1.3343108942333097
# Last value of clon in df with height 61 is 1.3343108942333097
# Last value of clon in df with height 66 is 1.3343108942333097
# Last value of clon in df with height 71 is 1.3343108942333097
# Last value of clon in df with height 76 is 1.3343108942333097
# Last value of clon in df with height 81 is 1.3343108942333097
# Last value of clon in df with height 86 is 1.3343108942333097
# Expected length of df:  251658240
# Final length of df:  251658240

# %%
threshold = 5e-12
df_new = df[(df['cli'] + df['clw'] + df['qr'] + df['qg'] + df['qs']) >= threshold]
# print('df- After threshold-1:')
# print(df_new)
if df_new.empty:
    df_new = df

df = df_new
# print('df after threshold-2:\n', df)

# %%
#RH from SH
def RH_from_SH(pfull, hus, ta, T_0= 273.16):
    RH = 0.26 * pfull * hus / np.exp(17.67 * (ta - T_0) / (ta - 29.65))
    return RH

# %%
df['RH']=RH_from_SH(df['pfull'], df['hus'], df['ta'])

# %%
count=0
for i in df['RH']:
    if i>100 or i<0:
        count+=1
print("incorrect count = ", count)
print("incorrect count percent = ", 100*count/len(df['RH']))
# Out:
# incorrect count =  600516
# incorrect count percent =  0.9964409504582096

# %%
df['RH']= df['RH'].clip(lower=0, upper=100)

# %%
df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2',
#        'clw/(clw+cli)', 'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)',
#        'qg/(qr+qs+qg)', 'RH'],
#       dtype='object')

# %%
col=df.pop('RH')
df.insert(16, 'RH', col) #hus is at 15th position
#df.pop('hus')

df['clw+cli']=df['clw']+df['cli']

col=df.pop('clw+cli')
df.insert(26, 'clw+cli', col) 

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'clw/(clw+cli)', 'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)',
#        'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
#Include 'cloud liquid water path + cloud ice path' as a feature.

df['cllvi+clivi']=df['cllvi']+df['clivi']

col=df.pop('cllvi+clivi')
df.insert(27, 'cllvi+clivi', col) 

# df.to_csv("df.csv", index=False)
df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'clw/(clw+cli)', 'cli/(clw+cli)', 'qr/(qr+qs+qg)',
#        'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
# m_ci_j=dzghalf*rho*cell_area*(clw+cli)

#NOte df['m_ci'] actually refers to mass of qr+qg+qs

df['m_ci']=df['dzghalf']*df['rho']*df['cell_area']* (df['qr']+df['qg']+df['qs'])

col=df.pop('m_ci')
df.insert(28, 'm_ci', col) 

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'clw/(clw+cli)', 'cli/(clw+cli)',
#        'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
df = df.sort_values(by='m_ci', ascending=False)
df
# Out:
#                clon      clat     cell_area            pr  tas         clivi  \
# 159855181 -1.031281 -0.427751  2.456351e+07  4.644030e-02  NaN  1.202769e+00
# 159855180 -1.031901 -0.428095  2.456019e+07  4.741778e-02  NaN  1.368358e+00
# 182262863  2.815546 -0.135832  2.481709e+07  8.865210e-02  NaN  1.151053e+00
# 180826701 -1.031281 -0.427751  2.456351e+07  4.644030e-02  NaN  1.202769e+00
# 180826751 -1.030676 -0.427990  2.455627e+07  7.847045e-02  NaN  1.248525e+00
# ...             ...       ...           ...           ...  ...           ...
# 182416711  2.751418 -0.522541  2.443239e+07 -1.090858e-10  NaN  2.098459e-12
# 182417368  2.744391 -0.533043  2.445866e+07  1.989806e-04  NaN  2.244071e-11
# 195469960  1.927579  0.441296  2.051638e+07 -1.948925e-10  NaN  9.639783e-08
# 195469962  1.927705  0.440714  2.050037e+07 -2.643868e-12  NaN  3.252415e-08
# 250334275  2.289760 -1.140735  2.476948e+07  1.291108e-06  NaN  1.310900e-05
#
#               cllvi          qgvi       qrvi          qsvi  ...  height  \
# 159855181  0.236302  2.905353e+01  58.486599  1.616142e-02  ...    66.0
# 159855180  0.200882  2.740425e+01  55.791115  2.173984e-02  ...    66.0
# 182262863  0.591597  1.285223e+01  62.619976  5.829696e-02  ...    71.0
# 180826701  0.236302  2.905353e+01  58.486599  1.616142e-02  ...    71.0
# 180826751  0.153892  3.514213e+01  56.485802  2.388498e-02  ...    71.0
# ...             ...           ...        ...           ...  ...     ...
# 182416711  1.360129  8.631672e-13   0.023480  2.468158e-12  ...    71.0
# 182417368  0.991518  2.068265e-12   0.053951  3.609831e-12  ...    71.0
# 195469960  0.083047  7.250317e-04   0.000107  3.955646e-09  ...    76.0
# 195469962  0.110406  4.735694e-04   0.000129  1.279460e-09  ...    76.0
# 250334275  0.082244  2.918173e-04   0.000011  1.602997e-06  ...    86.0
#
#            height_2       clw+cli  cllvi+clivi          m_ci  clw/(clw+cli)  \
# 159855181      66.0  2.516514e-05     1.439072  7.971469e+07       1.000000
# 159855180      66.0  2.349071e-05     1.569240  7.728639e+07       0.999999
# 182262863      71.0  2.402958e-05     1.742650  7.399849e+07       1.000000
# 180826701      71.0  1.871419e-05     1.439072  7.125116e+07       1.000000
# 180826751      71.0  2.058680e-05     1.402417  7.106237e+07       1.000000
# ...             ...           ...          ...           ...            ...
# 182416711      71.0  3.446805e-09     1.360129  0.000000e+00       1.000000
# 182417368      71.0  6.839227e-11     0.991518  0.000000e+00       0.998965
# 195469960      76.0  8.918242e-11     0.083047  0.000000e+00       0.999998
# 195469962      76.0  4.279200e-10     0.110406  0.000000e+00       1.000000
# 250334275      86.0  1.594269e-08     0.082257  0.000000e+00       0.999880
#
#            cli/(clw+cli)  qr/(qr+qs+qg)  qs/(qr+qs+qg)  qg/(qr+qs+qg)
# 159855181   6.461818e-09       0.997905   2.920574e-13   2.095348e-03
# 159855180   7.018220e-07       0.999809   1.993921e-10   1.907070e-04
# 182262863   9.436018e-12       1.000000   5.778623e-16   5.676546e-11
# 180826701   8.520762e-12       1.000000   1.214298e-15   3.774783e-10
# 180826751   9.275723e-12       0.999997   1.272068e-12   2.873613e-06
# ...                  ...            ...            ...            ...
# 182416711   6.960463e-11       0.000000   0.000000e+00   0.000000e+00
# 182417368   1.035274e-03       0.000000   0.000000e+00   0.000000e+00
# 195469960   1.749745e-06       0.000000   0.000000e+00   0.000000e+00
# 195469962   4.225435e-07       0.000000   0.000000e+00   0.000000e+00
# 250334275   1.197217e-04       0.000000   0.000000e+00   0.000000e+00
#
# [60266090 rows x 34 columns]

# %%
df = df.reset_index(drop=True)
df['m_ci']
# Out:
# 0           7.971469e+07
# 1           7.728639e+07
# 2           7.399849e+07
# 3           7.125116e+07
# 4           7.106237e+07
#                 ...
# 60266085    0.000000e+00
# 60266086    0.000000e+00
# 60266087    0.000000e+00
# 60266088    0.000000e+00
# 60266089    0.000000e+00
# Name: m_ci, Length: 60266090, dtype: float64

# %%
total_mass = df['m_ci'].sum()
total_mass #kg #prevsly: np.float64(6506367837186.283)
# Out:
# np.float64(5633778714515.674)

# %%
df['cum_mass'] = df['m_ci'].cumsum()

col=df.pop('cum_mass')
df.insert(29, 'cum_mass', col) 

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'cum_mass', 'clw/(clw+cli)', 'cli/(clw+cli)',
#        'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
#Adding another column; qr+qg+qs and use it later as an input feature

df['qr+qg+qs'] = df['qr'] + df['qg'] + df['qs']

col=df.pop('qr+qg+qs')
df.insert(30, 'qr+qg+qs', col)

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'cum_mass', 'qr+qg+qs', 'clw/(clw+cli)',
#        'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
n_samples= int(np.floor(len(df) * 0.1)) #we are taking a way smaller dataset because of this 
# n_samples= int(np.floor(len(df))) 
np.random.seed(29)

random_values = np.random.uniform(0, total_mass, size=n_samples)

print('Random values: ', random_values)

indices= np.searchsorted(df['cum_mass'].values, random_values)

df_orig=df

df = df.iloc[indices].reset_index(drop=True)
# Out:
# Random values:  [4.86623262e+12 1.60509716e+12 4.12710280e+11 ... 3.13547893e+12
#  3.88298155e+12 1.46527931e+12]

# %%
df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'cum_mass', 'qr+qg+qs', 'clw/(clw+cli)',
#        'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
#continue from here
#overall MLR code
X = df.iloc[:, [0,1,15,16,17,18,21,22,23,26,27,30]].values 
# X = df.iloc[:, [15,16,17,18,21,22,23,26,27,30]].values 
y = df.iloc[:, [-2]].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)
cols= [0,1,15,16,17,18,21,22,23,26,27,30]
feature_names=df.columns[cols].tolist()

from sklearn import linear_model

regr=linear_model.LinearRegression()
regr.fit(X_train,y_train)

y_predicted = regr.predict(X_test)
y_predicted = np.clip(y_predicted, 0, 1)

#Error Analysis on TEST data
#MSE_test
mse_TEST= np.mean((y_test- y_predicted)**2)
print(f'MSE_TEST: {mse_TEST}')

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_predicted)**2))
print(f'RMSE_TEST: {rmse_TEST}')
# print(f'MSE_TEST: {(rmse_TEST)**2}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_predicted))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_predicted)
print("R² score:", r2_sklearn)

#Coefficient
coef_list= regr.coef_[0]

coef_table = pd.DataFrame(
{
    'Feature': feature_names,
    'Coefficient': coef_list
}
)

#Sort by absolute coeff val

coef_table['abs(Coefficient)'] = coef_table['Coefficient'].abs()
coef_table.sort_values(by='abs(Coefficient)', ascending=False, inplace=True)
print(coef_table)
# Out:
# MSE_TEST: 0.05134043848051733
# RMSE_TEST: 0.2265842855992386
# mae_TEST: 0.1675216904991621
# R² score: 0.7186888074584113
#         Feature  Coefficient  abs(Coefficient)
# 9       clw+cli  -335.099582        335.099582
# 2           hus   -54.240484         54.240484
# 11     qr+qg+qs   -41.173038         41.173038
# 1          clat     0.028260          0.028260
# 3            RH    -0.006702          0.006702
# 5            wa    -0.004014          0.004014
# 10  cllvi+clivi     0.002987          0.002987
# 4            ta     0.001475          0.001475
# 0          clon    -0.001171          0.001171
# 6            ua     0.000619          0.000619
# 7            va    -0.000598          0.000598
# 8         pfull    -0.000001          0.000001

# %%
pairs = [(name, abs(coef)) for name, coef in zip(feature_names, coef_list)]
total = sum(c for _, c in pairs)

#Sort by importance (descending)
pairs.sort(key=lambda x: x[1], reverse=True)

names = []
importances = []

for name, coef in pairs:
    pct = (coef / total) * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

#Bar plot
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")

#Modify title accordingly
plt.title(r"$\mathbf{Snow\ fraction}$ determination using $\mathbf{Multi\ Linear\ Regression}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of bars
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,        #small space after the bar
        y,
        f"{width:.2f}%",
        va="center"
    )

plt.xlim(0, 100)
plt.tight_layout()
plt.show()
# Out:
# clw+cli: 77.8290 %
# hus: 12.5977 %
# qr+qg+qs: 9.5627 %
# clat: 0.0066 %
# RH: 0.0016 %
# wa: 0.0009 %
# cllvi+clivi: 0.0007 %
# ta: 0.0003 %
# clon: 0.0003 %
# ua: 0.0001 %
# va: 0.0001 %
# pfull: 0.0000 %

# %%
# import seaborn as sns

# plt.figure(figsize=(8,6))
# sns.scatterplot(x=y_test.flatten(), y=y_predicted.flatten(), alpha=0.7)
# plt.xlabel("Actual Values")
# plt.ylabel("Predicted Values")
# plt.title("Actual vs Predicted Values (MLR)")
# # Add a perfect prediction line
# plt.plot([y_test.min(), y_test.max()],
#          [y_test.min(), y_test.max()],
#          color='red', lw=2)
# plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hexbin(
    y_test.flatten(), 
    y_predicted.flatten(), 
    gridsize=40,  # smaller → finer grid
    cmap='viridis', 
    bins='log'  # logarithmic scaling helps emphasize dense areas
)
plt.colorbar(label='log10(N)')
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color='red', lw=2
)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (MLR)")
plt.show()

# %%
##ft 16 ('RH') and -5 ('clw/(clw+cli)')
# df['RH']

# %%
df['clw/(clw+cli)']
# Out:
# 0          3.036822e-21
# 1          1.000000e+00
# 2          5.862302e-03
# 3          0.000000e+00
# 4          1.000000e+00
#                ...
# 6026604    0.000000e+00
# 6026605    1.000000e+00
# 6026606    6.747710e-01
# 6026607    9.998628e-01
# 6026608    1.000000e+00
# Name: clw/(clw+cli), Length: 6026609, dtype: float32

# %%
# plt.plot(df['RH'], df['clw/(clw+cli)']) #error in plotting probably because of huge size of data

# %%
plt.scatter(df['RH'][::100], df['clw/(clw+cli)'][::100], s=2)
plt.xlabel("RH")
plt.ylabel("clw / (clw + cli)")
plt.title("Scatter Plot: RH vs clw/(clw+cli)")
plt.show()

# %%
plt.scatter(df['RH'][::100], df['clw/(clw+cli)'][::100], s=2)
plt.xlim(95,100)
plt.xlabel("RH")
plt.ylabel("clw / (clw + cli)")
plt.title("Scatter Plot: RH vs clw/(clw+cli)")
plt.show()

# %%
plt.hexbin(
    df['RH'][::100],
    df['clw/(clw+cli)'][::100],
    gridsize=60,    # adjust resolution (smaller = finer)
    cmap='viridis', # color map
    bins='log'      # use log scale for density
)
plt.colorbar(label='log10(N points)')
# plt.xlim(95, 100)
plt.xlabel("RH")
plt.ylabel("clw / (clw + cli)")
plt.title("Hexbin Density Plot: RH vs clw/(clw+cli)")
plt.show()

# %%
#clw frac v/s ta
plt.hexbin(
    df['ta'][::100],
    df['clw/(clw+cli)'][::100],
    gridsize=60,    # adjust resolution (smaller = finer)
    cmap='viridis', # color map
    bins='log'      # use log scale for density
)
plt.colorbar(label='log10(N points)')
# plt.xlim(95, 100)
plt.xlabel("temperature")
plt.ylabel("clw / (clw + cli)")
plt.title("Hexbin Density Plot: ta vs clw/(clw+cli)")
plt.show()

# %%
#clw frac v/s ta
plt.hexbin(
    df['ta'][::100],
    df['clw/(clw+cli)'][::100],
    gridsize=60,    # adjust resolution (smaller = finer)
    cmap='viridis', # color map
    bins='log'      # use log scale for density
)
plt.colorbar(label='log10(N points)')
plt.xlim(260, 280)
plt.xlabel("temperature")
plt.ylabel("clw / (clw + cli)")
plt.title("Hexbin Density Plot: ta vs clw/(clw+cli)")
plt.show()

# %%
# print("Description of the df:\n")
# print(df[['cli', 'clw', 'qr', 'qg', 'qs']].describe())
# print(df[['cli', 'clw', 'qr', 'qg', 'qs']].isna().sum())
# print("Description ends\n")

# split data into X and y
# X = df.iloc[:, [15,16]].values # RH, ta
X = df.iloc[:, [0,1,15,16,17,18,21,22,23,26,27,30]].values 

y = df.iloc[:, [-2]].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

cols= [0,1,15,16,17,18,21,22,23,26,27,30]
feature_names=df.columns[cols].tolist()
print(feature_names)
# Out:
# ['clon', 'clat', 'hus', 'RH', 'ta', 'wa', 'ua', 'va', 'pfull', 'clw+cli', 'cllvi+clivi', 'qr+qg+qs']

# %%
#This is df and not X_train
# print('RH min: ', df['RH'].min())
# print('RH max: ', df['RH'].max())
# print('\n')
print('ta min: ', df['ta'].min())
print('ta max: ', df['ta'].max())
print('\n')
print('pfull min: ', df['pfull'].min())
print('pfull max: ', df['pfull'].max())
print('\n')
print('wa min: ', df['wa'].min())
print('wa max: ', df['wa'].max())
print('\n')
# Out:
# ta min:  184.59962
# ta max:  300.20624
#
#
# pfull min:  11026.286
# pfull max:  99285.89
#
#
# wa min:  -5.7964835
# wa max:  27.104033

# %%
print(len(y_train))
print(len(y_test))
# Out:
# 4821287
# 1205322

# %% [markdown]
# Decision Tree

# %%
# # #Medium
# # #Use Cross-Validation
# # #best depth acc. to val data

# train_r2_scores=[]
# val_r2_scores=[]
# depths=range(1,11) #This seemed a reasonable depth range which is obtained from trial and error and articles online
# for depth in depths:
#     tree=DTR(max_depth=depth, random_state=1)
#     #train
#     tree.fit(X_train,y_train)
#     train_score=tree.score(X_train, y_train)
#     train_r2_scores.append(train_score)
#     # print(f"Depth {depth}: Training R2 score = {train_score} ") 

#     #val
    
#     val_scores= cross_val_score(tree, X_train, y_train, cv=5, scoring='r2')
#     # print(f"Depth {depth}: Mean Validation R2 score = {val_scores.mean()} ") #val_scores.mean(): .4f
#     val_r2_scores.append(val_scores.mean())

# #print(type(val_scores)) #<class 'numpy.ndarray'>
# #print(val_scores)
# max_val_r2_score=max(val_r2_scores)
# bestDepth=depths[val_r2_scores.index(max_val_r2_score)]
# print(f"\nMax. Validation R2 score: {max_val_r2_score} is at depth (bestDepth): {bestDepth}") #Validation R2 score is different from Test R2 score

# #Plotting
# plt.figure() #figsize=(8,5)
# plt.plot(depths, train_r2_scores, marker='o', label='Training R2')
# plt.plot(depths, val_r2_scores, marker='s', label='Validation R2')
# plt.xlabel("Tree Depth")
# plt.ylabel("R2 score")
# plt.title("Decision Tree Performance vs Depth")
# plt.legend()
# plt.grid(True)
# plt.show()

# #time taken = 64 mins 51 seconds

# %%
# #to find the best Depth and the best number of min samples in leaf
# depths = range(1, 11) #range(1, 21)
# min_samples_in_leaf = range(1, 41) #range(1,51)

# train_r2_scores = []
# val_r2_scores = []
# param_combinations = []

# best_val_score = -np.inf
# best_depth = None
# best_min_samples_leaf = None

# for depth in depths:
#     for min_samples in min_samples_in_leaf:
#         tree = DTR(max_depth=depth, min_samples_leaf=min_samples, random_state=1)

#         tree.fit(X_train, y_train)
#         train_score = tree.score(X_train, y_train)
      
#         val_scores = cross_val_score(tree, X_train, y_train, cv=5, scoring='r2')
#         val_mean = val_scores.mean()
       
#         train_r2_scores.append(train_score)
#         val_r2_scores.append(val_mean)
#         param_combinations.append((depth, min_samples))

#         if val_mean > best_val_score:
#             best_val_score = val_mean
#             best_depth = depth
#             best_min_samples_leaf = min_samples

# print(f"\nBest Validation R2 Score: {best_val_score: }")
# print(f"Best Parameters: max_depth={best_depth}, min_samples_leaf={best_min_samples_leaf}")

# #took 48 mins to run
# #eg: max_depth=14, min_samples_leaf=40

# %%
# #Plot

# param_combinations = np.array(param_combinations)
# depths_arr = param_combinations[:, 0]
# min_samples_arr = param_combinations[:, 1]
# val_r2_scores = np.array(val_r2_scores)


# plt.figure(figsize=(10, 6))
# plt.tricontourf(depths_arr, min_samples_arr, val_r2_scores, levels=20, cmap='viridis')
# plt.colorbar(label="Mean CV (Validation) R2 Score")
# plt.xlabel("Tree Depth")
# plt.ylabel("Min Samples in Leaf")
# plt.title("Decision Tree Cross-Validation Performance Grid Search")
# plt.show()

# %%
#Pathway-1
best_depth= 10 #14
best_min_samples_leaf=30 #40

reg=DTR(max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, random_state=0)
reg.fit(X_train, y_train)
ax=subplots(figsize=(12,12))[1]
plot_tree(reg, feature_names=feature_names, ax=ax)
# Out:
# [Text(0.5498109716859717, 0.9545454545454546, 'ta <= 273.921\nsquared_error = 0.182\nsamples = 4821287\nvalue = 0.529'),
#  Text(0.31114764317889315, 0.8636363636363636, 'clw+cli <= 0.0\nsquared_error = 0.09\nsamples = 3316690\nvalue = 0.76'),
#  Text(0.43047930743243246, 0.9090909090909092, 'True  '),
#  Text(0.16374074967824967, 0.7727272727272727, 'RH <= 95.92\nsquared_error = 0.059\nsamples = 3048782\nvalue = 0.809'),
#  Text(0.08236808236808237, 0.6818181818181818, 'clw+cli <= 0.0\nsquared_error = 0.034\nsamples = 2178736\nvalue = 0.872'),
#  Text(0.04118404118404118, 0.5909090909090909, 'cllvi+clivi <= 0.285\nsquared_error = 0.059\nsamples = 838045\nvalue = 0.798'),
#  Text(0.02059202059202059, 0.5, 'hus <= 0.003\nsquared_error = 0.031\nsamples = 558172\nvalue = 0.847'),
#  Text(0.010296010296010296, 0.4090909090909091, 'hus <= 0.001\nsquared_error = 0.016\nsamples = 273408\nvalue = 0.894'),
#  Text(0.005148005148005148, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.008\nsamples = 72821\nvalue = 0.941'),
#  Text(0.002574002574002574, 0.22727272727272727, 'RH <= 82.135\nsquared_error = 0.005\nsamples = 34227\nvalue = 0.977'),
#  Text(0.001287001287001287, 0.13636363636363635, 'RH <= 74.362\nsquared_error = 0.003\nsamples = 31670\nvalue = 0.984'),
#  Text(0.0006435006435006435, 0.045454545454545456, 'squared_error = 0.003\nsamples = 26979\nvalue = 0.988'),
#  Text(0.0019305019305019305, 0.045454545454545456, 'squared_error = 0.005\nsamples = 4691\nvalue = 0.958'),
#  Text(0.003861003861003861, 0.13636363636363635, 'cllvi+clivi <= 0.008\nsquared_error = 0.018\nsamples = 2557\nvalue = 0.893'),
#  Text(0.0032175032175032173, 0.045454545454545456, 'squared_error = 0.02\nsamples = 382\nvalue = 0.726'),
#  Text(0.0045045045045045045, 0.045454545454545456, 'squared_error = 0.011\nsamples = 2175\nvalue = 0.922'),
#  Text(0.007722007722007722, 0.22727272727272727, 'wa <= 1.834\nsquared_error = 0.008\nsamples = 38594\nvalue = 0.91'),
#  Text(0.006435006435006435, 0.13636363636363635, 'RH <= 50.171\nsquared_error = 0.008\nsamples = 34860\nvalue = 0.916'),
#  Text(0.005791505791505791, 0.045454545454545456, 'squared_error = 0.093\nsamples = 977\nvalue = 0.793'),
#  Text(0.007078507078507079, 0.045454545454545456, 'squared_error = 0.005\nsamples = 33883\nvalue = 0.919'),
#  Text(0.009009009009009009, 0.13636363636363635, 'wa <= 4.128\nsquared_error = 0.004\nsamples = 3734\nvalue = 0.85'),
#  Text(0.008365508365508366, 0.045454545454545456, 'squared_error = 0.002\nsamples = 3117\nvalue = 0.86'),
#  Text(0.009652509652509652, 0.045454545454545456, 'squared_error = 0.01\nsamples = 617\nvalue = 0.803'),
#  Text(0.015444015444015444, 0.3181818181818182, 'qr+qg+qs <= 0.003\nsquared_error = 0.017\nsamples = 200587\nvalue = 0.877'),
#  Text(0.01287001287001287, 0.22727272727272727, 'RH <= 89.958\nsquared_error = 0.017\nsamples = 172519\nvalue = 0.888'),
#  Text(0.011583011583011582, 0.13636363636363635, 'ua <= 22.904\nsquared_error = 0.017\nsamples = 130745\nvalue = 0.899'),
#  Text(0.010939510939510939, 0.045454545454545456, 'squared_error = 0.015\nsamples = 120414\nvalue = 0.903'),
#  Text(0.012226512226512226, 0.045454545454545456, 'squared_error = 0.035\nsamples = 10331\nvalue = 0.846'),
#  Text(0.014157014157014158, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.017\nsamples = 41774\nvalue = 0.854'),
#  Text(0.013513513513513514, 0.045454545454545456, 'squared_error = 0.06\nsamples = 1555\nvalue = 0.586'),
#  Text(0.014800514800514801, 0.045454545454545456, 'squared_error = 0.012\nsamples = 40219\nvalue = 0.864'),
#  Text(0.018018018018018018, 0.22727272727272727, 'RH <= 90.878\nsquared_error = 0.011\nsamples = 28068\nvalue = 0.81'),
#  Text(0.01673101673101673, 0.13636363636363635, 'qr+qg+qs <= 0.004\nsquared_error = 0.008\nsamples = 26762\nvalue = 0.817'),
#  Text(0.016087516087516088, 0.045454545454545456, 'squared_error = 0.008\nsamples = 20191\nvalue = 0.833'),
#  Text(0.017374517374517374, 0.045454545454545456, 'squared_error = 0.006\nsamples = 6571\nvalue = 0.769'),
#  Text(0.019305019305019305, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.041\nsamples = 1306\nvalue = 0.666'),
#  Text(0.01866151866151866, 0.045454545454545456, 'squared_error = 0.013\nsamples = 837\nvalue = 0.766'),
#  Text(0.019948519948519948, 0.045454545454545456, 'squared_error = 0.042\nsamples = 469\nvalue = 0.488'),
#  Text(0.03088803088803089, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.041\nsamples = 284764\nvalue = 0.801'),
#  Text(0.02574002574002574, 0.3181818181818182, 'pfull <= 86265.605\nsquared_error = 0.137\nsamples = 12918\nvalue = 0.589'),
#  Text(0.023166023166023165, 0.22727272727272727, 'RH <= 86.814\nsquared_error = 0.122\nsamples = 9480\nvalue = 0.659'),
#  Text(0.021879021879021878, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.104\nsamples = 4349\nvalue = 0.775'),
#  Text(0.021235521235521235, 0.045454545454545456, 'squared_error = 0.079\nsamples = 1451\nvalue = 0.884'),
#  Text(0.02252252252252252, 0.045454545454545456, 'squared_error = 0.108\nsamples = 2898\nvalue = 0.72'),
#  Text(0.02445302445302445, 0.13636363636363635, 'ta <= 269.872\nsquared_error = 0.116\nsamples = 5131\nvalue = 0.561'),
#  Text(0.023809523809523808, 0.045454545454545456, 'squared_error = 0.097\nsamples = 4090\nvalue = 0.6'),
#  Text(0.025096525096525095, 0.045454545454545456, 'squared_error = 0.162\nsamples = 1041\nvalue = 0.406'),
#  Text(0.028314028314028315, 0.22727272727272727, 'cllvi+clivi <= 0.053\nsquared_error = 0.128\nsamples = 3438\nvalue = 0.395'),
#  Text(0.02702702702702703, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.103\nsamples = 1753\nvalue = 0.56'),
#  Text(0.026383526383526385, 0.045454545454545456, 'squared_error = 0.123\nsamples = 585\nvalue = 0.419'),
#  Text(0.027670527670527672, 0.045454545454545456, 'squared_error = 0.079\nsamples = 1168\nvalue = 0.63'),
#  Text(0.029601029601029602, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.097\nsamples = 1685\nvalue = 0.224'),
#  Text(0.02895752895752896, 0.045454545454545456, 'squared_error = 0.198\nsamples = 119\nvalue = 0.687'),
#  Text(0.030244530244530245, 0.045454545454545456, 'squared_error = 0.072\nsamples = 1566\nvalue = 0.189'),
#  Text(0.036036036036036036, 0.3181818181818182, 'qr+qg+qs <= 0.002\nsquared_error = 0.034\nsamples = 271846\nvalue = 0.811'),
#  Text(0.03346203346203346, 0.22727272727272727, 'ta <= 270.999\nsquared_error = 0.036\nsamples = 221863\nvalue = 0.824'),
#  Text(0.032175032175032175, 0.13636363636363635, 'clat <= -0.302\nsquared_error = 0.033\nsamples = 188064\nvalue = 0.832'),
#  Text(0.03153153153153153, 0.045454545454545456, 'squared_error = 0.024\nsamples = 47400\nvalue = 0.866'),
#  Text(0.032818532818532815, 0.045454545454545456, 'squared_error = 0.035\nsamples = 140664\nvalue = 0.821'),
#  Text(0.03474903474903475, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.053\nsamples = 33799\nvalue = 0.775'),
#  Text(0.0341055341055341, 0.045454545454545456, 'squared_error = 0.137\nsamples = 2811\nvalue = 0.641'),
#  Text(0.035392535392535396, 0.045454545454545456, 'squared_error = 0.044\nsamples = 30988\nvalue = 0.788'),
#  Text(0.03861003861003861, 0.22727272727272727, 'RH <= 77.332\nsquared_error = 0.022\nsamples = 49983\nvalue = 0.757'),
#  Text(0.03732303732303732, 0.13636363636363635, 'wa <= -1.823\nsquared_error = 0.091\nsamples = 378\nvalue = 0.307'),
#  Text(0.03667953667953668, 0.045454545454545456, 'squared_error = 0.037\nsamples = 147\nvalue = 0.602'),
#  Text(0.03796653796653797, 0.045454545454545456, 'squared_error = 0.036\nsamples = 231\nvalue = 0.119'),
#  Text(0.039897039897039896, 0.13636363636363635, 'ta <= 261.672\nsquared_error = 0.02\nsamples = 49605\nvalue = 0.76'),
#  Text(0.039253539253539256, 0.045454545454545456, 'squared_error = 0.012\nsamples = 17021\nvalue = 0.809'),
#  Text(0.04054054054054054, 0.045454545454545456, 'squared_error = 0.022\nsamples = 32584\nvalue = 0.734'),
#  Text(0.06177606177606178, 0.5, 'qr+qg+qs <= 0.001\nsquared_error = 0.101\nsamples = 279873\nvalue = 0.701'),
#  Text(0.05148005148005148, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.09\nsamples = 129717\nvalue = 0.774'),
#  Text(0.04633204633204633, 0.3181818181818182, 'pfull <= 84189.992\nsquared_error = 0.112\nsamples = 76798\nvalue = 0.724'),
#  Text(0.043758043758043756, 0.22727272727272727, 'clat <= 0.47\nsquared_error = 0.108\nsamples = 75719\nvalue = 0.732'),
#  Text(0.04247104247104247, 0.13636363636363635, 'pfull <= 51381.322\nsquared_error = 0.116\nsamples = 63798\nvalue = 0.707'),
#  Text(0.04182754182754183, 0.045454545454545456, 'squared_error = 0.102\nsamples = 28429\nvalue = 0.764'),
#  Text(0.043114543114543116, 0.045454545454545456, 'squared_error = 0.122\nsamples = 35369\nvalue = 0.662'),
#  Text(0.04504504504504504, 0.13636363636363635, 'pfull <= 74423.27\nsquared_error = 0.045\nsamples = 11921\nvalue = 0.865'),
#  Text(0.0444015444015444, 0.045454545454545456, 'squared_error = 0.023\nsamples = 9433\nvalue = 0.895'),
#  Text(0.04568854568854569, 0.045454545454545456, 'squared_error = 0.11\nsamples = 2488\nvalue = 0.751'),
#  Text(0.0489060489060489, 0.22727272727272727, 'cllvi+clivi <= 0.312\nsquared_error = 0.098\nsamples = 1079\nvalue = 0.179'),
#  Text(0.047619047619047616, 0.13636363636363635, 'clon <= 0.822\nsquared_error = 0.164\nsamples = 249\nvalue = 0.399'),
#  Text(0.046975546975546977, 0.045454545454545456, 'squared_error = 0.162\nsamples = 189\nvalue = 0.488'),
#  Text(0.04826254826254826, 0.045454545454545456, 'squared_error = 0.069\nsamples = 60\nvalue = 0.119'),
#  Text(0.05019305019305019, 0.13636363636363635, 'cllvi+clivi <= 0.41\nsquared_error = 0.059\nsamples = 830\nvalue = 0.113'),
#  Text(0.04954954954954955, 0.045454545454545456, 'squared_error = 0.091\nsamples = 413\nvalue = 0.173'),
#  Text(0.05083655083655084, 0.045454545454545456, 'squared_error = 0.021\nsamples = 417\nvalue = 0.055'),
#  Text(0.05662805662805663, 0.3181818181818182, 'wa <= -0.366\nsquared_error = 0.05\nsamples = 52919\nvalue = 0.846'),
#  Text(0.05405405405405406, 0.22727272727272727, 'wa <= -0.857\nsquared_error = 0.101\nsamples = 3715\nvalue = 0.709'),
#  Text(0.05276705276705277, 0.13636363636363635, 'clat <= 0.021\nsquared_error = 0.124\nsamples = 550\nvalue = 0.558'),
#  Text(0.052123552123552123, 0.045454545454545456, 'squared_error = 0.121\nsamples = 332\nvalue = 0.459'),
#  Text(0.05341055341055341, 0.045454545454545456, 'squared_error = 0.091\nsamples = 218\nvalue = 0.71'),
#  Text(0.055341055341055344, 0.13636363636363635, 'RH <= 89.83\nsquared_error = 0.092\nsamples = 3165\nvalue = 0.735'),
#  Text(0.0546975546975547, 0.045454545454545456, 'squared_error = 0.082\nsamples = 2810\nvalue = 0.76'),
#  Text(0.055984555984555984, 0.045454545454545456, 'squared_error = 0.125\nsamples = 355\nvalue = 0.537'),
#  Text(0.059202059202059204, 0.22727272727272727, 'pfull <= 76190.363\nsquared_error = 0.044\nsamples = 49204\nvalue = 0.856'),
#  Text(0.05791505791505792, 0.13636363636363635, 'clat <= 0.469\nsquared_error = 0.043\nsamples = 48886\nvalue = 0.859'),
#  Text(0.05727155727155727, 0.045454545454545456, 'squared_error = 0.049\nsamples = 37913\nvalue = 0.844'),
#  Text(0.05855855855855856, 0.045454545454545456, 'squared_error = 0.017\nsamples = 10973\nvalue = 0.908'),
#  Text(0.06048906048906049, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.168\nsamples = 318\nvalue = 0.509'),
#  Text(0.059845559845559844, 0.045454545454545456, 'squared_error = 0.134\nsamples = 165\nvalue = 0.264'),
#  Text(0.06113256113256113, 0.045454545454545456, 'squared_error = 0.072\nsamples = 153\nvalue = 0.772'),
#  Text(0.07207207207207207, 0.4090909090909091, 'ta <= 266.363\nsquared_error = 0.103\nsamples = 150156\nvalue = 0.638'),
#  Text(0.06692406692406692, 0.3181818181818182, 'qr+qg+qs <= 0.007\nsquared_error = 0.075\nsamples = 114967\nvalue = 0.708'),
#  Text(0.06435006435006435, 0.22727272727272727, 'RH <= 93.721\nsquared_error = 0.065\nsamples = 108198\nvalue = 0.729'),
#  Text(0.06306306306306306, 0.13636363636363635, 'RH <= 67.876\nsquared_error = 0.055\nsamples = 94861\nvalue = 0.749'),
#  Text(0.06241956241956242, 0.045454545454545456, 'squared_error = 0.172\nsamples = 1328\nvalue = 0.345'),
#  Text(0.0637065637065637, 0.045454545454545456, 'squared_error = 0.051\nsamples = 93533\nvalue = 0.755'),
#  Text(0.06563706563706563, 0.13636363636363635, 'qr+qg+qs <= 0.003\nsquared_error = 0.11\nsamples = 13337\nvalue = 0.587'),
#  Text(0.064993564993565, 0.045454545454545456, 'squared_error = 0.058\nsamples = 10296\nvalue = 0.711'),
#  Text(0.06628056628056628, 0.045454545454545456, 'squared_error = 0.06\nsamples = 3041\nvalue = 0.168'),
#  Text(0.0694980694980695, 0.22727272727272727, 'RH <= 88.684\nsquared_error = 0.12\nsamples = 6769\nvalue = 0.37'),
#  Text(0.0682110682110682, 0.13636363636363635, 'RH <= 87.566\nsquared_error = 0.034\nsamples = 3648\nvalue = 0.661'),
#  Text(0.06756756756756757, 0.045454545454545456, 'squared_error = 0.024\nsamples = 3237\nvalue = 0.693'),
#  Text(0.06885456885456885, 0.045454545454545456, 'squared_error = 0.043\nsamples = 411\nvalue = 0.409'),
#  Text(0.07078507078507079, 0.13636363636363635, 'cllvi+clivi <= 0.698\nsquared_error = 0.006\nsamples = 3121\nvalue = 0.029'),
#  Text(0.07014157014157014, 0.045454545454545456, 'squared_error = 0.007\nsamples = 233\nvalue = 0.244'),
#  Text(0.07142857142857142, 0.045454545454545456, 'squared_error = 0.001\nsamples = 2888\nvalue = 0.012'),
#  Text(0.07722007722007722, 0.3181818181818182, 'RH <= 90.272\nsquared_error = 0.124\nsamples = 35189\nvalue = 0.409'),
#  Text(0.07464607464607464, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.112\nsamples = 16043\nvalue = 0.261'),
#  Text(0.07335907335907337, 0.13636363636363635, 'RH <= 78.295\nsquared_error = 0.133\nsamples = 4176\nvalue = 0.493'),
#  Text(0.07271557271557272, 0.045454545454545456, 'squared_error = 0.055\nsamples = 1341\nvalue = 0.11'),
#  Text(0.074002574002574, 0.045454545454545456, 'squared_error = 0.069\nsamples = 2835\nvalue = 0.674'),
#  Text(0.07593307593307594, 0.13636363636363635, 'qr+qg+qs <= 0.002\nsquared_error = 0.079\nsamples = 11867\nvalue = 0.18'),
#  Text(0.07528957528957529, 0.045454545454545456, 'squared_error = 0.124\nsamples = 3764\nvalue = 0.353'),
#  Text(0.07657657657657657, 0.045454545454545456, 'squared_error = 0.038\nsamples = 8103\nvalue = 0.099'),
#  Text(0.07979407979407979, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.1\nsamples = 19146\nvalue = 0.534'),
#  Text(0.07850707850707851, 0.13636363636363635, 'ta <= 268.851\nsquared_error = 0.087\nsamples = 16813\nvalue = 0.572'),
#  Text(0.07786357786357787, 0.045454545454545456, 'squared_error = 0.065\nsamples = 10196\nvalue = 0.637'),
#  Text(0.07915057915057915, 0.045454545454545456, 'squared_error = 0.106\nsamples = 6617\nvalue = 0.472'),
#  Text(0.08108108108108109, 0.13636363636363635, 'clon <= -1.607\nsquared_error = 0.107\nsamples = 2333\nvalue = 0.257'),
#  Text(0.08043758043758044, 0.045454545454545456, 'squared_error = 0.109\nsamples = 300\nvalue = 0.638'),
#  Text(0.08172458172458172, 0.045454545454545456, 'squared_error = 0.082\nsamples = 2033\nvalue = 0.2'),
#  Text(0.12355212355212356, 0.5909090909090909, 'qr+qg+qs <= 0.001\nsquared_error = 0.013\nsamples = 1340691\nvalue = 0.919'),
#  Text(0.10296010296010295, 0.5, 'RH <= 88.852\nsquared_error = 0.006\nsamples = 1051328\nvalue = 0.937'),
#  Text(0.09266409266409266, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.005\nsamples = 743776\nvalue = 0.952'),
#  Text(0.08751608751608751, 0.3181818181818182, 'RH <= 82.062\nsquared_error = 0.002\nsamples = 602768\nvalue = 0.958'),
#  Text(0.08494208494208494, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.002\nsamples = 347126\nvalue = 0.971'),
#  Text(0.08365508365508366, 0.13636363636363635, 'ta <= 248.693\nsquared_error = 0.001\nsamples = 274589\nvalue = 0.976'),
#  Text(0.08301158301158301, 0.045454545454545456, 'squared_error = 0.001\nsamples = 198397\nvalue = 0.981'),
#  Text(0.08429858429858429, 0.045454545454545456, 'squared_error = 0.002\nsamples = 76192\nvalue = 0.961'),
#  Text(0.08622908622908623, 0.13636363636363635, 'RH <= 68.869\nsquared_error = 0.005\nsamples = 72537\nvalue = 0.954'),
#  Text(0.08558558558558559, 0.045454545454545456, 'squared_error = 0.01\nsamples = 15579\nvalue = 0.933'),
#  Text(0.08687258687258688, 0.045454545454545456, 'squared_error = 0.003\nsamples = 56958\nvalue = 0.959'),
#  Text(0.09009009009009009, 0.22727272727272727, 'cllvi+clivi <= 0.046\nsquared_error = 0.003\nsamples = 255642\nvalue = 0.941'),
#  Text(0.0888030888030888, 0.13636363636363635, 'cllvi+clivi <= 0.012\nsquared_error = 0.004\nsamples = 38491\nvalue = 0.903'),
#  Text(0.08815958815958816, 0.045454545454545456, 'squared_error = 0.008\nsamples = 4677\nvalue = 0.84'),
#  Text(0.08944658944658945, 0.045454545454545456, 'squared_error = 0.003\nsamples = 33814\nvalue = 0.912'),
#  Text(0.09137709137709138, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.002\nsamples = 217151\nvalue = 0.948'),
#  Text(0.09073359073359073, 0.045454545454545456, 'squared_error = 0.011\nsamples = 7267\nvalue = 0.888'),
#  Text(0.09202059202059203, 0.045454545454545456, 'squared_error = 0.002\nsamples = 209884\nvalue = 0.95'),
#  Text(0.0978120978120978, 0.3181818181818182, 'cllvi+clivi <= 0.315\nsquared_error = 0.013\nsamples = 141008\nvalue = 0.927'),
#  Text(0.09523809523809523, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.004\nsamples = 82034\nvalue = 0.943'),
#  Text(0.09395109395109395, 0.13636363636363635, 'cllvi+clivi <= 0.189\nsquared_error = 0.009\nsamples = 17880\nvalue = 0.921'),
#  Text(0.0933075933075933, 0.045454545454545456, 'squared_error = 0.005\nsamples = 13606\nvalue = 0.928'),
#  Text(0.0945945945945946, 0.045454545454545456, 'squared_error = 0.019\nsamples = 4274\nvalue = 0.898'),
#  Text(0.09652509652509653, 0.13636363636363635, 'cllvi+clivi <= 0.199\nsquared_error = 0.003\nsamples = 64154\nvalue = 0.949'),
#  Text(0.09588159588159588, 0.045454545454545456, 'squared_error = 0.001\nsamples = 43590\nvalue = 0.954'),
#  Text(0.09716859716859717, 0.045454545454545456, 'squared_error = 0.006\nsamples = 20564\nvalue = 0.94'),
#  Text(0.10038610038610038, 0.22727272727272727, 'clon <= -2.095\nsquared_error = 0.023\nsamples = 58974\nvalue = 0.904'),
#  Text(0.0990990990990991, 0.13636363636363635, 'clon <= -2.913\nsquared_error = 0.004\nsamples = 15335\nvalue = 0.955'),
#  Text(0.09845559845559845, 0.045454545454545456, 'squared_error = 0.016\nsamples = 2410\nvalue = 0.918'),
#  Text(0.09974259974259975, 0.045454545454545456, 'squared_error = 0.001\nsamples = 12925\nvalue = 0.962'),
#  Text(0.10167310167310167, 0.13636363636363635, 'clon <= -0.982\nsquared_error = 0.029\nsamples = 43639\nvalue = 0.886'),
#  Text(0.10102960102960103, 0.045454545454545456, 'squared_error = 0.065\nsamples = 4019\nvalue = 0.784'),
#  Text(0.10231660231660232, 0.045454545454545456, 'squared_error = 0.024\nsamples = 39620\nvalue = 0.896'),
#  Text(0.11325611325611326, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.008\nsamples = 307552\nvalue = 0.901'),
#  Text(0.10810810810810811, 0.3181818181818182, 'ta <= 266.445\nsquared_error = 0.028\nsamples = 22328\nvalue = 0.785'),
#  Text(0.10553410553410554, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.015\nsamples = 19832\nvalue = 0.811'),
#  Text(0.10424710424710425, 0.13636363636363635, 'hus <= 0.001\nsquared_error = 0.02\nsamples = 6636\nvalue = 0.757'),
#  Text(0.1036036036036036, 0.045454545454545456, 'squared_error = 0.009\nsamples = 1714\nvalue = 0.836'),
#  Text(0.1048906048906049, 0.045454545454545456, 'squared_error = 0.021\nsamples = 4922\nvalue = 0.729'),
#  Text(0.10682110682110682, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.011\nsamples = 13196\nvalue = 0.837'),
#  Text(0.10617760617760617, 0.045454545454545456, 'squared_error = 0.006\nsamples = 7027\nvalue = 0.864'),
#  Text(0.10746460746460747, 0.045454545454545456, 'squared_error = 0.014\nsamples = 6169\nvalue = 0.807'),
#  Text(0.11068211068211069, 0.22727272727272727, 'ta <= 269.385\nsquared_error = 0.079\nsamples = 2496\nvalue = 0.581'),
#  Text(0.1093951093951094, 0.13636363636363635, 'pfull <= 88132.188\nsquared_error = 0.053\nsamples = 1943\nvalue = 0.643'),
#  Text(0.10875160875160875, 0.045454545454545456, 'squared_error = 0.036\nsamples = 1144\nvalue = 0.719'),
#  Text(0.11003861003861004, 0.045454545454545456, 'squared_error = 0.056\nsamples = 799\nvalue = 0.534'),
#  Text(0.11196911196911197, 0.13636363636363635, 'cllvi+clivi <= 0.059\nsquared_error = 0.113\nsamples = 553\nvalue = 0.366'),
#  Text(0.11132561132561132, 0.045454545454545456, 'squared_error = 0.072\nsamples = 238\nvalue = 0.596'),
#  Text(0.11261261261261261, 0.045454545454545456, 'squared_error = 0.074\nsamples = 315\nvalue = 0.191'),
#  Text(0.11840411840411841, 0.3181818181818182, 'ta <= 266.915\nsquared_error = 0.006\nsamples = 285224\nvalue = 0.91'),
#  Text(0.11583011583011583, 0.22727272727272727, 'cllvi+clivi <= 0.066\nsquared_error = 0.005\nsamples = 264545\nvalue = 0.915'),
#  Text(0.11454311454311454, 0.13636363636363635, 'cllvi+clivi <= 0.027\nsquared_error = 0.005\nsamples = 42843\nvalue = 0.881'),
#  Text(0.1138996138996139, 0.045454545454545456, 'squared_error = 0.008\nsamples = 7076\nvalue = 0.84'),
#  Text(0.11518661518661519, 0.045454545454545456, 'squared_error = 0.004\nsamples = 35767\nvalue = 0.889'),
#  Text(0.11711711711711711, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.004\nsamples = 221702\nvalue = 0.922'),
#  Text(0.11647361647361647, 0.045454545454545456, 'squared_error = 0.007\nsamples = 97709\nvalue = 0.908'),
#  Text(0.11776061776061776, 0.045454545454545456, 'squared_error = 0.002\nsamples = 123993\nvalue = 0.932'),
#  Text(0.12097812097812098, 0.22727272727272727, 'pfull <= 86645.688\nsquared_error = 0.013\nsamples = 20679\nvalue = 0.846'),
#  Text(0.11969111969111969, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.009\nsamples = 15542\nvalue = 0.864'),
#  Text(0.11904761904761904, 0.045454545454545456, 'squared_error = 0.016\nsamples = 2493\nvalue = 0.812'),
#  Text(0.12033462033462033, 0.045454545454545456, 'squared_error = 0.007\nsamples = 13049\nvalue = 0.874'),
#  Text(0.12226512226512226, 0.13636363636363635, 'cllvi+clivi <= 0.282\nsquared_error = 0.022\nsamples = 5137\nvalue = 0.792'),
#  Text(0.12162162162162163, 0.045454545454545456, 'squared_error = 0.017\nsamples = 4990\nvalue = 0.802'),
#  Text(0.12290862290862291, 0.045454545454545456, 'squared_error = 0.08\nsamples = 147\nvalue = 0.453'),
#  Text(0.14414414414414414, 0.5, 'RH <= 80.4\nsquared_error = 0.034\nsamples = 289363\nvalue = 0.851'),
#  Text(0.13384813384813385, 0.4090909090909091, 'cllvi+clivi <= 0.245\nsquared_error = 0.02\nsamples = 243098\nvalue = 0.875'),
#  Text(0.1287001287001287, 0.3181818181818182, 'qr+qg+qs <= 0.005\nsquared_error = 0.005\nsamples = 122153\nvalue = 0.913'),
#  Text(0.12612612612612611, 0.22727272727272727, 'qr+qg+qs <= 0.003\nsquared_error = 0.004\nsamples = 101241\nvalue = 0.925'),
#  Text(0.12483912483912483, 0.13636363636363635, 'ta <= 251.732\nsquared_error = 0.003\nsamples = 67950\nvalue = 0.934'),
#  Text(0.1241956241956242, 0.045454545454545456, 'squared_error = 0.003\nsamples = 66985\nvalue = 0.936'),
#  Text(0.12548262548262548, 0.045454545454545456, 'squared_error = 0.029\nsamples = 965\nvalue = 0.821'),
#  Text(0.1274131274131274, 0.13636363636363635, 'RH <= 74.554\nsquared_error = 0.004\nsamples = 33291\nvalue = 0.907'),
#  Text(0.12676962676962678, 0.045454545454545456, 'squared_error = 0.003\nsamples = 30580\nvalue = 0.912'),
#  Text(0.12805662805662807, 0.045454545454545456, 'squared_error = 0.013\nsamples = 2711\nvalue = 0.851'),
#  Text(0.13127413127413126, 0.22727272727272727, 'qr+qg+qs <= 0.008\nsquared_error = 0.006\nsamples = 20912\nvalue = 0.854'),
#  Text(0.12998712998713, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.005\nsamples = 20571\nvalue = 0.857'),
#  Text(0.12934362934362933, 0.045454545454545456, 'squared_error = 0.005\nsamples = 19886\nvalue = 0.861'),
#  Text(0.13063063063063063, 0.045454545454545456, 'squared_error = 0.013\nsamples = 685\nvalue = 0.741'),
#  Text(0.13256113256113256, 0.13636363636363635, 'clon <= -1.153\nsquared_error = 0.021\nsamples = 341\nvalue = 0.67'),
#  Text(0.13191763191763192, 0.045454545454545456, 'squared_error = 0.001\nsamples = 139\nvalue = 0.502'),
#  Text(0.13320463320463322, 0.045454545454545456, 'squared_error = 0.002\nsamples = 202\nvalue = 0.786'),
#  Text(0.138996138996139, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.032\nsamples = 120945\nvalue = 0.837'),
#  Text(0.1364221364221364, 0.22727272727272727, 'ta <= 253.279\nsquared_error = 0.024\nsamples = 98209\nvalue = 0.856'),
#  Text(0.13513513513513514, 0.13636363636363635, 'qr+qg+qs <= 0.004\nsquared_error = 0.021\nsamples = 96537\nvalue = 0.862'),
#  Text(0.13449163449163448, 0.045454545454545456, 'squared_error = 0.019\nsamples = 60328\nvalue = 0.888'),
#  Text(0.13577863577863578, 0.045454545454545456, 'squared_error = 0.021\nsamples = 36209\nvalue = 0.818'),
#  Text(0.1377091377091377, 0.13636363636363635, 'RH <= 74.835\nsquared_error = 0.12\nsamples = 1672\nvalue = 0.534'),
#  Text(0.13706563706563707, 0.045454545454545456, 'squared_error = 0.074\nsamples = 387\nvalue = 0.236'),
#  Text(0.13835263835263836, 0.045454545454545456, 'squared_error = 0.098\nsamples = 1285\nvalue = 0.624'),
#  Text(0.14157014157014158, 0.22727272727272727, 'pfull <= 29978.757\nsquared_error = 0.057\nsamples = 22736\nvalue = 0.757'),
#  Text(0.1402831402831403, 0.13636363636363635, 'qr+qg+qs <= 0.002\nsquared_error = 0.039\nsamples = 17982\nvalue = 0.799'),
#  Text(0.13963963963963963, 0.045454545454545456, 'squared_error = 0.027\nsamples = 11047\nvalue = 0.851'),
#  Text(0.14092664092664092, 0.045454545454545456, 'squared_error = 0.047\nsamples = 6935\nvalue = 0.717'),
#  Text(0.14285714285714285, 0.13636363636363635, 'qr+qg+qs <= 0.002\nsquared_error = 0.094\nsamples = 4754\nvalue = 0.597'),
#  Text(0.14221364221364222, 0.045454545454545456, 'squared_error = 0.071\nsamples = 3527\nvalue = 0.677'),
#  Text(0.1435006435006435, 0.045454545454545456, 'squared_error = 0.087\nsamples = 1227\nvalue = 0.367'),
#  Text(0.15444015444015444, 0.4090909090909091, 'qr+qg+qs <= 0.003\nsquared_error = 0.088\nsamples = 46265\nvalue = 0.721'),
#  Text(0.1492921492921493, 0.3181818181818182, 'cllvi+clivi <= 0.382\nsquared_error = 0.06\nsamples = 41213\nvalue = 0.779'),
#  Text(0.14671814671814673, 0.22727272727272727, 'qr+qg+qs <= 0.002\nsquared_error = 0.02\nsamples = 23361\nvalue = 0.862'),
#  Text(0.14543114543114544, 0.13636363636363635, 'cllvi+clivi <= 0.234\nsquared_error = 0.014\nsamples = 17680\nvalue = 0.882'),
#  Text(0.14478764478764478, 0.045454545454545456, 'squared_error = 0.009\nsamples = 13882\nvalue = 0.895'),
#  Text(0.14607464607464607, 0.045454545454545456, 'squared_error = 0.033\nsamples = 3798\nvalue = 0.832'),
#  Text(0.148005148005148, 0.13636363636363635, 'RH <= 91.881\nsquared_error = 0.033\nsamples = 5681\nvalue = 0.798'),
#  Text(0.14736164736164736, 0.045454545454545456, 'squared_error = 0.027\nsamples = 5207\nvalue = 0.817'),
#  Text(0.14864864864864866, 0.045454545454545456, 'squared_error = 0.063\nsamples = 474\nvalue = 0.595'),
#  Text(0.15186615186615188, 0.22727272727272727, 'qr+qg+qs <= 0.002\nsquared_error = 0.091\nsamples = 17852\nvalue = 0.671'),
#  Text(0.15057915057915058, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.073\nsamples = 12016\nvalue = 0.74'),
#  Text(0.14993564993564992, 0.045454545454545456, 'squared_error = 0.062\nsamples = 10643\nvalue = 0.773'),
#  Text(0.15122265122265122, 0.045454545454545456, 'squared_error = 0.086\nsamples = 1373\nvalue = 0.483'),
#  Text(0.15315315315315314, 0.13636363636363635, 'wa <= 2.132\nsquared_error = 0.098\nsamples = 5836\nvalue = 0.529'),
#  Text(0.1525096525096525, 0.045454545454545456, 'squared_error = 0.114\nsamples = 2991\nvalue = 0.413'),
#  Text(0.1537966537966538, 0.045454545454545456, 'squared_error = 0.053\nsamples = 2845\nvalue = 0.65'),
#  Text(0.15958815958815958, 0.3181818181818182, 'RH <= 87.439\nsquared_error = 0.059\nsamples = 5052\nvalue = 0.245'),
#  Text(0.15701415701415702, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.058\nsamples = 2301\nvalue = 0.393'),
#  Text(0.15572715572715573, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.057\nsamples = 346\nvalue = 0.718'),
#  Text(0.15508365508365507, 0.045454545454545456, 'squared_error = 0.018\nsamples = 298\nvalue = 0.785'),
#  Text(0.15637065637065636, 0.045454545454545456, 'squared_error = 0.102\nsamples = 48\nvalue = 0.306'),
#  Text(0.1583011583011583, 0.13636363636363635, 'qr+qg+qs <= 0.004\nsquared_error = 0.036\nsamples = 1955\nvalue = 0.335'),
#  Text(0.15765765765765766, 0.045454545454545456, 'squared_error = 0.033\nsamples = 1258\nvalue = 0.414'),
#  Text(0.15894465894465895, 0.045454545454545456, 'squared_error = 0.009\nsamples = 697\nvalue = 0.192'),
#  Text(0.16216216216216217, 0.22727272727272727, 'qr+qg+qs <= 0.004\nsquared_error = 0.026\nsamples = 2751\nvalue = 0.121'),
#  Text(0.16087516087516088, 0.13636363636363635, 'wa <= 2.339\nsquared_error = 0.049\nsamples = 768\nvalue = 0.257'),
#  Text(0.16023166023166024, 0.045454545454545456, 'squared_error = 0.032\nsamples = 313\nvalue = 0.104'),
#  Text(0.1615186615186615, 0.045454545454545456, 'squared_error = 0.033\nsamples = 455\nvalue = 0.363'),
#  Text(0.16344916344916344, 0.13636363636363635, 'clon <= 2.863\nsquared_error = 0.007\nsamples = 1983\nvalue = 0.069'),
#  Text(0.1628056628056628, 0.045454545454545456, 'squared_error = 0.005\nsamples = 1940\nvalue = 0.062'),
#  Text(0.1640926640926641, 0.045454545454545456, 'squared_error = 0.003\nsamples = 43\nvalue = 0.386'),
#  Text(0.245113416988417, 0.6818181818181818, 'qr+qg+qs <= 0.002\nsquared_error = 0.087\nsamples = 870046\nvalue = 0.652'),
#  Text(0.2059202059202059, 0.5909090909090909, 'clw+cli <= 0.0\nsquared_error = 0.061\nsamples = 732508\nvalue = 0.706'),
#  Text(0.18532818532818532, 0.5, 'qr+qg+qs <= 0.0\nsquared_error = 0.041\nsamples = 596478\nvalue = 0.756'),
#  Text(0.17503217503217502, 0.4090909090909091, 'cllvi+clivi <= 0.071\nsquared_error = 0.094\nsamples = 25113\nvalue = 0.492'),
#  Text(0.16988416988416988, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.063\nsamples = 13091\nvalue = 0.597'),
#  Text(0.16731016731016732, 0.22727272727272727, 'ta <= 264.101\nsquared_error = 0.075\nsamples = 4158\nvalue = 0.433'),
#  Text(0.16602316602316602, 0.13636363636363635, 'hus <= 0.001\nsquared_error = 0.037\nsamples = 1144\nvalue = 0.603'),
#  Text(0.1653796653796654, 0.045454545454545456, 'squared_error = 0.016\nsamples = 263\nvalue = 0.752'),
#  Text(0.16666666666666666, 0.045454545454545456, 'squared_error = 0.035\nsamples = 881\nvalue = 0.558'),
#  Text(0.16859716859716858, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.075\nsamples = 3014\nvalue = 0.368'),
#  Text(0.16795366795366795, 0.045454545454545456, 'squared_error = 0.069\nsamples = 1001\nvalue = 0.229'),
#  Text(0.16924066924066924, 0.045454545454545456, 'squared_error = 0.063\nsamples = 2013\nvalue = 0.438'),
#  Text(0.17245817245817247, 0.22727272727272727, 'wa <= -0.055\nsquared_error = 0.039\nsamples = 8933\nvalue = 0.674'),
#  Text(0.17117117117117117, 0.13636363636363635, 'hus <= 0.003\nsquared_error = 0.076\nsamples = 717\nvalue = 0.48'),
#  Text(0.17052767052767054, 0.045454545454545456, 'squared_error = 0.055\nsamples = 425\nvalue = 0.576'),
#  Text(0.1718146718146718, 0.045454545454545456, 'squared_error = 0.074\nsamples = 292\nvalue = 0.34'),
#  Text(0.17374517374517376, 0.13636363636363635, 'cllvi+clivi <= 0.049\nsquared_error = 0.032\nsamples = 8216\nvalue = 0.691'),
#  Text(0.1731016731016731, 0.045454545454545456, 'squared_error = 0.024\nsamples = 6032\nvalue = 0.718'),
#  Text(0.1743886743886744, 0.045454545454545456, 'squared_error = 0.046\nsamples = 2184\nvalue = 0.616'),
#  Text(0.18018018018018017, 0.3181818181818182, 'pfull <= 85827.789\nsquared_error = 0.102\nsamples = 12022\nvalue = 0.377'),
#  Text(0.1776061776061776, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.099\nsamples = 7545\nvalue = 0.473'),
#  Text(0.17631917631917632, 0.13636363636363635, 'ta <= 264.763\nsquared_error = 0.089\nsamples = 2642\nvalue = 0.35'),
#  Text(0.17567567567567569, 0.045454545454545456, 'squared_error = 0.05\nsamples = 595\nvalue = 0.531'),
#  Text(0.17696267696267695, 0.045454545454545456, 'squared_error = 0.089\nsamples = 2047\nvalue = 0.297'),
#  Text(0.1788931788931789, 0.13636363636363635, 'hus <= 0.003\nsquared_error = 0.092\nsamples = 4903\nvalue = 0.539'),
#  Text(0.17824967824967825, 0.045454545454545456, 'squared_error = 0.049\nsamples = 1702\nvalue = 0.66'),
#  Text(0.17953667953667954, 0.045454545454545456, 'squared_error = 0.104\nsamples = 3201\nvalue = 0.474'),
#  Text(0.18275418275418276, 0.22727272727272727, 'cllvi+clivi <= 0.126\nsquared_error = 0.066\nsamples = 4477\nvalue = 0.217'),
#  Text(0.18146718146718147, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.071\nsamples = 2377\nvalue = 0.309'),
#  Text(0.18082368082368083, 0.045454545454545456, 'squared_error = 0.049\nsamples = 1048\nvalue = 0.166'),
#  Text(0.1821106821106821, 0.045454545454545456, 'squared_error = 0.059\nsamples = 1329\nvalue = 0.422'),
#  Text(0.18404118404118405, 0.13636363636363635, 'pfull <= 88517.414\nsquared_error = 0.04\nsamples = 2100\nvalue = 0.112'),
#  Text(0.1833976833976834, 0.045454545454545456, 'squared_error = 0.072\nsamples = 677\nvalue = 0.216'),
#  Text(0.18468468468468469, 0.045454545454545456, 'squared_error = 0.018\nsamples = 1423\nvalue = 0.063'),
#  Text(0.1956241956241956, 0.4090909090909091, 'hus <= 0.005\nsquared_error = 0.035\nsamples = 571365\nvalue = 0.768'),
#  Text(0.19047619047619047, 0.3181818181818182, 'qr+qg+qs <= 0.001\nsquared_error = 0.029\nsamples = 384989\nvalue = 0.796'),
#  Text(0.1879021879021879, 0.22727272727272727, 'ta <= 268.827\nsquared_error = 0.025\nsamples = 361301\nvalue = 0.804'),
#  Text(0.1866151866151866, 0.13636363636363635, 'RH <= 98.041\nsquared_error = 0.019\nsamples = 230635\nvalue = 0.827'),
#  Text(0.18597168597168598, 0.045454545454545456, 'squared_error = 0.015\nsamples = 110468\nvalue = 0.853'),
#  Text(0.18725868725868725, 0.045454545454545456, 'squared_error = 0.022\nsamples = 120167\nvalue = 0.803'),
#  Text(0.1891891891891892, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.034\nsamples = 130666\nvalue = 0.763'),
#  Text(0.18854568854568854, 0.045454545454545456, 'squared_error = 0.028\nsamples = 103597\nvalue = 0.786'),
#  Text(0.18983268983268983, 0.045454545454545456, 'squared_error = 0.045\nsamples = 27069\nvalue = 0.675'),
#  Text(0.19305019305019305, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.062\nsamples = 23688\nvalue = 0.672'),
#  Text(0.19176319176319176, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.024\nsamples = 19026\nvalue = 0.752'),
#  Text(0.19111969111969113, 0.045454545454545456, 'squared_error = 0.013\nsamples = 14907\nvalue = 0.773'),
#  Text(0.19240669240669242, 0.045454545454545456, 'squared_error = 0.057\nsamples = 4119\nvalue = 0.676'),
#  Text(0.19433719433719435, 0.13636363636363635, 'wa <= 1.748\nsquared_error = 0.086\nsamples = 4662\nvalue = 0.347'),
#  Text(0.19369369369369369, 0.045454545454545456, 'squared_error = 0.071\nsamples = 2857\nvalue = 0.235'),
#  Text(0.19498069498069498, 0.045454545454545456, 'squared_error = 0.059\nsamples = 1805\nvalue = 0.524'),
#  Text(0.20077220077220076, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.044\nsamples = 186376\nvalue = 0.711'),
#  Text(0.1981981981981982, 0.22727272727272727, 'wa <= -0.092\nsquared_error = 0.037\nsamples = 143198\nvalue = 0.733'),
#  Text(0.1969111969111969, 0.13636363636363635, 'wa <= -0.383\nsquared_error = 0.078\nsamples = 9866\nvalue = 0.595'),
#  Text(0.19626769626769627, 0.045454545454545456, 'squared_error = 0.108\nsamples = 1039\nvalue = 0.378'),
#  Text(0.19755469755469757, 0.045454545454545456, 'squared_error = 0.068\nsamples = 8827\nvalue = 0.621'),
#  Text(0.1994851994851995, 0.13636363636363635, 'ta <= 273.589\nsquared_error = 0.033\nsamples = 133332\nvalue = 0.743'),
#  Text(0.19884169884169883, 0.045454545454545456, 'squared_error = 0.032\nsamples = 132305\nvalue = 0.745'),
#  Text(0.20012870012870013, 0.045454545454545456, 'squared_error = 0.037\nsamples = 1027\nvalue = 0.486'),
#  Text(0.20334620334620335, 0.22727272727272727, 'qr+qg+qs <= 0.001\nsquared_error = 0.058\nsamples = 43178\nvalue = 0.637'),
#  Text(0.20205920205920205, 0.13636363636363635, 'wa <= -0.052\nsquared_error = 0.039\nsamples = 38945\nvalue = 0.677'),
#  Text(0.20141570141570142, 0.045454545454545456, 'squared_error = 0.069\nsamples = 2815\nvalue = 0.506'),
#  Text(0.20270270270270271, 0.045454545454545456, 'squared_error = 0.035\nsamples = 36130\nvalue = 0.691'),
#  Text(0.20463320463320464, 0.13636363636363635, 'ta <= 269.879\nsquared_error = 0.08\nsamples = 4233\nvalue = 0.268'),
#  Text(0.20398970398970398, 0.045454545454545456, 'squared_error = 0.041\nsamples = 2505\nvalue = 0.149'),
#  Text(0.20527670527670527, 0.045454545454545456, 'squared_error = 0.085\nsamples = 1728\nvalue = 0.441'),
#  Text(0.22651222651222652, 0.5, 'qr+qg+qs <= 0.001\nsquared_error = 0.092\nsamples = 136030\nvalue = 0.485'),
#  Text(0.21621621621621623, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.078\nsamples = 117947\nvalue = 0.535'),
#  Text(0.21106821106821108, 0.3181818181818182, 'cllvi+clivi <= 0.102\nsquared_error = 0.075\nsamples = 19175\nvalue = 0.321'),
#  Text(0.2084942084942085, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.062\nsamples = 6874\nvalue = 0.449'),
#  Text(0.2072072072072072, 0.13636363636363635, 'ta <= 264.646\nsquared_error = 0.051\nsamples = 2523\nvalue = 0.271'),
#  Text(0.20656370656370657, 0.045454545454545456, 'squared_error = 0.031\nsamples = 884\nvalue = 0.406'),
#  Text(0.20785070785070786, 0.045454545454545456, 'squared_error = 0.046\nsamples = 1639\nvalue = 0.197'),
#  Text(0.2097812097812098, 0.13636363636363635, 'wa <= -0.025\nsquared_error = 0.039\nsamples = 4351\nvalue = 0.553'),
#  Text(0.20913770913770913, 0.045454545454545456, 'squared_error = 0.056\nsamples = 732\nvalue = 0.412'),
#  Text(0.21042471042471042, 0.045454545454545456, 'squared_error = 0.03\nsamples = 3619\nvalue = 0.582'),
#  Text(0.21364221364221364, 0.22727272727272727, 'ta <= 264.87\nsquared_error = 0.067\nsamples = 12301\nvalue = 0.249'),
#  Text(0.21235521235521235, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.053\nsamples = 1624\nvalue = 0.474'),
#  Text(0.21171171171171171, 0.045454545454545456, 'squared_error = 0.04\nsamples = 303\nvalue = 0.302'),
#  Text(0.212998712998713, 0.045454545454545456, 'squared_error = 0.048\nsamples = 1321\nvalue = 0.513'),
#  Text(0.21492921492921493, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.061\nsamples = 10677\nvalue = 0.215'),
#  Text(0.21428571428571427, 0.045454545454545456, 'squared_error = 0.035\nsamples = 3868\nvalue = 0.116'),
#  Text(0.21557271557271557, 0.045454545454545456, 'squared_error = 0.067\nsamples = 6809\nvalue = 0.271'),
#  Text(0.22136422136422138, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.068\nsamples = 98772\nvalue = 0.577'),
#  Text(0.2187902187902188, 0.22727272727272727, 'ta <= 265.577\nsquared_error = 0.055\nsamples = 59353\nvalue = 0.635'),
#  Text(0.2175032175032175, 0.13636363636363635, 'RH <= 97.914\nsquared_error = 0.039\nsamples = 15834\nvalue = 0.743'),
#  Text(0.21685971685971686, 0.045454545454545456, 'squared_error = 0.025\nsamples = 2997\nvalue = 0.85'),
#  Text(0.21814671814671815, 0.045454545454545456, 'squared_error = 0.039\nsamples = 12837\nvalue = 0.717'),
#  Text(0.22007722007722008, 0.13636363636363635, 'cllvi+clivi <= 0.18\nsquared_error = 0.055\nsamples = 43519\nvalue = 0.596'),
#  Text(0.21943371943371942, 0.045454545454545456, 'squared_error = 0.024\nsamples = 10569\nvalue = 0.667'),
#  Text(0.22072072072072071, 0.045454545454545456, 'squared_error = 0.063\nsamples = 32950\nvalue = 0.573'),
#  Text(0.22393822393822393, 0.22727272727272727, 'ta <= 266.616\nsquared_error = 0.076\nsamples = 39419\nvalue = 0.49'),
#  Text(0.22265122265122264, 0.13636363636363635, 'qr+qg+qs <= 0.001\nsquared_error = 0.06\nsamples = 11622\nvalue = 0.591'),
#  Text(0.222007722007722, 0.045454545454545456, 'squared_error = 0.05\nsamples = 10353\nvalue = 0.613'),
#  Text(0.2232947232947233, 0.045454545454545456, 'squared_error = 0.106\nsamples = 1269\nvalue = 0.419'),
#  Text(0.22522522522522523, 0.13636363636363635, 'pfull <= 83701.574\nsquared_error = 0.077\nsamples = 27797\nvalue = 0.447'),
#  Text(0.2245817245817246, 0.045454545454545456, 'squared_error = 0.071\nsamples = 20497\nvalue = 0.482'),
#  Text(0.22586872586872586, 0.045454545454545456, 'squared_error = 0.082\nsamples = 7300\nvalue = 0.349'),
#  Text(0.23680823680823682, 0.4090909090909091, 'pfull <= 49437.539\nsquared_error = 0.057\nsamples = 18083\nvalue = 0.158'),
#  Text(0.23166023166023167, 0.3181818181818182, 'qr+qg+qs <= 0.001\nsquared_error = 0.073\nsamples = 5380\nvalue = 0.292'),
#  Text(0.22908622908622908, 0.22727272727272727, 'wa <= 1.501\nsquared_error = 0.084\nsamples = 2812\nvalue = 0.391'),
#  Text(0.2277992277992278, 0.13636363636363635, 'wa <= 1.192\nsquared_error = 0.056\nsamples = 1057\nvalue = 0.241'),
#  Text(0.22715572715572716, 0.045454545454545456, 'squared_error = 0.039\nsamples = 573\nvalue = 0.17'),
#  Text(0.22844272844272845, 0.045454545454545456, 'squared_error = 0.065\nsamples = 484\nvalue = 0.324'),
#  Text(0.23037323037323038, 0.13636363636363635, 'qr+qg+qs <= 0.001\nsquared_error = 0.079\nsamples = 1755\nvalue = 0.481'),
#  Text(0.22972972972972974, 0.045454545454545456, 'squared_error = 0.068\nsamples = 702\nvalue = 0.6'),
#  Text(0.231016731016731, 0.045454545454545456, 'squared_error = 0.071\nsamples = 1053\nvalue = 0.402'),
#  Text(0.23423423423423423, 0.22727272727272727, 'wa <= 2.419\nsquared_error = 0.038\nsamples = 2568\nvalue = 0.184'),
#  Text(0.23294723294723294, 0.13636363636363635, 'qr+qg+qs <= 0.002\nsquared_error = 0.016\nsamples = 1528\nvalue = 0.101'),
#  Text(0.2323037323037323, 0.045454545454545456, 'squared_error = 0.027\nsamples = 336\nvalue = 0.182'),
#  Text(0.2335907335907336, 0.045454545454545456, 'squared_error = 0.01\nsamples = 1192\nvalue = 0.078'),
#  Text(0.23552123552123552, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.045\nsamples = 1040\nvalue = 0.307'),
#  Text(0.2348777348777349, 0.045454545454545456, 'squared_error = 0.033\nsamples = 593\nvalue = 0.398'),
#  Text(0.23616473616473616, 0.045454545454545456, 'squared_error = 0.036\nsamples = 447\nvalue = 0.186'),
#  Text(0.24195624195624196, 0.3181818181818182, 'hus <= 0.006\nsquared_error = 0.039\nsamples = 12703\nvalue = 0.101'),
#  Text(0.23938223938223938, 0.22727272727272727, 'qr+qg+qs <= 0.001\nsquared_error = 0.03\nsamples = 11810\nvalue = 0.081'),
#  Text(0.23809523809523808, 0.13636363636363635, 'wa <= 0.971\nsquared_error = 0.075\nsamples = 2378\nvalue = 0.206'),
#  Text(0.23745173745173745, 0.045454545454545456, 'squared_error = 0.034\nsamples = 1558\nvalue = 0.101'),
#  Text(0.23873873873873874, 0.045454545454545456, 'squared_error = 0.093\nsamples = 820\nvalue = 0.405'),
#  Text(0.24066924066924067, 0.13636363636363635, 'wa <= 1.895\nsquared_error = 0.014\nsamples = 9432\nvalue = 0.049'),
#  Text(0.24002574002574004, 0.045454545454545456, 'squared_error = 0.01\nsamples = 8414\nvalue = 0.04'),
#  Text(0.2413127413127413, 0.045454545454545456, 'squared_error = 0.038\nsamples = 1018\nvalue = 0.13'),
#  Text(0.24453024453024452, 0.22727272727272727, 'wa <= 1.188\nsquared_error = 0.074\nsamples = 893\nvalue = 0.367'),
#  Text(0.24324324324324326, 0.13636363636363635, 'wa <= -0.679\nsquared_error = 0.077\nsamples = 579\nvalue = 0.277'),
#  Text(0.2425997425997426, 0.045454545454545456, 'squared_error = 0.004\nsamples = 100\nvalue = 0.591'),
#  Text(0.2438867438867439, 0.045454545454545456, 'squared_error = 0.067\nsamples = 479\nvalue = 0.211'),
#  Text(0.24581724581724582, 0.13636363636363635, 'ta <= 270.656\nsquared_error = 0.025\nsamples = 314\nvalue = 0.533'),
#  Text(0.24517374517374518, 0.045454545454545456, 'squared_error = 0.035\nsamples = 62\nvalue = 0.305'),
#  Text(0.24646074646074645, 0.045454545454545456, 'squared_error = 0.007\nsamples = 252\nvalue = 0.589'),
#  Text(0.28430662805662804, 0.5909090909090909, 'clw+cli <= 0.0\nsquared_error = 0.126\nsamples = 137538\nvalue = 0.366'),
#  Text(0.2668114543114543, 0.5, 'qr+qg+qs <= 0.005\nsquared_error = 0.068\nsamples = 77663\nvalue = 0.615'),
#  Text(0.2574002574002574, 0.4090909090909091, 'RH <= 97.827\nsquared_error = 0.042\nsamples = 70924\nvalue = 0.665'),
#  Text(0.25225225225225223, 0.3181818181818182, 'wa <= 0.021\nsquared_error = 0.024\nsamples = 62679\nvalue = 0.697'),
#  Text(0.24967824967824967, 0.22727272727272727, 'cllvi+clivi <= 0.709\nsquared_error = 0.102\nsamples = 760\nvalue = 0.241'),
#  Text(0.2483912483912484, 0.13636363636363635, 'clat <= 0.452\nsquared_error = 0.085\nsamples = 346\nvalue = 0.489'),
#  Text(0.24774774774774774, 0.045454545454545456, 'squared_error = 0.086\nsamples = 249\nvalue = 0.396'),
#  Text(0.24903474903474904, 0.045454545454545456, 'squared_error = 0.003\nsamples = 97\nvalue = 0.727'),
#  Text(0.25096525096525096, 0.13636363636363635, 'hus <= 0.005\nsquared_error = 0.021\nsamples = 414\nvalue = 0.034'),
#  Text(0.2503217503217503, 0.045454545454545456, 'squared_error = 0.106\nsamples = 31\nvalue = 0.44'),
#  Text(0.2516087516087516, 0.045454545454545456, 'squared_error = 0.0\nsamples = 383\nvalue = 0.001'),
#  Text(0.2548262548262548, 0.22727272727272727, 'qr+qg+qs <= 0.004\nsquared_error = 0.021\nsamples = 61919\nvalue = 0.703'),
#  Text(0.25353925353925355, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.016\nsamples = 52467\nvalue = 0.717'),
#  Text(0.2528957528957529, 0.045454545454545456, 'squared_error = 0.012\nsamples = 43646\nvalue = 0.728'),
#  Text(0.25418275418275416, 0.045454545454545456, 'squared_error = 0.036\nsamples = 8821\nvalue = 0.66'),
#  Text(0.25611325611325614, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.036\nsamples = 9452\nvalue = 0.623'),
#  Text(0.2554697554697555, 0.045454545454545456, 'squared_error = 0.021\nsamples = 8097\nvalue = 0.664'),
#  Text(0.25675675675675674, 0.045454545454545456, 'squared_error = 0.057\nsamples = 1355\nvalue = 0.382'),
#  Text(0.2625482625482625, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.112\nsamples = 8245\nvalue = 0.423'),
#  Text(0.25997425997426, 0.22727272727272727, 'qr+qg+qs <= 0.003\nsquared_error = 0.047\nsamples = 5043\nvalue = 0.64'),
#  Text(0.25868725868725867, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.019\nsamples = 3575\nvalue = 0.712'),
#  Text(0.25804375804375806, 0.045454545454545456, 'squared_error = 0.007\nsamples = 2709\nvalue = 0.737'),
#  Text(0.25933075933075933, 0.045454545454545456, 'squared_error = 0.049\nsamples = 866\nvalue = 0.633'),
#  Text(0.26126126126126126, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.073\nsamples = 1468\nvalue = 0.465'),
#  Text(0.2606177606177606, 0.045454545454545456, 'squared_error = 0.034\nsamples = 908\nvalue = 0.591'),
#  Text(0.2619047619047619, 0.045454545454545456, 'squared_error = 0.067\nsamples = 560\nvalue = 0.26'),
#  Text(0.2651222651222651, 0.22727272727272727, 'ta <= 270.164\nsquared_error = 0.021\nsamples = 3202\nvalue = 0.08'),
#  Text(0.26383526383526384, 0.13636363636363635, 'qr+qg+qs <= 0.003\nsquared_error = 0.015\nsamples = 3121\nvalue = 0.068'),
#  Text(0.2631917631917632, 0.045454545454545456, 'squared_error = 0.028\nsamples = 910\nvalue = 0.167'),
#  Text(0.2644787644787645, 0.045454545454545456, 'squared_error = 0.003\nsamples = 2211\nvalue = 0.027'),
#  Text(0.26640926640926643, 0.13636363636363635, 'ta <= 272.889\nsquared_error = 0.042\nsamples = 81\nvalue = 0.562'),
#  Text(0.26576576576576577, 0.045454545454545456, 'squared_error = 0.01\nsamples = 47\nvalue = 0.705'),
#  Text(0.26705276705276704, 0.045454545454545456, 'squared_error = 0.02\nsamples = 34\nvalue = 0.366'),
#  Text(0.2762226512226512, 0.4090909090909091, 'cllvi+clivi <= 0.63\nsquared_error = 0.033\nsamples = 6739\nvalue = 0.086'),
#  Text(0.27187902187902185, 0.3181818181818182, 'RH <= 97.451\nsquared_error = 0.055\nsamples = 1053\nvalue = 0.411'),
# ...
#  Text(0.5334620334620335, 0.045454545454545456, 'squared_error = 0.007\nsamples = 20759\nvalue = 0.018'),
#  Text(0.5366795366795367, 0.22727272727272727, 'pfull <= 76600.207\nsquared_error = 0.028\nsamples = 6720\nvalue = 0.115'),
#  Text(0.5353925353925354, 0.13636363636363635, 'clw+cli <= 0.001\nsquared_error = 0.031\nsamples = 4133\nvalue = 0.158'),
#  Text(0.5347490347490348, 0.045454545454545456, 'squared_error = 0.034\nsamples = 1811\nvalue = 0.239'),
#  Text(0.536036036036036, 0.045454545454545456, 'squared_error = 0.019\nsamples = 2322\nvalue = 0.096'),
#  Text(0.5379665379665379, 0.13636363636363635, 'wa <= 1.287\nsquared_error = 0.016\nsamples = 2587\nvalue = 0.047'),
#  Text(0.5373230373230373, 0.045454545454545456, 'squared_error = 0.014\nsamples = 2533\nvalue = 0.042'),
#  Text(0.5386100386100386, 0.045454545454545456, 'squared_error = 0.061\nsamples = 54\nvalue = 0.256'),
#  Text(0.5600466537966537, 0.5909090909090909, 'cllvi+clivi <= 0.57\nsquared_error = 0.013\nsamples = 109634\nvalue = 0.035'),
#  Text(0.5451254826254827, 0.5, 'cllvi+clivi <= 0.31\nsquared_error = 0.068\nsamples = 1881\nvalue = 0.257'),
#  Text(0.5398970398970399, 0.4090909090909091, 'pfull <= 39663.762\nsquared_error = 0.066\nsamples = 158\nvalue = 0.602'),
#  Text(0.5386100386100386, 0.3181818181818182, 'ua <= 2.287\nsquared_error = 0.031\nsamples = 83\nvalue = 0.725'),
#  Text(0.5379665379665379, 0.22727272727272727, 'squared_error = 0.011\nsamples = 44\nvalue = 0.799'),
#  Text(0.5392535392535392, 0.22727272727272727, 'squared_error = 0.041\nsamples = 39\nvalue = 0.64'),
#  Text(0.5411840411840412, 0.3181818181818182, 'clat <= -0.145\nsquared_error = 0.068\nsamples = 75\nvalue = 0.466'),
#  Text(0.5405405405405406, 0.22727272727272727, 'squared_error = 0.07\nsamples = 30\nvalue = 0.312'),
#  Text(0.5418275418275418, 0.22727272727272727, 'squared_error = 0.041\nsamples = 45\nvalue = 0.569'),
#  Text(0.5503539253539254, 0.4090909090909091, 'pfull <= 46782.387\nsquared_error = 0.056\nsamples = 1723\nvalue = 0.225'),
#  Text(0.5456885456885456, 0.3181818181818182, 'qr+qg+qs <= 0.001\nsquared_error = 0.062\nsamples = 989\nvalue = 0.292'),
#  Text(0.5431145431145431, 0.22727272727272727, 'clon <= 1.069\nsquared_error = 0.065\nsamples = 648\nvalue = 0.363'),
#  Text(0.5418275418275418, 0.13636363636363635, 'cllvi+clivi <= 0.329\nsquared_error = 0.053\nsamples = 406\nvalue = 0.3'),
#  Text(0.5411840411840412, 0.045454545454545456, 'squared_error = 0.023\nsamples = 34\nvalue = 0.582'),
#  Text(0.5424710424710425, 0.045454545454545456, 'squared_error = 0.047\nsamples = 372\nvalue = 0.274'),
#  Text(0.5444015444015444, 0.13636363636363635, 'pfull <= 39665.906\nsquared_error = 0.068\nsamples = 242\nvalue = 0.469'),
#  Text(0.5437580437580437, 0.045454545454545456, 'squared_error = 0.047\nsamples = 120\nvalue = 0.598'),
#  Text(0.545045045045045, 0.045454545454545456, 'squared_error = 0.057\nsamples = 122\nvalue = 0.342'),
#  Text(0.5482625482625483, 0.22727272727272727, 'cllvi+clivi <= 0.464\nsquared_error = 0.028\nsamples = 341\nvalue = 0.156'),
#  Text(0.546975546975547, 0.13636363636363635, 'ta <= 248.198\nsquared_error = 0.06\nsamples = 69\nvalue = 0.331'),
#  Text(0.5463320463320464, 0.045454545454545456, 'squared_error = 0.044\nsamples = 34\nvalue = 0.418'),
#  Text(0.5476190476190477, 0.045454545454545456, 'squared_error = 0.061\nsamples = 35\nvalue = 0.247'),
#  Text(0.5495495495495496, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.01\nsamples = 272\nvalue = 0.112'),
#  Text(0.5489060489060489, 0.045454545454545456, 'squared_error = 0.009\nsamples = 167\nvalue = 0.145'),
#  Text(0.5501930501930502, 0.045454545454545456, 'squared_error = 0.006\nsamples = 105\nvalue = 0.06'),
#  Text(0.555019305019305, 0.3181818181818182, 'ta <= 273.121\nsquared_error = 0.035\nsamples = 734\nvalue = 0.135'),
#  Text(0.5534105534105535, 0.22727272727272727, 'va <= 4.872\nsquared_error = 0.027\nsamples = 663\nvalue = 0.113'),
#  Text(0.5521235521235521, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.022\nsamples = 567\nvalue = 0.093'),
#  Text(0.5514800514800515, 0.045454545454545456, 'squared_error = 0.019\nsamples = 535\nvalue = 0.083'),
#  Text(0.5527670527670527, 0.045454545454545456, 'squared_error = 0.047\nsamples = 32\nvalue = 0.254'),
#  Text(0.5546975546975547, 0.13636363636363635, 'RH <= 98.868\nsquared_error = 0.043\nsamples = 96\nvalue = 0.232'),
#  Text(0.5540540540540541, 0.045454545454545456, 'squared_error = 0.031\nsamples = 59\nvalue = 0.133'),
#  Text(0.5553410553410554, 0.045454545454545456, 'squared_error = 0.022\nsamples = 37\nvalue = 0.389'),
#  Text(0.5566280566280566, 0.22727272727272727, 'wa <= 0.661\nsquared_error = 0.059\nsamples = 71\nvalue = 0.338'),
#  Text(0.555984555984556, 0.13636363636363635, 'squared_error = 0.056\nsamples = 38\nvalue = 0.189'),
#  Text(0.5572715572715573, 0.13636363636363635, 'squared_error = 0.008\nsamples = 33\nvalue = 0.51'),
#  Text(0.574967824967825, 0.5, 'hus <= 0.003\nsquared_error = 0.011\nsamples = 107753\nvalue = 0.031'),
#  Text(0.5661196911196911, 0.4090909090909091, 'qr+qg+qs <= 0.001\nsquared_error = 0.022\nsamples = 21124\nvalue = 0.078'),
#  Text(0.5620978120978121, 0.3181818181818182, 'ta <= 243.839\nsquared_error = 0.046\nsamples = 6862\nvalue = 0.174'),
#  Text(0.5598455598455598, 0.22727272727272727, 'qr+qg+qs <= 0.001\nsquared_error = 0.047\nsamples = 3586\nvalue = 0.228'),
#  Text(0.5585585585585585, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.065\nsamples = 1109\nvalue = 0.346'),
#  Text(0.5579150579150579, 0.045454545454545456, 'squared_error = 0.083\nsamples = 482\nvalue = 0.437'),
#  Text(0.5592020592020592, 0.045454545454545456, 'squared_error = 0.04\nsamples = 627\nvalue = 0.276'),
#  Text(0.5611325611325612, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.029\nsamples = 2477\nvalue = 0.175'),
#  Text(0.5604890604890604, 0.045454545454545456, 'squared_error = 0.054\nsamples = 664\nvalue = 0.248'),
#  Text(0.5617760617760618, 0.045454545454545456, 'squared_error = 0.018\nsamples = 1813\nvalue = 0.148'),
#  Text(0.5643500643500643, 0.22727272727272727, 'RH <= 98.663\nsquared_error = 0.039\nsamples = 3276\nvalue = 0.115'),
#  Text(0.5637065637065637, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.034\nsamples = 3221\nvalue = 0.107'),
#  Text(0.5630630630630631, 0.045454545454545456, 'squared_error = 0.082\nsamples = 340\nvalue = 0.238'),
#  Text(0.5643500643500643, 0.045454545454545456, 'squared_error = 0.026\nsamples = 2881\nvalue = 0.091'),
#  Text(0.564993564993565, 0.13636363636363635, 'squared_error = 0.071\nsamples = 55\nvalue = 0.606'),
#  Text(0.5701415701415702, 0.3181818181818182, 'qr+qg+qs <= 0.002\nsquared_error = 0.004\nsamples = 14262\nvalue = 0.032'),
#  Text(0.5675675675675675, 0.22727272727272727, 'RH <= 97.163\nsquared_error = 0.009\nsamples = 4629\nvalue = 0.067'),
#  Text(0.5662805662805663, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.011\nsamples = 3222\nvalue = 0.083'),
#  Text(0.5656370656370656, 0.045454545454545456, 'squared_error = 0.019\nsamples = 824\nvalue = 0.133'),
#  Text(0.5669240669240669, 0.045454545454545456, 'squared_error = 0.007\nsamples = 2398\nvalue = 0.065'),
#  Text(0.5688545688545689, 0.13636363636363635, 'cllvi+clivi <= 0.948\nsquared_error = 0.003\nsamples = 1407\nvalue = 0.031'),
#  Text(0.5682110682110683, 0.045454545454545456, 'squared_error = 0.007\nsamples = 245\nvalue = 0.069'),
#  Text(0.5694980694980695, 0.045454545454545456, 'squared_error = 0.002\nsamples = 1162\nvalue = 0.023'),
#  Text(0.5727155727155727, 0.22727272727272727, 'qr+qg+qs <= 0.003\nsquared_error = 0.001\nsamples = 9633\nvalue = 0.015'),
#  Text(0.5714285714285714, 0.13636363636363635, 'RH <= 82.259\nsquared_error = 0.002\nsamples = 4113\nvalue = 0.025'),
#  Text(0.5707850707850708, 0.045454545454545456, 'squared_error = 0.001\nsamples = 279\nvalue = 0.074'),
#  Text(0.5720720720720721, 0.045454545454545456, 'squared_error = 0.002\nsamples = 3834\nvalue = 0.022'),
#  Text(0.574002574002574, 0.13636363636363635, 'RH <= 81.137\nsquared_error = 0.0\nsamples = 5520\nvalue = 0.007'),
#  Text(0.5733590733590733, 0.045454545454545456, 'squared_error = 0.001\nsamples = 184\nvalue = 0.036'),
#  Text(0.5746460746460746, 0.045454545454545456, 'squared_error = 0.0\nsamples = 5336\nvalue = 0.006'),
#  Text(0.5838159588159588, 0.4090909090909091, 'ta <= 273.382\nsquared_error = 0.007\nsamples = 86629\nvalue = 0.02'),
#  Text(0.5794723294723295, 0.3181818181818182, 'qr+qg+qs <= 0.001\nsquared_error = 0.006\nsamples = 84897\nvalue = 0.018'),
#  Text(0.5778635778635779, 0.22727272727272727, 'RH <= 98.414\nsquared_error = 0.014\nsamples = 25902\nvalue = 0.034'),
#  Text(0.5765765765765766, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.027\nsamples = 4346\nvalue = 0.079'),
#  Text(0.575933075933076, 0.045454545454545456, 'squared_error = 0.051\nsamples = 930\nvalue = 0.188'),
#  Text(0.5772200772200772, 0.045454545454545456, 'squared_error = 0.016\nsamples = 3416\nvalue = 0.049'),
#  Text(0.5791505791505791, 0.13636363636363635, 'RH <= 99.493\nsquared_error = 0.01\nsamples = 21556\nvalue = 0.025'),
#  Text(0.5785070785070785, 0.045454545454545456, 'squared_error = 0.01\nsamples = 21437\nvalue = 0.023'),
#  Text(0.5797940797940798, 0.045454545454545456, 'squared_error = 0.105\nsamples = 119\nvalue = 0.259'),
#  Text(0.581081081081081, 0.22727272727272727, 'RH <= 96.237\nsquared_error = 0.003\nsamples = 58995\nvalue = 0.011'),
#  Text(0.5804375804375804, 0.13636363636363635, 'squared_error = 0.098\nsamples = 57\nvalue = 0.332'),
#  Text(0.5817245817245817, 0.13636363636363635, 'cllvi+clivi <= 0.856\nsquared_error = 0.003\nsamples = 58938\nvalue = 0.01'),
#  Text(0.581081081081081, 0.045454545454545456, 'squared_error = 0.01\nsamples = 1330\nvalue = 0.055'),
#  Text(0.5823680823680824, 0.045454545454545456, 'squared_error = 0.002\nsamples = 57608\nvalue = 0.009'),
#  Text(0.5881595881595881, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.048\nsamples = 1732\nvalue = 0.145'),
#  Text(0.5855855855855856, 0.22727272727272727, 'wa <= 0.97\nsquared_error = 0.063\nsamples = 774\nvalue = 0.244'),
#  Text(0.5842985842985843, 0.13636363636363635, 'qr+qg+qs <= 0.001\nsquared_error = 0.033\nsamples = 344\nvalue = 0.107'),
#  Text(0.5836550836550837, 0.045454545454545456, 'squared_error = 0.041\nsamples = 149\nvalue = 0.245'),
#  Text(0.584942084942085, 0.045454545454545456, 'squared_error = 0.0\nsamples = 195\nvalue = 0.001'),
#  Text(0.5868725868725869, 0.13636363636363635, 'qr+qg+qs <= 0.002\nsquared_error = 0.061\nsamples = 430\nvalue = 0.354'),
#  Text(0.5862290862290862, 0.045454545454545456, 'squared_error = 0.023\nsamples = 297\nvalue = 0.49'),
#  Text(0.5875160875160875, 0.045454545454545456, 'squared_error = 0.01\nsamples = 133\nvalue = 0.05'),
#  Text(0.5907335907335908, 0.22727272727272727, 'pfull <= 64297.914\nsquared_error = 0.021\nsamples = 958\nvalue = 0.065'),
#  Text(0.5894465894465895, 0.13636363636363635, 'clw+cli <= 0.001\nsquared_error = 0.029\nsamples = 269\nvalue = 0.136'),
#  Text(0.5888030888030888, 0.045454545454545456, 'squared_error = 0.034\nsamples = 154\nvalue = 0.202'),
#  Text(0.5900900900900901, 0.045454545454545456, 'squared_error = 0.009\nsamples = 115\nvalue = 0.047'),
#  Text(0.592020592020592, 0.13636363636363635, 'qr+qg+qs <= 0.001\nsquared_error = 0.016\nsamples = 689\nvalue = 0.038'),
#  Text(0.5913770913770914, 0.045454545454545456, 'squared_error = 0.057\nsamples = 53\nvalue = 0.174'),
#  Text(0.5926640926640927, 0.045454545454545456, 'squared_error = 0.01\nsamples = 636\nvalue = 0.026'),
#  Text(0.7884743001930502, 0.8636363636363636, 'ta <= 275.389\nsquared_error = 0.009\nsamples = 1504597\nvalue = 0.02'),
#  Text(0.669142635939511, 0.9090909090909092, '  False'),
#  Text(0.6916324806949807, 0.7727272727272727, 'RH <= 92.697\nsquared_error = 0.073\nsamples = 81030\nvalue = 0.251'),
#  Text(0.6401423745173745, 0.6818181818181818, 'cllvi+clivi <= 0.317\nsquared_error = 0.122\nsamples = 10480\nvalue = 0.639'),
#  Text(0.6201335263835264, 0.5909090909090909, 'RH <= 83.554\nsquared_error = 0.092\nsamples = 8292\nvalue = 0.693'),
#  Text(0.6062580437580437, 0.5, 'clon <= -2.349\nsquared_error = 0.089\nsamples = 5208\nvalue = 0.75'),
#  Text(0.5986164736164736, 0.4090909090909091, 'clat <= 0.547\nsquared_error = 0.049\nsamples = 1254\nvalue = 0.861'),
#  Text(0.5955598455598455, 0.3181818181818182, 'wa <= -0.547\nsquared_error = 0.032\nsamples = 944\nvalue = 0.906'),
#  Text(0.5939510939510939, 0.22727272727272727, 'ta <= 274.506\nsquared_error = 0.085\nsamples = 60\nvalue = 0.727'),
#  Text(0.5933075933075933, 0.13636363636363635, 'squared_error = 0.007\nsamples = 30\nvalue = 0.857'),
#  Text(0.5945945945945946, 0.13636363636363635, 'squared_error = 0.129\nsamples = 30\nvalue = 0.597'),
#  Text(0.5971685971685972, 0.22727272727272727, 'hus <= 0.005\nsquared_error = 0.027\nsamples = 884\nvalue = 0.918'),
#  Text(0.5958815958815958, 0.13636363636363635, 'clon <= -2.95\nsquared_error = 0.024\nsamples = 755\nvalue = 0.936'),
#  Text(0.5952380952380952, 0.045454545454545456, 'squared_error = 0.085\nsamples = 81\nvalue = 0.811'),
#  Text(0.5965250965250966, 0.045454545454545456, 'squared_error = 0.014\nsamples = 674\nvalue = 0.951'),
#  Text(0.5984555984555985, 0.13636363636363635, 'va <= 1.362\nsquared_error = 0.032\nsamples = 129\nvalue = 0.817'),
#  Text(0.5978120978120978, 0.045454545454545456, 'squared_error = 0.042\nsamples = 44\nvalue = 0.704'),
#  Text(0.5990990990990991, 0.045454545454545456, 'squared_error = 0.016\nsamples = 85\nvalue = 0.876'),
#  Text(0.6016731016731016, 0.3181818181818182, 'cllvi+clivi <= 0.14\nsquared_error = 0.076\nsamples = 310\nvalue = 0.725'),
#  Text(0.6003861003861004, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.037\nsamples = 245\nvalue = 0.783'),
#  Text(0.5997425997425997, 0.13636363636363635, 'squared_error = 0.134\nsamples = 30\nvalue = 0.627'),
#  Text(0.601029601029601, 0.13636363636363635, 'clat <= 0.595\nsquared_error = 0.019\nsamples = 215\nvalue = 0.805'),
#  Text(0.6003861003861004, 0.045454545454545456, 'squared_error = 0.012\nsamples = 31\nvalue = 0.7'),
#  Text(0.6016731016731016, 0.045454545454545456, 'squared_error = 0.019\nsamples = 184\nvalue = 0.823'),
#  Text(0.6029601029601029, 0.22727272727272727, 'clon <= -2.946\nsquared_error = 0.161\nsamples = 65\nvalue = 0.504'),
#  Text(0.6023166023166023, 0.13636363636363635, 'squared_error = 0.074\nsamples = 35\nvalue = 0.258'),
#  Text(0.6036036036036037, 0.13636363636363635, 'squared_error = 0.109\nsamples = 30\nvalue = 0.791'),
#  Text(0.6138996138996139, 0.4090909090909091, 'pfull <= 65117.652\nsquared_error = 0.096\nsamples = 3954\nvalue = 0.715'),
#  Text(0.6087516087516087, 0.3181818181818182, 'cllvi+clivi <= 0.116\nsquared_error = 0.103\nsamples = 1978\nvalue = 0.636'),
#  Text(0.6061776061776062, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.064\nsamples = 1287\nvalue = 0.734'),
#  Text(0.6048906048906049, 0.13636363636363635, 'clon <= -1.234\nsquared_error = 0.049\nsamples = 893\nvalue = 0.771'),
#  Text(0.6042471042471043, 0.045454545454545456, 'squared_error = 0.066\nsamples = 336\nvalue = 0.701'),
#  Text(0.6055341055341056, 0.045454545454545456, 'squared_error = 0.035\nsamples = 557\nvalue = 0.812'),
#  Text(0.6074646074646075, 0.13636363636363635, 'wa <= -0.148\nsquared_error = 0.088\nsamples = 394\nvalue = 0.652'),
#  Text(0.6068211068211068, 0.045454545454545456, 'squared_error = 0.059\nsamples = 258\nvalue = 0.697'),
#  Text(0.6081081081081081, 0.045454545454545456, 'squared_error = 0.132\nsamples = 136\nvalue = 0.566'),
#  Text(0.6113256113256114, 0.22727272727272727, 'clon <= -1.293\nsquared_error = 0.124\nsamples = 691\nvalue = 0.452'),
#  Text(0.61003861003861, 0.13636363636363635, 'cllvi+clivi <= 0.192\nsquared_error = 0.098\nsamples = 301\nvalue = 0.319'),
#  Text(0.6093951093951094, 0.045454545454545456, 'squared_error = 0.089\nsamples = 147\nvalue = 0.469'),
#  Text(0.6106821106821106, 0.045454545454545456, 'squared_error = 0.065\nsamples = 154\nvalue = 0.176'),
#  Text(0.6126126126126126, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.119\nsamples = 390\nvalue = 0.554'),
#  ...]

# %%
#Prediction
prediction_start_time = time.time()
y_pred = reg.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
# Out:
# Prediction- Elapsed time: 0.0016 minutes

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
#Error Analysis on TEST data
#MSE_test
mse_TEST= np.mean((y_test- y_pred)**2)
print(f'MSE_TEST: {mse_TEST}')

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')
# print(f'MSE_TEST: {(rmse_TEST)**2}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score before CCP:", r2_sklearn)
# Out:
# MSE_TEST: 0.015856987083944535
# RMSE_TEST: 0.1259245293179392
# mae_TEST: 0.06169220344035019
# R² score before CCP: 0.913114338741112

# %%
# #Pathway-1
# #This seems more robust because it uses CV and not test data to determine the best ccp_alpha

# ccp_path = reg.cost_complexity_pruning_path(X_train, y_train)

# kfold = skm.KFold(5,
# shuffle=True,
# random_state=10)

# grid = skm.GridSearchCV(reg,
# {'ccp_alpha': ccp_path.ccp_alphas},
# refit=True,
# cv=kfold,
# scoring='r2',
# n_jobs=-1)

# G = grid.fit(X_train, y_train)

# best_ = grid.best_estimator_
# print(best_)

# depth = best_.get_depth()
# print(depth)

# %%
# #Pathway-1
# #Plot the best tree
# ax= subplots(figsize=(12,12))[1]
# plot_tree(G.best_estimator_, feature_names=feature_names, ax=ax) #after ccp

# %%
# # ##Prediction
# prediction_start_time = time.time()
# y_pred = best_.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# #########################################
# print('size of y_pred: ', len(y_pred))

# %%
# #Comment this block if you do CCP

# ##Prediction
# prediction_start_time = time.time()
# y_pred = reg.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# #########################################
# print('size of y_pred: ', len(y_pred))

# %%
# #Error Analysis on TEST data
# #MSE_test
# mse_TEST= np.mean((y_test- y_pred)**2)
# print(f'MSE_TEST: {mse_TEST}')

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
# print(f'RMSE_TEST: {rmse_TEST}')
# # print(f'MSE_TEST: {(rmse_TEST)**2}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_pred))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_pred)
# print("R² score:", r2_sklearn)

# %%
# #If CCP:

# # # #DT-feature importances in descending order
# # importance = best_.feature_importances_
# # feature_scores= list(zip(feature_names, importance))
# # feature_scores.sort(key=lambda x: x[1], reverse= True)
# for name, score in feature_scores:
#     pct = score*100
#     print(f'{name}:{pct:.4f} %')

# If no CCP:
## DT-feature importances in descending order
importance = reg.feature_importances_
feature_scores= list(zip(feature_names, importance))
feature_scores.sort(key=lambda x: x[1], reverse= True)
for name, score in feature_scores:
    pct = score*100
    print(f'{name}:{pct:.4f} %')
# Out:
# ta:71.8372 %
# clw+cli:15.7459 %
# RH:6.1959 %
# qr+qg+qs:4.4010 %
# cllvi+clivi:0.9476 %
# hus:0.3401 %
# pfull:0.2335 %
# wa:0.1619 %
# clat:0.0710 %
# clon:0.0551 %
# ua:0.0077 %
# va:0.0031 %

# %%
import matplotlib.pyplot as plt

# Your existing logic
importance = reg.feature_importances_
feature_scores = list(zip(feature_names, importance))
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f'{name}:{pct:.4f} %')

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Snow\ fraction}$ determination using $\mathbf{Decision\ Tree}$")


# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of each bar
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,   # small space after bar
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis from 0 to 100
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# ta:71.8372 %
# clw+cli:15.7459 %
# RH:6.1959 %
# qr+qg+qs:4.4010 %
# cllvi+clivi:0.9476 %
# hus:0.3401 %
# pfull:0.2335 %
# wa:0.1619 %
# clat:0.0710 %
# clon:0.0551 %
# ua:0.0077 %
# va:0.0031 %

# %%
# best_ccp_alpha= best_.ccp_alpha
# best_ccp_alpha

# %% [markdown]
# Bagging

# %%
#expt with min_sample_leaf = 50, etc.

# %%
# #for loop to see at what n_estimators the validation error converges

# X_train_sub, X_val, y_train_sub, y_val=train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# prev_validation_r2_score=0 #Initialized arbitrarily to 0 to run the first tree in the for loop 
# diff=1 # difference between R2 scores of the previous and the current tree. Initialized arbitrarily to 1 to run the first tree in the for loop 
# upper_bound_n_trees=201
# x_axis= range(1,upper_bound_n_trees)
# threshold= 1E-7 ###1E-7
# train_sub_r2_scores=[]
# validation_r2_scores=[]
# for n_trees in x_axis:
        
#         # print("Diff= ", diff)
#         if(diff<threshold):
#                 print(f"Converged at {n_trees-1} trees")
#                 ideal_n_trees= n_trees-1
#                 break


#         #Bagging
#         model = RandomForestRegressor(n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf ,n_estimators=n_trees, oob_score=True) #can set verbose=2 to see the steps 

#         ##Training
#         model.fit(X_train_sub, y_train_sub)

#         train_sub_r2= model.score(X_train_sub, y_train_sub)
#         validation_r2 = model.score(X_val, y_val)

#         train_sub_r2_scores.append(train_sub_r2)
#         validation_r2_scores.append(validation_r2)

#         diff= abs(validation_r2 - prev_validation_r2_score)
#         prev_validation_r2_score=validation_r2

# n_trees_for_which_max_r2 = x_axis[validation_r2_scores.index(max(validation_r2_scores))]


# print(f"Best number of trees (based on validation data): {n_trees_for_which_max_r2}")
# print(f"Best validation R² score: {max(validation_r2_scores)}")

# if(diff>=threshold):
#                 ideal_n_trees= upper_bound_n_trees-1

# plt.figure(figsize=(8,5))
# plt.plot(range(1, len(train_sub_r2_scores)+1 ), train_sub_r2_scores, marker='o', label='Training R2')
# plt.plot(range(1, len(validation_r2_scores)+1 ), validation_r2_scores, marker='s', label='Validation R2')
# plt.xlabel('Number of Trees')
# plt.ylabel('R2 Score')
# plt.title('R2 score vs number of trees')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
#Bagging
ideal_n_trees=100
model = RandomForestRegressor(n_jobs=-1, random_state=0, max_depth=best_depth, n_estimators=ideal_n_trees, oob_score=True, min_samples_leaf=best_min_samples_leaf) #can set verbose=2 to see the steps 

##Training
training_start_time = time.time()
model.fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

##Prediction
prediction_start_time = time.time()
y_pred = model.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
 

#Error Analysis on TEST data
#MSE_test
MSE_Test = np.mean((y_test - y_pred)**2)
print(f'MSE_Test: {MSE_Test}')

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score (sklearn):", r2_sklearn)
# Out:
# Training- Elapsed time: 7.1943 minutes
# Prediction- Elapsed time: 0.0068 minutes
# MSE_Test: 0.015067023571432178
# RMSE_TEST: 0.12274780475198804
# mae_TEST: 0.06053622245525163
# R² score (sklearn): 0.9174428093258251

# %%
#Bagging ft. importance in descending order
#Sort indices by importance
sorted_idx = np.argsort(model.feature_importances_)[::-1]

#print("\nAll features sorted by importance:")
for i in sorted_idx:
    pct=model.feature_importances_[i] * 100
    print(f"{feature_names[i]}: {pct:.4f} %")
# Out:
# ta: 71.8451 %
# clw+cli: 15.6833 %
# RH: 6.1969 %
# qr+qg+qs: 4.4085 %
# cllvi+clivi: 0.9550 %
# hus: 0.3420 %
# pfull: 0.2447 %
# wa: 0.1785 %
# clat: 0.0694 %
# clon: 0.0626 %
# ua: 0.0071 %
# va: 0.0069 %

# %%
sorted_idx = np.argsort(model.feature_importances_)[::-1]

names = []
importances = []

for i in sorted_idx:
    pct = model.feature_importances_[i] * 100
    names.append(feature_names[i])
    importances.append(pct)
    print(f"{feature_names[i]}: {pct:.4f} %")

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Snow\ fraction}$ determination using $\mathbf{Bagging}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of bars
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis from 0 to 100
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# ta: 71.8451 %
# clw+cli: 15.6833 %
# RH: 6.1969 %
# qr+qg+qs: 4.4085 %
# cllvi+clivi: 0.9550 %
# hus: 0.3420 %
# pfull: 0.2447 %
# wa: 0.1785 %
# clat: 0.0694 %
# clon: 0.0626 %
# ua: 0.0071 %
# va: 0.0069 %

# %%
# # Bagging with CCP

# ideal_n_trees=100
# #I am using the best_ccp_alpha I got from a single Decision Tree using CV
# model = RandomForestRegressor(ccp_alpha=best_ccp_alpha, n_jobs=-1, random_state=0, max_depth=best_depth, n_estimators=ideal_n_trees, oob_score=True, min_samples_leaf=best_min_samples_leaf) #can set verbose=2 to see the steps 

# ##Training
# training_start_time = time.time()
# model.fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

# ##Prediction
# prediction_start_time = time.time()
# y_pred = model.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
 

# #Error Analysis on TEST data
# #MSE_test
# MSE_Test = np.mean((y_test - y_pred)**2)
# print(f'MSE_Test: {MSE_Test}')

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_pred))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_pred)
# print("R² score (sklearn):", r2_sklearn)

# %%
# #Bagging ft. importance in descending order
# #Sort indices by importance
# sorted_idx = np.argsort(model.feature_importances_)[::-1]

# #print("\nAll features sorted by importance:")
# for i in sorted_idx:
#     print(f"{feature_names[i]}: {model.feature_importances_[i]:.4f}")

# %% [markdown]
# Random Forest

# %% [markdown]
# #Bagging Code 2

# %% [markdown]
# Random Forest

# %%
# #ideal num of trees for Random Forest
# #for loop to see at what n_estimators the validation error converges

# X_train_sub, X_val, y_train_sub, y_val=train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# prev_validation_r2_score=0 #Initialized arbitrarily to 0 to run the first tree in the for loop 
# diff=1 # difference between R2 scores of the previous and the current tree. Initialized arbitrarily to 1 to run the first tree in the for loop 
# upper_bound_n_trees=201
# x_axis= range(1,upper_bound_n_trees)
# threshold= 1E-7 #1E-7
# train_sub_r2_scores=[]
# validation_r2_scores=[]
# for n_trees in x_axis:
        
#         # print("Diff= ", diff)
#         if(diff<threshold):
#                 print(f"Converged at {n_trees-1} trees")
#                 ideal_n_trees= n_trees-1
#                 break


#         #Bagging
#         model = RandomForestRegressor(n_jobs=-1, random_state=0, max_features=int(np.sqrt(X_train.shape[1])), max_depth=best_depth, min_samples_leaf=best_min_samples_leaf ,n_estimators=n_trees, oob_score=True) #can set verbose=2 to see the steps 

#         ##Training
#         model.fit(X_train_sub, y_train_sub)

#         train_sub_r2= model.score(X_train_sub, y_train_sub)
#         validation_r2 = model.score(X_val, y_val)

#         train_sub_r2_scores.append(train_sub_r2)
#         validation_r2_scores.append(validation_r2)

#         diff= abs(validation_r2 - prev_validation_r2_score)
#         prev_validation_r2_score=validation_r2

# n_trees_for_which_max_r2 = x_axis[validation_r2_scores.index(max(validation_r2_scores))]


# print(f"Best number of trees (based on validation data): {n_trees_for_which_max_r2}")
# print(f"Best validation R² score: {max(validation_r2_scores)}")

# if(diff>=threshold):
#                 ideal_n_trees= upper_bound_n_trees-1

# plt.figure(figsize=(8,5))
# plt.plot(range(1, len(train_sub_r2_scores)+1 ), train_sub_r2_scores, marker='o', label='Training R2')
# plt.plot(range(1, len(validation_r2_scores)+1 ), validation_r2_scores, marker='s', label='Validation R2')
# plt.xlabel('Number of Trees')
# plt.ylabel('R2 Score')
# plt.title('R2 score vs number of trees')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
#Random Forest
##Training
ideal_n_trees=100

training_start_time = time.time()
RF_condensates = RandomForestRegressor(n_estimators=ideal_n_trees, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
#RF_condensates = RandomForestRegressor(n_estimators=ideal_n_trees, max_features=int( np.floor(0.75 * X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
# RF_condensates = RF(n_estimators=200, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, oob_score=True).fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

##Prediction
prediction_start_time = time.time()
y_hat_RF = RF_condensates.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

print("max: ", np.max(y_hat_RF))
print("min: ", np.min(y_hat_RF))
# Out:
# Training- Elapsed time: 1.8240 minutes
# Prediction- Elapsed time: 0.0058 minutes
# max:  0.9835827151692927
# min:  8.832648708876055e-06

# %%
int( np.floor(0.75 * X_train.shape[1]))
# Out:
# 9

# %%
int(np.sqrt(X_train.shape[1]))
# Out:
# 3

# %%
RF_condensates
# Out:
# RandomForestRegressor(max_depth=10, max_features=3, min_samples_leaf=30,
#                       n_jobs=-1, oob_score=True, random_state=0)

# %%
# List of depths for all trees
tree_depths = [estimator.tree_.max_depth for estimator in RF_condensates.estimators_]

# Average, min, and max depth across the forest
print("Average depth:", sum(tree_depths) / len(tree_depths))
print("Min depth:", min(tree_depths))
print("Max depth:", max(tree_depths))
# Out:
# Average depth: 10.0
# Min depth: 10
# Max depth: 10

# %%
#Error Analysis on TEST data
#mse_Test
mse= np.mean((y_test- y_hat_RF)**2)
print('MSE: ', mse)

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_hat_RF)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_hat_RF))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_hat_RF)
print("R² score: ", r2_sklearn)
# Out:
# MSE:  0.01507051151159176
# RMSE_TEST: 0.12276201167947583
# mae_TEST: 0.06530242206030021
# R² score:  0.917423697751502

# %%
#RF Ft. importance in descending order
importance = RF_condensates.feature_importances_

#Combine ft. names and scores
feature_scores = list(zip(feature_names, importance))

#Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

for name, score in feature_scores:
    pct= score *100
    print(f'{name}:{pct:.4f} %')
# Out:
# ta:27.0976 %
# hus:19.8820 %
# RH:17.4554 %
# clw+cli:14.1935 %
# cllvi+clivi:9.4329 %
# pfull:6.1183 %
# qr+qg+qs:2.7937 %
# wa:1.2951 %
# clat:1.0700 %
# ua:0.2927 %
# clon:0.2632 %
# va:0.1057 %

# %%
importance = RF_condensates.feature_importances_

# Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

# Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Snow\ fraction}$ determination using $\mathbf{Random\ Forest}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of the bars
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis range from 0 to 100
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# ta: 27.0976 %
# hus: 19.8820 %
# RH: 17.4554 %
# clw+cli: 14.1935 %
# cllvi+clivi: 9.4329 %
# pfull: 6.1183 %
# qr+qg+qs: 2.7937 %
# wa: 1.2951 %
# clat: 1.0700 %
# ua: 0.2927 %
# clon: 0.2632 %
# va: 0.1057 %

# %%
# #Random Forest with CCP

# ##Training
# ideal_n_trees=100

# training_start_time = time.time()
# RF_condensates = RandomForestRegressor(ccp_alpha= best_ccp_alpha, n_estimators=ideal_n_trees, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
# #RF_condensates = RandomForestRegressor(n_estimators=ideal_n_trees, max_features=int( np.floor(0.75 * X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
# # RF_condensates = RF(n_estimators=200, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, oob_score=True).fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

# ##Prediction
# prediction_start_time = time.time()
# y_hat_RF = RF_condensates.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# print("max: ", np.max(y_hat_RF))
# print("min: ", np.min(y_hat_RF))

# #Error Analysis on TEST data
# #mse_Test
# mse= np.mean((y_test- y_hat_RF)**2)
# print('MSE: ', mse)

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_hat_RF)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_hat_RF))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_hat_RF)
# print("R² score: ", r2_sklearn) #old value: 0.9922993421321149

# %%
# #RF Ft. importance in descending order
# importance = RF_condensates.feature_importances_

# #Combine ft. names and scores
# feature_scores = list(zip(feature_names, importance))

# #Sort by score in descending order
# feature_scores.sort(key=lambda x: x[1], reverse=True)

# for name, score in feature_scores:
#     print(f'{name}:{score:.6f}')

# %% [markdown]
# Boosting

# %%
#Method 1: Using GridSearchCV
# from sklearn.model_selection import GridSearchCV

# param_grid ={
#     'n_estimators':[100,200],
#     'learning_rate':[0.01, 0.1, 0.5],
#     'max_depth': [5,7,10,12], #add more depths later
#     'min_samples_leaf' :[10, 30] 
# }

# gb_model= GBR()

# grid_search= GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1)

# grid_search.fit(X_train, y_train)

# best_params = grid_search.best_params_
# best_model = grid_search.best_estimator_

# y_pred_best = best_model.predict(X_test)

# r2_best = r2_score(y_test, y_pred_best)

# print('Best parameters: ', best_params)
# print(f'Best Model R2 score: {r2_best}')

# %%
#Method 2: Best hyperparameters using RandomizedSeachCV

# from sklearn.model_selection import RandomizedSearchCV

# param_dist ={
#     'n_estimators':[100,200],
#     'learning_rate': np.arange(0.01,0.1, 0.5),
#     'max_depth': [5,7,10,12], #add more depths later
#     'min_samples_leaf' :[10, 30] 
# }

# gb_model = GBR()

# random_search= RandomizedSearchCV(estimator=gb_model, param_distributions=param_dist, n_iter=10, cv=5, scoring='r2', n_jobs=-1)

# random_search.fit(X_train, y_train)

# best_params= random_search.best_params_
# best_model= random_search.best_estimator_

# y_pred_best= best_model.predict(X_test)
# r2_best = r2_score(y_test, y_pred_best)

# print("Best parameters: ", best_params)
# print(f"Best Model R2 Score: {r2_best}")

# %%
# #Use this block-1

# #Use grid search's best parameters!
# best_n_trees=100 #best_params['n_estimators']
# best_min_samples_leaf=30 #best_params['min_samples_leaf']
# best_max_depth=10 #best_params['max_depth']
# best_learning_rate= 0.1 #best_params['learning_rate']

# %%
# #Use this block-2

# #Boosting
# boost_condensates=GBR(random_state=0, n_estimators=best_n_trees, learning_rate=best_learning_rate, min_samples_leaf=best_min_samples_leaf, max_depth=best_max_depth)

# ##Training
# training_start_time = time.time()
# boost_condensates.fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes") #73 mins and countiung, then disconnected.
# #Total elapsed time: 163.8 mins

# %%
# #Use this block

# #x axis: boosting iteration number
# test_error = np.zeros_like(boost_condensates.train_score_)
# for idx, y_ in enumerate(boost_condensates.staged_predict(X_test)):
#     ######################################################
#     #####################################################
#     count=0
#     for i in y_:
#         if i>1 or i<0:
#             # print(i)
#             count+=1
#     print(f"Iteration {idx} incorrect count = ", count)
#     print("incorrect count percent = ", 100*count/len(y_))
#     #####################################################
#     y_ = np.clip(y_, 0, 1)
#     ######################################################
#     test_error[idx] = np.mean((y_test- y_)**2)
# plot_idx = np.arange(boost_condensates.train_score_.shape[0])
# ax = subplots(figsize=(8,8))[1]
# ax.plot(plot_idx,
# boost_condensates.train_score_,
# 'b',
# label='Training')

# ax.plot(plot_idx,
# test_error,
# 'r',
# label='Test')
# ax.legend();

# ax.set_xlabel("Total number of trees")
# ax.set_ylabel("Mean Squared Error")

# # print("Shape:", boost_condensates.train_score_.shape) #iterations
# # print("Number of elements:", boost_condensates.train_score_.size)

# %%
# #Use this block-3

# ##Prediction
# prediction_start_time = time.time()
# y_hat_boost = boost_condensates.predict(X_test);
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# y_hat_boost = np.clip(y_hat_boost, 0, 1)
# #Error Analysis on TEST data
# #mse_test
# mse= np.mean((y_test- y_hat_boost)**2)
# print('MSE_Test: ', mse)

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_hat_boost)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_hat_boost))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_hat_boost)
# print("R² score: ", r2_sklearn)

# %%
# #Use this block-4

# #Boosting ft. importance in descending order
# importance = boost_condensates.feature_importances_

# #Combine ft. names and scores
# feature_scores = list(zip(feature_names, importance))

# #Sort by score in descending order
# feature_scores.sort(key=lambda x: x[1], reverse=True)

# for name, score in feature_scores:
#     print(f'{name}:{score:.6f}')

# %%
# #Boosting with CCP

# best_n_trees=100 #best_params['n_estimators']
# best_min_samples_leaf=30 #best_params['min_samples_leaf']
# best_max_depth=12 #best_params['max_depth']
# best_learning_rate= 0.1 #best_params['learning_rate']

# #Boosting
# boost_condensates=GBR(ccp_alpha=best_ccp_alpha, random_state=0, n_estimators=best_n_trees, learning_rate=best_learning_rate, min_samples_leaf=best_min_samples_leaf, max_depth=best_max_depth)

# ##Training
# training_start_time = time.time()
# boost_condensates.fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes") #73 mins and countiung, then disconnected.

# #Training- Elapsed time: 150.0770 minutes (compute node)
# #Training- Elapsed time:  minutes (interactive node)

# %%
# #x axis: boosting iteration number
# test_error = np.zeros_like(boost_condensates.train_score_)
# for idx, y_ in enumerate(boost_condensates.staged_predict(X_test)):
#     ######################################################
#     #####################################################
#     count=0
#     for i in y_:
#         if i>1 or i<0:
#             # print(i)
#             count+=1
#     print(f"Iteration {idx} incorrect count = ", count)
#     print("incorrect count percent = ", 100*count/len(y_))
#     #####################################################
#     y_ = np.clip(y_, 0, 1)
#     ######################################################
#     test_error[idx] = np.mean((y_test- y_)**2)
# plot_idx = np.arange(boost_condensates.train_score_.shape[0])
# ax = subplots(figsize=(8,8))[1]
# ax.plot(plot_idx,
# boost_condensates.train_score_,
# 'b',
# label='Training')

# ax.plot(plot_idx,
# test_error,
# 'r',
# label='Test')
# ax.legend();

# ax.set_xlabel("Total number of trees")
# ax.set_ylabel("Mean Squared Error")


# # print("Shape:", boost_condensates.train_score_.shape) #iterations
# # print("Number of elements:", boost_condensates.train_score_.size)

# %%
# ##Prediction
# prediction_start_time = time.time()
# y_hat_boost = boost_condensates.predict(X_test);
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# y_hat_boost = np.clip(y_hat_boost, 0, 1)
# #Error Analysis on TEST data
# #mse_test
# mse= np.mean((y_test- y_hat_boost)**2)
# print('MSE_Test: ', mse)

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_hat_boost)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_hat_boost))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_hat_boost)
# print("R² score: ", r2_sklearn)

# %%
# #Boosting ft. importance in descending order
# importance = boost_condensates.feature_importances_

# #Combine ft. names and scores
# feature_scores = list(zip(feature_names, importance))

# #Sort by score in descending order
# feature_scores.sort(key=lambda x: x[1], reverse=True)

# for name, score in feature_scores:
#     print(f'{name}:{score:.6f}')

# %% [markdown]
# XGBoost

# %%
# #Method 1: Grid Search
# from sklearn.model_selection import GridSearchCV

# param_grid={
#     'n_estimators': [100, 200],
#     'max_depth': [5, 7, 10, 12],
#     'learning_rate': [0.01, 0.1, 0.2],
#     'min_child_weight': [10, 30]
# }


# xgb_model= xgb.XGBRegressor()

# grid_search= GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')


# grid_search.fit(X_train, y_train)

# print("Best set of hyperparameters: ", grid_search.best_params_)
# print("Best score: ", grid_search.best_score_)

# %%
# #n_estimators, eta/learning_rate, max_depth, min_child_weight?, max_bin (def=256)->increasing this number improves the optimality of splits at the cost of higher computation time.
# #Method 2: Random Search
# import scipy.stats as stats

# param_dist = {
#     'n_estimators': stats.randint(100, 201),
#     'max_depth': stats.randint(5,13),
#     'learning_rate': stats.uniform(0.01, 0.2),
#     'min_child_weight': stats.randint(10, 31)
#     }

# model = XGBRegressor()

# # Set up the random search with 4-fold cross validation
# random_cv = RandomizedSearchCV(random_state=1, estimator=model, param_distributions= param_dist, cv=5, n_iter=100, scoring='r2', n_jobs=-1, return_train_score= True)  #verbose=5

# random_cv.fit(X_train, y_train)

# print("Best set of hyperparameters: ", random_cv.best_params_)
# print("Best score: ", random_cv.best_score_)

# %%
#random_cv.best_estimator_

# %%
# best_parameters= grid_search.best_params_

best_n_estimators=100 #best_parameters['n_estimators']
best_min_child_weight=30 #best_parameters['min_child_weight']
best_max_depth=10 #best_parameters['max_depth']
best_learning_rate=0.1 #best_parameters['learning_rate']

# %%
#XGBoost

# fit model
model = XGBRegressor(n_estimators=best_n_estimators, min_child_weight= best_min_child_weight, max_depth=best_max_depth, learning_rate=best_learning_rate, n_jobs=-1, random_state=0) #verbosity=3 (optional)

##Training
training_start_time = time.time()
model.fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

##Prediction
prediction_start_time = time.time()
y_pred = model.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
# Out:
# Training- Elapsed time: 0.4077 minutes
# Prediction- Elapsed time: 0.0025 minutes

# %%
print("max: ", np.max(y_pred))
print("min: ", np.min(y_pred))
# Out:
# max:  1.130333
# min:  -0.33201703

# %%
# count=0
# for i in y_pred:
#     if i>1 or i<0:
#         # print(i)
#         count+=1
# print("incorrect count = ", count)
# print("incorrect count percent = ", 100*count/len(y_pred))

# %%
y_pred = np.clip(y_pred, 0, 1)

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
#Error Analysis on TEST data
#mse
mse= np.mean((y_test- y_pred)**2)
print('MSE_Test: ', mse)

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score: ", r2_sklearn)
# Out:
# MSE_Test:  0.007061215
# RMSE_TEST: 0.08403103798627853
# mae_TEST: 0.03889485448598862
# R² score:  0.9613093137741089

# %%
#xgb feature importance
importance = model.feature_importances_

#Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

#Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

for name, score in feature_scores:
    pct = score*100
    print(f'{name}:{pct:.4f} %')
# Out:
# ta:73.6807 %
# clw+cli:12.1599 %
# RH:5.9645 %
# qr+qg+qs:3.2471 %
# hus:1.1456 %
# cllvi+clivi:1.1152 %
# wa:0.7430 %
# pfull:0.6691 %
# clat:0.4473 %
# clon:0.4355 %
# ua:0.2004 %
# va:0.1918 %

# %%
import matplotlib.pyplot as plt

# ---- Your existing logic ----
importance = model.feature_importances_

# Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

# Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Snow\ fraction}$ determination using $\mathbf{XGBoost}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis range
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# ta: 73.6807 %
# clw+cli: 12.1599 %
# RH: 5.9645 %
# qr+qg+qs: 3.2471 %
# hus: 1.1456 %
# cllvi+clivi: 1.1152 %
# wa: 0.7430 %
# pfull: 0.6691 %
# clat: 0.4473 %
# clon: 0.4355 %
# ua: 0.2004 %
# va: 0.1918 %

# %%
# plt.figure(figsize=(8,6))
# sns.scatterplot(x=y_test.flatten(), y=y_pred.flatten(), alpha=0.7)
# plt.xlabel("Actual Values")
# plt.ylabel("Predicted Values")
# plt.title("Actual vs Predicted Values (XGB)")
# # Add a perfect prediction line
# plt.plot([y_test.min(), y_test.max()],
#          [y_test.min(), y_test.max()],
#          color='red', lw=2)
# plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hexbin(
    y_test.flatten(), 
    y_pred.flatten(), 
    gridsize=40,  # smaller → finer grid
    cmap='viridis', 
    bins='log'  # logarithmic scaling helps emphasize dense areas
)
plt.colorbar(label='log10(N)')
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color='red', lw=2
)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (XGB)")
plt.show()

# %% [markdown]
# BART

# %%
#BART

# bart_condensates = BART(random_state=0, burnin=100, ndraw=15)
# bart_condensates.fit(X_train, y_train)

# %%
# yhat_test = bart_condensates.predict(X_test.astype(np.float32))

# yhat_test = np.clip(yhat_test, 0, 1)
# np.mean((y_test- yhat_test)**2)

# %%
# var_inclusion = pd.Series(bart_condensates.variable_inclusion_.mean(0),
#  index=D.columns)
# var_inclusion

# %%
overall_end_time = time.time()

totalElapsedTime=overall_end_time - overall_start_time
print(f"The Total Elapsed Time is: {totalElapsedTime/60:.4f} minutes")
# Out:
# The Total Elapsed Time is: 15.7997 minutes
