# %%
#the threshold is commented

#The folder structure has been changed and the code is updated accordingly. Copy-paste the imports code block in other relevant codes if needed.

#color bar updated and y-axis is set to altitude instead of height levels in Curtains
#mass-weighted random sampling and weighted R2
#new Dataset
#update output folder if required
#Opt for m_rsg or m_sg depending on the problem at hand

output_folder_name = '13-8-2026_data-init-with-SA_global_paper_qs_qrsg'
# Dendrogram_output_file_name = 'Dendrogram_qs_by_(qr+qs+qg)_using_all_locals.png' #write .png
# HC_output_file_name = 'HC_qs_by_(qr+qs+qg)_using_all_locals.csv' #write .csv
pred_vs_actual_output_file_name = 'Pred_vs_Actual_qs_by_(qr+qs+qg)_using_all_locals.png' #write .png

import time
overall_start_time = time.time()
import os
import importlib
import sys

# #Remove cached modules
# for module_name in list(sys.modules.keys()):
#     if 'dataset_init' in module_name:
#         del sys.modules[module_name]

# #Reimport
# from Tools import dataset_init

#To go up one level from 'Codes' sub-folder to 'MS' Folder, then the other sub-folders such as 'File_management' are accessible
MS_PATH = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(MS_PATH)

import numpy as np
import pandas as pd
#%matplotlib inline  #won't work for .py
import matplotlib.pyplot as plt
import xarray as xr

from File_management import json_file_editer as JFE
from Calculation import job_manager 
# from Tools import dataset_init
from Tools import data_init_with_SA as dataset_init
from Tools import thermodynamics
from Log_management import Log

import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

#random forest
import warnings
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

warnings.filterwarnings('ignore')

#ISLP
from matplotlib.pyplot import subplots
from statsmodels.datasets import get_rdataset
import sklearn.model_selection as skm
from ISLP import load_data, confusion_table
# from ISLP.models import ModelSpec as MS

from sklearn.tree import (DecisionTreeClassifier as DTC,
 DecisionTreeRegressor as DTR,
 plot_tree,
 export_text)
from sklearn.metrics import (accuracy_score,
 log_loss)
from sklearn.ensemble import \
 (RandomForestRegressor as RF,
 GradientBoostingRegressor as GBR)
from ISLP.bart import BART
import joblib

import csv
from Tools.data_init_with_SA import saturation_adjustment_newton

#################################################################
# Log.init_log(os.path.join('./output'), filename=f"Log_ML.txt")
Log.init_log(os.path.join(MS_PATH, 'output'), filename="Log_ML.txt")
Log.add_to_log("Log nicely initialized ")

# options_json=JFE.get_json_data("options.json")
options_json = JFE.get_json_data(os.path.join(MS_PATH, "options.json"))

options_json["Header"]["status"]
chunks = {}
myJob = job_manager.JobManager(options_json)
# ds = dataset_init.ds_init_3d(myJob, chunks={}) 
ds = dataset_init.ds_init(myJob, chunks={}) 

#Test dataset
options_json_another_date = JFE.get_json_data(os.path.join(MS_PATH, "options_another_date.json"))

options_json_another_date["Header"]["status"]
chunks = {}
myJob_another_date = job_manager.JobManager(options_json_another_date)
# ds = dataset_init.ds_init_3d(myJob_another_date, chunks={}) 
ds_test = dataset_init.ds_init(myJob_another_date, chunks={})
# Out:
# The job folder path : /home/m/m301214/MS/output/Log_ML.txt
# 2026 Aug 13 17:39:47 > Log nicely initialized
# 2026 Aug 13 17:39:47 > (DI0010) making data from P-O files requires small differences in the code, hardly automisable.
# 2026 Aug 13 17:39:47 > (DI0020) Starting PO dataset creation from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0003
# 2026 Aug 13 17:39:47 > (DI0021) Found 35 time-varying files in date range
# 2026 Aug 13 17:39:47 > (DI0022) Loading vertical grid data from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0003/pod0003_atm_vgrid_ml.nc
# 2026 Aug 13 17:39:48 > (DI0023) Grid variables available: ['clon_bnds', 'clat_bnds', 'height_bnds', 'height_2_bnds', 'zghalf', 'zg', 'dzghalf', 'clon', 'clat', 'height', 'height_2']
# 2026 Aug 13 17:39:48 > (DI0024) Dimensions in vgrid: {'ncells': 20971520, 'vertices': 3, 'height': 60, 'bnds': 2, 'height_2': 60}
# 2026 Aug 13 17:39:48 > (DI0037) Loading horizontal grid data from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2026 Aug 13 17:39:48 > (DI0039) Successfully loaded cell areas from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2026 Aug 13 17:39:51 > (DI0019) Combining 5 time-varying datasets
# 2026 Aug 13 17:39:56 > (DI0018) Merging time-varying data with vertical grid data
# 2026 Aug 13 17:39:56 > (DI0017) Common dimensions: {'ncells', 'height_2', 'height', 'bnds'}
# 2026 Aug 13 17:39:56 > (DI0016) Successfully merged with vertical grid data
# 2026 Aug 13 17:39:56 > (DI0074) Merging with horizontal grid data (cell areas)
# 2026 Aug 13 17:39:56 > (DI0073) Renamed 'cell' dimension to 'ncells'
# 2026 Aug 13 17:39:56 > (DI0071) After renaming - common dimensions: {'ncells'}
# 2026 Aug 13 17:39:59 > (DI0075) Successfully merged cell area data
# 2026 Aug 13 17:39:59 > (DI0033) Selected variables: ['cell_area', 'clat', 'cli', 'clivi', 'cllvi', 'clon', 'clw', 'dzghalf', 'hus', 'pfull', 'pr', 'qg', 'qgvi', 'qr', 'qrvi', 'qs', 'qsvi', 'rho', 'ta', 'tas', 'ua', 'va', 'wa', 'zg']
# 2026 Aug 13 17:39:59 > (DI0035) Final dataset shape: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2026 Aug 13 17:39:59 > (DI0036) Final dataset variables: ['cell_area', 'clat', 'cli', 'clivi', 'cllvi', 'clon', 'clw', 'dzghalf', 'hus', 'pfull', 'pr', 'qg', 'qgvi', 'qr', 'qrvi', 'qs', 'qsvi', 'rho', 'ta', 'tas', 'ua', 'va', 'wa', 'zg', 'time', 'height', 'height_2']
# 2026 Aug 13 17:39:59 > (DI0100) ========== Final Dataset for scheme_comparison Information ==========
# 2026 Aug 13 17:39:59 > (DI0101) Dimensions: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2026 Aug 13 17:39:59 > (DI0102) Coordinates:
# 2026 Aug 13 17:39:59 >   clat: (20971520,) float64
# 2026 Aug 13 17:39:59 >   clon: (20971520,) float64
# 2026 Aug 13 17:39:59 >   time: (1,) datetime64[ns]
# 2026 Aug 13 17:39:59 >   height: (61,) float64
# 2026 Aug 13 17:39:59 >   height_2: (61,) float64
# 2026 Aug 13 17:39:59 > (DI0103) Data Variables:
# 2026 Aug 13 17:39:59 >   cell_area: (20971520,) float64 (ncells)
# 2026 Aug 13 17:39:59 >     Units: m2
# 2026 Aug 13 17:39:59 >     Description: area of grid cell
# 2026 Aug 13 17:39:59 >   cli: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg kg-1
# 2026 Aug 13 17:39:59 >     Description: specific cloud ice content
# 2026 Aug 13 17:39:59 >   clivi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg m-2
# 2026 Aug 13 17:39:59 >     Description: cloud ice path
# 2026 Aug 13 17:39:59 >   cllvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg m-2
# 2026 Aug 13 17:39:59 >     Description: cloud liquid water path
# 2026 Aug 13 17:39:59 >   clw: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg kg-1
# 2026 Aug 13 17:39:59 >     Description: specific cloud water content
# 2026 Aug 13 17:39:59 >   dzghalf: (61, 20971520) float32 (height, ncells)
# 2026 Aug 13 17:39:59 >     Units: -
# 2026 Aug 13 17:39:59 >     Description: metrics functional determinant
# 2026 Aug 13 17:39:59 >   hus: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg kg-1
# 2026 Aug 13 17:39:59 >     Description: Specific humidity
# 2026 Aug 13 17:39:59 >   pfull: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: Pa
# 2026 Aug 13 17:39:59 >     Description: Pressure
# 2026 Aug 13 17:39:59 >   pr: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg m-2 s-1
# 2026 Aug 13 17:39:59 >     Description: precipitation flux
# 2026 Aug 13 17:39:59 >   qg: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg kg-1
# 2026 Aug 13 17:39:59 >     Description: specific graupel content
# 2026 Aug 13 17:39:59 >   qgvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg m-2
# 2026 Aug 13 17:39:59 >     Description: graupel path
# 2026 Aug 13 17:39:59 >   qr: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg kg-1
# 2026 Aug 13 17:39:59 >     Description: specific rain content
# 2026 Aug 13 17:39:59 >   qrvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg m-2
# 2026 Aug 13 17:39:59 >     Description: rain path
# 2026 Aug 13 17:39:59 >   qs: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg kg-1
# 2026 Aug 13 17:39:59 >     Description: specific snow content
# 2026 Aug 13 17:39:59 >   qsvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg m-2
# 2026 Aug 13 17:39:59 >     Description: snow path
# 2026 Aug 13 17:39:59 >   rho: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: kg m-3
# 2026 Aug 13 17:39:59 >     Description: density
# 2026 Aug 13 17:39:59 >   ta: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: K
# 2026 Aug 13 17:39:59 >     Description: Temperature
# 2026 Aug 13 17:39:59 >   tas: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: K
# 2026 Aug 13 17:39:59 >     Description: temperature in 2m
# 2026 Aug 13 17:39:59 >   ua: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: m s-1
# 2026 Aug 13 17:39:59 >     Description: Zonal wind
# 2026 Aug 13 17:39:59 >   va: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:39:59 >     Units: m s-1
# 2026 Aug 13 17:39:59 >     Description: Meridional wind
# 2026 Aug 13 17:39:59 >   wa: (1, 61, 20971520) float32 (time, height_2, ncells)
# 2026 Aug 13 17:39:59 >     Units: m s-1
# 2026 Aug 13 17:39:59 >     Description: Vertical velocity
# 2026 Aug 13 17:39:59 >   zg: (61, 20971520) float32 (height_2, ncells)
# 2026 Aug 13 17:39:59 >     Units: m
# 2026 Aug 13 17:39:59 >     Description: geometric height at full level center
# 2026 Aug 13 17:39:59 > (DI0104) Estimated memory usage: 72.42 GB
# 2026 Aug 13 17:39:59 > (DI0105) Time range: 2020-01-12T00:00:00.000000000 to 2020-01-12T00:00:00.000000000 (1 steps)
# 2026 Aug 13 17:39:59 > (DI0107) ========== End Final Dataset for scheme_comparison Information ==========
# 2026 Aug 13 17:39:59 > (DI0010) making data from P-O files requires small differences in the code, hardly automisable.
# 2026 Aug 13 17:39:59 > (DI0020) Starting PO dataset creation from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0003
# 2026 Aug 13 17:39:59 > (DI0021) Found 35 time-varying files in date range
# 2026 Aug 13 17:39:59 > (DI0022) Loading vertical grid data from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0003/pod0003_atm_vgrid_ml.nc
# 2026 Aug 13 17:39:59 > (DI0023) Grid variables available: ['clon_bnds', 'clat_bnds', 'height_bnds', 'height_2_bnds', 'zghalf', 'zg', 'dzghalf', 'clon', 'clat', 'height', 'height_2']
# 2026 Aug 13 17:39:59 > (DI0024) Dimensions in vgrid: {'ncells': 20971520, 'vertices': 3, 'height': 60, 'bnds': 2, 'height_2': 60}
# 2026 Aug 13 17:40:00 > (DI0037) Loading horizontal grid data from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2026 Aug 13 17:40:00 > (DI0039) Successfully loaded cell areas from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2026 Aug 13 17:40:01 > (DI0019) Combining 5 time-varying datasets
# 2026 Aug 13 17:40:06 > (DI0018) Merging time-varying data with vertical grid data
# 2026 Aug 13 17:40:06 > (DI0017) Common dimensions: {'ncells', 'height_2', 'height', 'bnds'}
# 2026 Aug 13 17:40:06 > (DI0016) Successfully merged with vertical grid data
# 2026 Aug 13 17:40:06 > (DI0074) Merging with horizontal grid data (cell areas)
# 2026 Aug 13 17:40:06 > (DI0073) Renamed 'cell' dimension to 'ncells'
# 2026 Aug 13 17:40:06 > (DI0071) After renaming - common dimensions: {'ncells'}
# 2026 Aug 13 17:40:08 > (DI0075) Successfully merged cell area data
# 2026 Aug 13 17:40:08 > (DI0033) Selected variables: ['cell_area', 'clat', 'cli', 'clivi', 'cllvi', 'clon', 'clw', 'dzghalf', 'hus', 'pfull', 'pr', 'qg', 'qgvi', 'qr', 'qrvi', 'qs', 'qsvi', 'rho', 'ta', 'tas', 'ua', 'va', 'wa', 'zg']
# 2026 Aug 13 17:40:08 > (DI0035) Final dataset shape: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2026 Aug 13 17:40:08 > (DI0036) Final dataset variables: ['cell_area', 'clat', 'cli', 'clivi', 'cllvi', 'clon', 'clw', 'dzghalf', 'hus', 'pfull', 'pr', 'qg', 'qgvi', 'qr', 'qrvi', 'qs', 'qsvi', 'rho', 'ta', 'tas', 'ua', 'va', 'wa', 'zg', 'time', 'height', 'height_2']
# 2026 Aug 13 17:40:08 > (DI0100) ========== Final Dataset for scheme_comparison Information ==========
# 2026 Aug 13 17:40:08 > (DI0101) Dimensions: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2026 Aug 13 17:40:08 > (DI0102) Coordinates:
# 2026 Aug 13 17:40:08 >   clat: (20971520,) float64
# 2026 Aug 13 17:40:08 >   clon: (20971520,) float64
# 2026 Aug 13 17:40:08 >   time: (1,) datetime64[ns]
# 2026 Aug 13 17:40:08 >   height: (61,) float64
# 2026 Aug 13 17:40:08 >   height_2: (61,) float64
# 2026 Aug 13 17:40:08 > (DI0103) Data Variables:
# 2026 Aug 13 17:40:08 >   cell_area: (20971520,) float64 (ncells)
# 2026 Aug 13 17:40:08 >     Units: m2
# 2026 Aug 13 17:40:08 >     Description: area of grid cell
# 2026 Aug 13 17:40:08 >   cli: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg kg-1
# 2026 Aug 13 17:40:08 >     Description: specific cloud ice content
# 2026 Aug 13 17:40:08 >   clivi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg m-2
# 2026 Aug 13 17:40:08 >     Description: cloud ice path
# 2026 Aug 13 17:40:08 >   cllvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg m-2
# 2026 Aug 13 17:40:08 >     Description: cloud liquid water path
# 2026 Aug 13 17:40:08 >   clw: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg kg-1
# 2026 Aug 13 17:40:08 >     Description: specific cloud water content
# 2026 Aug 13 17:40:08 >   dzghalf: (61, 20971520) float32 (height, ncells)
# 2026 Aug 13 17:40:08 >     Units: -
# 2026 Aug 13 17:40:08 >     Description: metrics functional determinant
# 2026 Aug 13 17:40:08 >   hus: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg kg-1
# 2026 Aug 13 17:40:08 >     Description: Specific humidity
# 2026 Aug 13 17:40:08 >   pfull: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: Pa
# 2026 Aug 13 17:40:08 >     Description: Pressure
# 2026 Aug 13 17:40:08 >   pr: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg m-2 s-1
# 2026 Aug 13 17:40:08 >     Description: precipitation flux
# 2026 Aug 13 17:40:08 >   qg: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg kg-1
# 2026 Aug 13 17:40:08 >     Description: specific graupel content
# 2026 Aug 13 17:40:08 >   qgvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg m-2
# 2026 Aug 13 17:40:08 >     Description: graupel path
# 2026 Aug 13 17:40:08 >   qr: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg kg-1
# 2026 Aug 13 17:40:08 >     Description: specific rain content
# 2026 Aug 13 17:40:08 >   qrvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg m-2
# 2026 Aug 13 17:40:08 >     Description: rain path
# 2026 Aug 13 17:40:08 >   qs: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg kg-1
# 2026 Aug 13 17:40:08 >     Description: specific snow content
# 2026 Aug 13 17:40:08 >   qsvi: (1, 20971520) float32 (time, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg m-2
# 2026 Aug 13 17:40:08 >     Description: snow path
# 2026 Aug 13 17:40:08 >   rho: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: kg m-3
# 2026 Aug 13 17:40:08 >     Description: density
# 2026 Aug 13 17:40:08 >   ta: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: K
# 2026 Aug 13 17:40:08 >     Description: Temperature
# 2026 Aug 13 17:40:08 >   tas: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: K
# 2026 Aug 13 17:40:08 >     Description: temperature in 2m
# 2026 Aug 13 17:40:08 >   ua: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: m s-1
# 2026 Aug 13 17:40:08 >     Description: Zonal wind
# 2026 Aug 13 17:40:08 >   va: (1, 61, 20971520) float32 (time, height, ncells)
# 2026 Aug 13 17:40:08 >     Units: m s-1
# 2026 Aug 13 17:40:08 >     Description: Meridional wind
# 2026 Aug 13 17:40:08 >   wa: (1, 61, 20971520) float32 (time, height_2, ncells)
# 2026 Aug 13 17:40:08 >     Units: m s-1
# 2026 Aug 13 17:40:08 >     Description: Vertical velocity
# 2026 Aug 13 17:40:08 >   zg: (61, 20971520) float32 (height_2, ncells)
# 2026 Aug 13 17:40:08 >     Units: m
# 2026 Aug 13 17:40:08 >     Description: geometric height at full level center
# 2026 Aug 13 17:40:08 > (DI0104) Estimated memory usage: 72.42 GB
# 2026 Aug 13 17:40:08 > (DI0105) Time range: 2020-01-13T00:00:00.000000000 to 2020-01-13T00:00:00.000000000 (1 steps)
# 2026 Aug 13 17:40:08 > (DI0107) ========== End Final Dataset for scheme_comparison Information ==========

# %%
#Rename variables as per our notation
ds = ds.rename({'clw': 'ql'})
ds = ds.rename({'cli': 'qi'})
ds = ds.rename({'ta': 'T'})
ds = ds.rename({'hus': 'SH'})
ds = ds.rename({'pfull': 'P'})
ds = ds.rename({'cllvi': 'CLWP'})
ds = ds.rename({'clivi': 'CIP'})
ds = ds.rename({'wa': 'upward_air_velocity'})
ds = ds.rename({'ua': 'zonal_wind'})
ds = ds.rename({'va': 'meridional_wind'})
ds = ds.rename({'rho': 'air_density'})

#Rename variables as per our notation
ds_test = ds_test.rename({'clw': 'ql'})
ds_test = ds_test.rename({'cli': 'qi'})
ds_test = ds_test.rename({'ta': 'T'})
ds_test = ds_test.rename({'hus': 'SH'})
ds_test = ds_test.rename({'pfull': 'P'})
ds_test = ds_test.rename({'cllvi': 'CLWP'})
ds_test = ds_test.rename({'clivi': 'CIP'})
ds_test = ds_test.rename({'wa': 'upward_air_velocity'})
ds_test = ds_test.rename({'ua': 'zonal_wind'})
ds_test = ds_test.rename({'va': 'meridional_wind'})
ds_test = ds_test.rename({'rho': 'air_density'})

# %%
#Weighted R2 score 
def weighted_r_squared(y_true, y_pred, weight, y_train):
    # Calculate the mean of the actual values
    mean_y_train = np.mean(y_train)
    mean_y_true = np.mean(y_true)
    ss_total = np.sum( weight * (y_true - mean_y_train)**2)
    ss_residual = np.sum( weight * (y_true - y_pred)**2)
    r2_score = 1 - (ss_residual / ss_total)
    return r2_score

def apply_saturation_adjustment_to_dataset(dataset):
    qti = dataset["qi"] + dataset["qg"] + dataset["qs"]
    SH_adjusted, ql_adjusted, T_adjusted = saturation_adjustment_newton(
        qv=dataset["SH"],
        ql=dataset["ql"],
        tk=dataset["T"],
        rho=dataset["air_density"],
        qr=dataset["qr"],
        qti=qti,
        n_iter=6,
    )

    dataset = dataset.assign(
        SH=SH_adjusted,
        ql=ql_adjusted,
        T=T_adjusted,
    )
    dataset["SH"].attrs.update({"saturation_adjusted": "newton"})
    dataset["ql"].attrs.update({"saturation_adjusted": "newton"})
    dataset["T"].attrs.update({"saturation_adjusted": "newton"})
    dataset.attrs["saturation_adjustment"] = "newton_liquid_water_energy_conserving"
    dataset.attrs["saturation_adjustment_iterations"] = 6
    return dataset

# %%
ds = apply_saturation_adjustment_to_dataset(ds)
ds_test = apply_saturation_adjustment_to_dataset(ds_test)

# %%
def add_upward_air_velocity_on_full_levels(ds):
    upward_air_velocity_full = ds["upward_air_velocity"].sel(height_2=slice(2, None))
    upward_air_velocity_full = upward_air_velocity_full.rename({"height_2": "height"})
    upward_air_velocity_full = upward_air_velocity_full.assign_coords(height=ds["height"])
    return ds.assign(upward_air_velocity=upward_air_velocity_full)

ds = add_upward_air_velocity_on_full_levels(ds)
ds_test = add_upward_air_velocity_on_full_levels(ds_test)

# %%
#Data Pre-processing

#subset of the original dataset

seed = 1
# sample_frac = 0.001

ht=31
data=ds.sel(height=ht, height_2=ht)

# %%
#Graupel Threshold set to 1e-6 kg/kg as mentioned in Michibata, 2024
# data = data.where(data['qg'] >= 1e-6)

total = data['ql'] + data['qi']
data['ql/(ql+qi)'] = data['ql'].where(total != 0, 0) / total.where(total != 0, 1)
data['qi/(ql+qi)'] = data['qi'].where(total != 0, 0) / total.where(total != 0, 1)

total_precipitates = data['qr'] + data['qs']+ data['qg']
data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

df = data.to_dataframe() #.sample(frac=1, random_state=seed) #frac=sample_frac

#threshold
threshold = 5e-12
df_new = df[(df['ql'] + df['qi'] + df['qr'] + df['qg'] + df['qs']) >= threshold]

if df_new.empty:
    df_new = df

df = df_new
# df = data.to_dataframe().sample(frac=sample_frac, random_state=seed)

dfs = [df]  
# for ht in range(32, 91, 5): #(32, 91, 5)
for ht in range(36, 91, 5): #(44, 91, 4)
    data = ds.sel(height=ht, height_2=ht)
    #Graupel Threshold set to 1e-6 kg/kg as mentioned in Michibata, 2024
    # data = data.where(data['qg'] >= 1e-6)

    total = data['ql'] + data['qi']
    data['ql/(ql+qi)'] = data['ql'].where(total != 0, 0) / total.where(total != 0, 1)
    data['qi/(ql+qi)'] = data['qi'].where(total != 0, 0) / total.where(total != 0, 1)

    total_precipitates = data['qr'] + data['qs']+ data['qg']
    data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

    df_sampled=data.to_dataframe() #.sample(frac=1, random_state= seed+ht) #frac=sample_frac

    #threshold
    threshold = 5e-12
    df_sampled_new = df_sampled[(df_sampled['ql'] + df_sampled['qi'] + df_sampled['qr'] + df_sampled['qg'] + df_sampled['qs']) >= threshold]

    if df_sampled_new.empty:
        df_sampled_new = df_sampled

    df_sampled = df_sampled_new

    dfs.append(df_sampled) 


    print(f"Last value of clon in df with height {ht} is", df_sampled['clon'].iloc[-1])

df = pd.concat(dfs, ignore_index=True)


expected_length = sum(len(x) for x in dfs)
print("Expected length of df: ", expected_length)
print('Final length of df: ', len(df))


#OBtain lon and lat from clon and clat respectively
df['lon'] = df['clon']*180/np.pi #in degrees
df['lat'] = df['clat']*180/np.pi #in degrees

# #Setting coordinates range as the range of coordinates in Curtains dataset

# print("Minimum latitude: ", df['lat'].min())
# print("Maximum latitude: ", df['lat'].max())
# print("Minimum longitude: ", df['lon'].min())
# print("Maximum longitude: ", df['lon'].max())

# len_df_before_coordinate_slicing = len(df)
# print("Length of df before coordinate slicing: ", len_df_before_coordinate_slicing)

# #Slice the df
# df = df[(df['lat'].between(-4, 23)) & (df['lon'].between(-62, -20))] #These are the range of values of coordinates in the Curtains dataset

# print("Minimum latitude: ", df['lat'].min())
# print("Maximum latitude: ", df['lat'].max())
# print("Minimum longitude: ", df['lon'].min())
# print("Maximum longitude: ", df['lon'].max())

# len_df_after_coordinate_slicing = len(df)
# print("Length of df after coordinate slicing: ", len_df_after_coordinate_slicing)

# #threshold
# threshold = 5e-12
# df_new = df[(df['qi'] + df['ql'] + df['qr'] + df['qg'] + df['qs']) >= threshold]

# if df_new.empty:
#     df_new = df

# df = df_new
# Out:
# Last value of clon in df with height 36 is -0.8223929610480394
# Last value of clon in df with height 41 is 1.8954505568741382
# Last value of clon in df with height 46 is 1.2075635365782438
# Last value of clon in df with height 51 is 1.274090353955931
# Last value of clon in df with height 56 is 1.3343108942333097
# Last value of clon in df with height 61 is 1.3311654584247423
# Last value of clon in df with height 66 is 1.3053725942366794
# Last value of clon in df with height 71 is 1.1805524665406022
# Last value of clon in df with height 76 is 1.1895574133799796
# Last value of clon in df with height 81 is 1.4321668545733466
# Last value of clon in df with height 86 is 1.3343108942333097
# Expected length of df:  58810458
# Final length of df:  58810458

# %%
#RH data

# df['RH']=RH_from_SH(df['P'], df['SH'], df['T'])
df['RH'] = thermodynamics.relative_humidity_water(df['SH'], df['T'], df['air_density'])

# %%
count=0
for i in df['RH']:
    if i>100 or i<0:
        count+=1
print("out-of-range count = ", count)
print("out-of-range count percent = ", 100*count/len(df['RH']), " %")

df['RH']= df['RH'].clip(lower=0, upper=100)

#Insert variables to the df
col=df.pop('RH')
df.insert(16, 'RH', col) #SH is at 15th position
#df.pop('SH')
# Out:
# out-of-range count =  0
# out-of-range count percent =  0.0  %

# %%
df['ql+qi']=df['ql']+df['qi']
col=df.pop('ql+qi')
df.insert(26, 'ql+qi', col) 

#Include 'cloud liquid water path + cloud ice path' as a feature.
df['CLWP+CIP']=df['CLWP']+df['CIP']
col=df.pop('CLWP+CIP')
df.insert(27, 'CLWP+CIP', col) 

#Adding another column; qr+qg+qs and use it later as an input feature
df['qr+qg+qs'] = df['qr'] + df['qg'] + df['qs']
col=df.pop('qr+qg+qs')
df.insert(30, 'qr+qg+qs', col)

# df['qs/(qr+qs+qg)'] = df['qs'] / (df['qr']+ df['qs'] + df['qg']) 
# print('Number of NaN values in qs/(qr+qs+qg) column: ', df['qs/(qr+qs+qg)'].isna().sum())
# df = df.dropna(subset=['qs/(qr+qs+qg)'])
# print('Number of NaN values in qs/(qr+qs+qg) column now: ', df['qs/(qr+qs+qg)'].isna().sum())

# #mass-weighted condensates
# df['m_ci']=df['dzghalf']*df['air_density']*df['cell_area']* (df['ql']+df['qi'])
# col=df.pop('m_ci')
# df.insert(28, 'm_ci', col) 

#mass-weighted random sampling
df['m_rsg']=df['dzghalf']*df['air_density']*df['cell_area']* (df['qr']+df['qs']+df['qg'])
col=df.pop('m_rsg')
df.insert(28, 'm_rsg', col) 

df = df.sort_values(by='m_rsg', ascending=False)
df = df.reset_index(drop=True)

total_mass = df['m_rsg'].sum()
df['cum_mass'] = df['m_rsg'].cumsum()
col=df.pop('cum_mass')
df.insert(29, 'cum_mass', col) 

n_samples= int(np.floor(len(df) * 0.1)) #we are taking a way smaller dataset because of this 
# n_samples= int(np.floor(len(df))) 
np.random.seed(29)
random_values = np.random.uniform(0, df['cum_mass'].max(), size=n_samples)
print('Random values: ', random_values)
# indices= np.searchsorted(df['cum_mass'].values, random_values)
indices = np.clip(np.searchsorted(df['cum_mass'].values, random_values), 0, len(df) - 1)
df_orig=df
df = df.iloc[indices].reset_index(drop=True)
# Out:
# Random values:  [5.14901517e+12 1.69837126e+12 4.36693364e+11 ... 7.92715367e+11
#  4.74838441e+12 3.54869337e+12]

# %%
feature_names= ['lat','lon','SH' ,'RH','T', 'upward_air_velocity', 'zonal_wind','meridional_wind','air_density','P','ql+qi','qr+qg+qs','qs/(qr+qs+qg)'] # [lat, lon, RH,T,upward_air_velocity,zonal_wind,meridional_wind,P,ql+qi,qr+qg+qs]
feature_names= [feature for feature in feature_names if feature not in ('CLWP+CIP', 'SH', 'air_density', 'qs/(qr+qs+qg)')] #'CLWP+CIP' is a non-local parameter

# %%
X_train = df[feature_names] 
y_train = df['qs/(qr+qs+qg)'].values 

#Train using xgb
#The following 'best' parameter values have been approximated from the values otained from the previous runs to find the best parameters in different datasets

# best_parameters= grid_search.best_params_
best_n_estimators=100 #best_parameters['n_estimators']
best_min_child_weight=30 #best_parameters['min_child_weight']
best_max_depth=10 #best_parameters['max_depth']
best_learning_rate=0.1 #best_parameters['learning_rate']

#XGBoost
##Training
training_start_time = time.time()
model = XGBRegressor(n_estimators=best_n_estimators, min_child_weight= best_min_child_weight, max_depth=best_max_depth, learning_rate=best_learning_rate, n_jobs=-1, random_state=0) #verbosity=3 (optional)
model.fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")


joblib.dump(model, os.path.join('../output', output_folder_name, 'xgb_model_qs_by_(qr+qs+qg)_using_all_locals'))
model=joblib.load(os.path.join('../output', output_folder_name, 'xgb_model_qs_by_(qr+qs+qg)_using_all_locals'))
# Out:
# Training- Elapsed time: 0.5732 minutes

# %%
#Preprocessing test ds_test
#subset of the original dataset
seed = 1
# sample_frac = 0.001
ht=31
data=ds_test.sel(height=ht, height_2=ht) 

total = data['ql'] + data['qi']
data['ql/(ql+qi)'] = data['ql'].where(total != 0, 0) / total.where(total != 0, 1)
data['qi/(ql+qi)'] = data['qi'].where(total != 0, 0) / total.where(total != 0, 1)

total_precipitates = data['qr'] + data['qs']+ data['qg']
data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

df_test = data.to_dataframe() #.sample(frac=1, random_state=seed) #frac=sample_frac

#threshold
threshold = 5e-12
df_test_new = df_test[(df_test['ql'] + df_test['qi'] + df_test['qr'] + df_test['qg'] + df_test['qs']) >= threshold]

if df_test_new.empty:
    df_test_new = df_test

df_test = df_test_new
# df_test = data.to_dataframe().sample(frac=sample_frac, random_state=seed)

df_tests = [df_test]  
# for ht in range(32, 91, 5): #(32, 91, 5)
for ht in range(36, 91, 5): #(44, 91, 4)
    data = ds_test.sel(height=ht, height_2=ht)
    #Graupel Threshold set to 1e-6 kg/kg as mentioned in Michibata, 2024
    # data = data.where(data['qg'] >= 1e-6)

    total = data['ql'] + data['qi']
    data['ql/(ql+qi)'] = data['ql'].where(total != 0, 0) / total.where(total != 0, 1)
    data['qi/(ql+qi)'] = data['qi'].where(total != 0, 0) / total.where(total != 0, 1)

    total_precipitates = data['qr'] + data['qs']+ data['qg']
    data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

    df_test_sampled=data.to_dataframe() #.sample(frac=1, random_state= seed+ht) #frac=sample_frac

    #threshold
    threshold = 5e-12
    df_test_sampled_new = df_test_sampled[(df_test_sampled['ql'] + df_test_sampled['qi'] + df_test_sampled['qr'] + df_test_sampled['qg'] + df_test_sampled['qs']) >= threshold]

    if df_test_sampled_new.empty:
        df_test_sampled_new = df_test_sampled

    df_test_sampled = df_test_sampled_new

    df_tests.append(df_test_sampled) 


    print(f"Last value of clon in df_test with height {ht} is", df_test_sampled['clon'].iloc[-1])

df_test = pd.concat(df_tests, ignore_index=True)

expected_length = sum(len(x) for x in df_tests)
print("Expected length of df_test: ", expected_length)
print('Final length of df_test: ', len(df_test))

#OBtain lon and lat from clon and clat respectively
df_test['lon'] = df_test['clon']*180/np.pi #in degrees
df_test['lat'] = df_test['clat']*180/np.pi #in degrees

#RH data
# df_test['RH']=RH_from_SH(df_test['P'], df_test['SH'], df_test['T'])
df_test['RH'] = thermodynamics.relative_humidity_water(df_test['SH'], df_test['T'], df_test['air_density'])

count=0
for i in df_test['RH']:
    if i>100 or i<0:
        count+=1
print("RH out-of-range count = ", count)
print("RH out-of-range count percent = ", 100*count/len(df_test['RH']), " %")

df_test['RH']= df_test['RH'].clip(lower=0, upper=100)

#Insert variables to the df_test
col=df_test.pop('RH')
df_test.insert(16, 'RH', col) #SH is at 15th position
#df_test.pop('SH')

df_test['ql+qi']=df_test['ql']+df_test['qi']
col=df_test.pop('ql+qi')
df_test.insert(26, 'ql+qi', col) 

#Include 'cloud liquid water path + cloud ice path' as a feature.
df_test['CLWP+CIP']=df_test['CLWP']+df_test['CIP']
col=df_test.pop('CLWP+CIP')
df_test.insert(27, 'CLWP+CIP', col) 

#Adding another column; qr+qg+qs and use it later as an input feature
df_test['qr+qg+qs'] = df_test['qr'] + df_test['qg'] + df_test['qs']
col=df_test.pop('qr+qg+qs')
df_test.insert(30, 'qr+qg+qs', col)

# df_test['ql/(ql+qi)'] = df_test['ql'] / (df_test['ql']+ df_test['qi']) 
# print('Number of NaN values in qr/(qr+qs+qg) column: ', df_test['ql/(ql+qi)'].isna().sum())
# df_test = df_test.dropna(subset=['ql/(ql+qi)'])
# print('Number of NaN values in qr/(qr+qs+qg) column now: ', df_test['ql/(ql+qi)'].isna().sum())

#mass-weighted condensates
# df_test['m_ci']=df_test['dzghalf']*df_test['air_density']*df_test['cell_area']* (df_test['ql']+df_test['qi'])
# col=df_test.pop('m_ci')
# df_test.insert(28, 'm_ci', col) 

# #mass-weighted random sampling
# df_test['m_rsg']=df_test['dzghalf']*df_test['air_density']*df_test['cell_area']* (df_test['qr']+df_test['qs']+df_test['qg'])
# col=df_test.pop('m_rsg')
# df_test.insert(28, 'm_rsg', col) 

# df_test = df_test.sort_values(by='m_ci', ascending=False)
# df_test = df_test.reset_index(drop=True)

# total_mass = df_test['m_ci'].sum()
# df_test['cum_mass'] = df_test['m_ci'].cumsum()
# col=df_test.pop('cum_mass')
# df_test.insert(29, 'cum_mass', col) 

# n_samples= int(np.floor(len(df_test) * 0.1)) #we are taking a way smaller dataset because of this 
# n_samples= int(np.floor(len(df_test))) 
# np.random.seed(29)
# random_values = np.random.uniform(0, df_test['cum_mass'].max(), size=n_samples)
# print('Random values: ', random_values)
# # indices= np.searchsorted(df_test['cum_mass'].values, random_values)
# indices = np.clip(np.searchsorted(df_test['cum_mass'].values, random_values), 0, len(df_test) - 1)
# df_test_orig=df_test
# df_test = df_test.iloc[indices].reset_index(drop=True)
# Out:
# Last value of clon in df_test with height 36 is 2.0357769087179167
# Last value of clon in df_test with height 41 is 1.901982962125632
# Last value of clon in df_test with height 46 is 0.956579968688332
# Last value of clon in df_test with height 51 is 1.3317619703945918
# Last value of clon in df_test with height 56 is 1.3343108942333097
# Last value of clon in df_test with height 61 is 1.3343108942333097
# Last value of clon in df_test with height 66 is 1.3085211399396937
# Last value of clon in df_test with height 71 is 1.3053725942366794
# Last value of clon in df_test with height 76 is 1.294027607905691
# Last value of clon in df_test with height 81 is 1.3343108942333097
# Last value of clon in df_test with height 86 is 1.3343108942333097
# Expected length of df_test:  58141682
# Final length of df_test:  58141682
# RH out-of-range count =  0
# RH out-of-range count percent =  0.0  %

# %%
X_test = df_test[feature_names] 
y_test = df_test['qs/(qr+qs+qg)'].values 

#XGBoost
#Training is already done

##Prediction
prediction_start_time = time.time()
y_pred = model.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

print("max value of the fraction: ", np.max(y_pred))
print("min value of the fraction: ", np.min(y_pred))

count=0
for i in y_pred:
    if i>1 or i<0:
        # print(i)
        count+=1
print("Out-of-range count = ", count)
print("Out-of-range count percent = ", 100*count/len(y_pred) , " %")

y_pred = np.clip(y_pred, 0, 1)
# y_test=y_test.ravel()
# y_pred=y_pred.ravel()

#Error Analysis on TEST data
#mse
mse= np.mean((y_test- y_pred)**2)
print('MSE_Test: ', mse)

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score: ", r2_sklearn)

#Modified R2 score
# modified_r2 = modified_r_squared(y_test, y_pred, y_train)
# print("Modified R² score: ", modified_r2)
# modified_r2_curtain_list.append(modified_r2)

#weight parameter
df_test_final= df_test.loc[X_test.index]
weight = df_test_final['cell_area']*df_test_final['dzghalf']*df_test_final['air_density']*(df_test_final['qr'] + df_test_final['qs']+ df_test_final['qg']) 

#weighted RMSE
from sklearn.metrics import mean_squared_error
weighted_mse_TEST = mean_squared_error(
    y_test,
    y_pred,
    sample_weight=weight
)
weighted_rmse_TEST = np.sqrt(weighted_mse_TEST)
print(f"Weighted RMSE_TEST: {weighted_rmse_TEST}")

#Weighted MAE
from sklearn.metrics import mean_absolute_error
weighted_mae_TEST = mean_absolute_error(
    y_test,
    y_pred,
    sample_weight=weight
)
print(f"Weighted MAE_TEST: {weighted_mae_TEST}")

#weighted R^2
weighted_r2 = weighted_r_squared(y_test, y_pred, weight, y_train)
print("Weighted R² score: ", weighted_r2)

# #Store numerator and denominator values to obtain the r2 across all the curtains
# num, den = numerator_denominator_across_all_curtains(y_test, y_pred, weight, y_another_date_train)
# numerator_across_all_curtains += num
# denominator_across_all_curtains += den

total_weight_cloud_liquid_water = (df_test_final['cell_area']*df_test_final['dzghalf']*df_test_final['air_density']*(df_test_final['ql'])).sum()
total_weight_cloud_ice = (df_test_final['cell_area']*df_test_final['dzghalf']*df_test_final['air_density']*(df_test_final['qi'])).sum() 
total_weight_rain = (df_test_final['cell_area']*df_test_final['dzghalf']*df_test_final['air_density']*(df_test_final['qr'])).sum() 
total_weight_snow = (df_test_final['cell_area']*df_test_final['dzghalf']*df_test_final['air_density']*(df_test_final['qs'])).sum() 
total_weight_graupel = (df_test_final['cell_area']*df_test_final['dzghalf']*df_test_final['air_density']*(df_test_final['qg'])).sum() 


# from matplotlib.ticker import MaxNLocator

# plt.rcParams['font.family'] = 'sans-serif'
# plt.rcParams['font.sans-serif'] = ['Arial', 'DejaVu Sans']
# plt.rcParams['font.size'] = 11
# plt.rcParams['axes.linewidth'] = 1.2
# plt.rcParams['xtick.major.width'] = 1.2
# plt.rcParams['ytick.major.width'] = 1.2
# plt.rcParams['xtick.major.size'] = 5
# plt.rcParams['ytick.major.size'] = 5

# fig, ax = plt.subplots(figsize=(7, 6), dpi=300)

# #Create hexbin plot with reversed colormap (light to dark)
# #Using viridis_r for reversed viridis, or try 'YlOrRd' for yellow-orange-red
# hb = ax.hexbin(
#     # y_test.flatten(), 
#     # y_test.values, 
#     y_test, 
#     y_pred.flatten(), 
#     gridsize=40,
#     cmap='viridis_r',  # Reversed: dark (low) to bright yellow (high)
#     bins='log',
#     mincnt=1,
#     linewidths=0.2,
#     edgecolors='face'
# )

# #Add colorbar with proper formatting
# cbar = plt.colorbar(hb, ax=ax, label='Count (log$_{10}$ scale)')
# cbar.ax.tick_params(labelsize=10)

# #Calculate axis limits with padding
# data_min = min(y_test.min(), y_pred.min())
# data_max = max(y_test.max(), y_pred.max())
# padding = (data_max - data_min) * 0.05
# ax.set_xlim(data_min - padding, data_max + padding)
# ax.set_ylim(data_min - padding, data_max + padding)

# #Perfect prediction line
# ax.plot(
#     [data_min - padding, data_max + padding],
#     [data_min - padding, data_max + padding],
#     'k--',  # Black dashed line
#     lw=1.5,
#     alpha=0.7,
#     label='Perfect prediction',
#     zorder=3
# )

# #Add statistics text box
# # textstr = f'$R^2$ = {r2_sklearn:.3f}\nWeighted $R^2$ = {weighted_r2:.3f}\nRMSE = {rmse_TEST:.3f}'
# textstr = f'Weighted $R^2$ = {weighted_r2:.3f}\nRMSE = {rmse_TEST:.3f}'
# props = dict(boxstyle='round', facecolor='white', alpha=0.9, edgecolor='gray', linewidth=1)
# ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=10,
#         verticalalignment='top', bbox=props)


# ax.set_xlabel('Actual values', fontsize=12, fontweight='bold')
# ax.set_ylabel('Predicted values', fontsize=12, fontweight='bold')
# ax.set_title('XGB Prediction versus Actual Values - Test data', fontsize=13, fontweight='bold', pad=15)

# #Make axes equal and square
# ax.set_aspect('equal', adjustable='box')

# ax.grid(True, alpha=0.3, linestyle=':', linewidth=0.5, zorder=0)
# ax.legend(loc='lower right', framealpha=0.9, edgecolor='gray')

# plt.tight_layout()
# # plt.show()

# #Adding altitudes in km to df for the difference plot
# height_vals = sorted(df['height_full'].unique())      
# print("Height_vals", height_vals)      
# height_to_alt = {h: round(altitude_kms[int(h) - 40], 2) for h in height_vals}
# df['altitude_kms'] = df['height_full'].map(height_to_alt)   

# #PDF of qg values on linear scale

# fig, ax = plt.subplots(figsize=(8, 5), dpi=300)

# qg_vals = df['qg'].dropna()  

# ax.hist(
#     qg_vals,
#     bins=50,           
#     density=True,     
#     color='steelblue',
#     edgecolor='black',
#     linewidth=0.4,
#     alpha=0.8
# )

# ax.set_xlabel('qg (kg/kg)', fontsize=12, fontweight='bold')
# ax.set_ylabel('Probability Density', fontsize=12, fontweight='bold')
# ax.set_title(f'PDF of Specific Mass of Graupel (qg)\n{file_name.replace(".nc", "")}',
#             fontsize=12, fontweight='bold', pad=12)

# ax.grid(True, alpha=0.3, linestyle=':', linewidth=0.5)
# plt.tight_layout()
# plt.savefig(
#     f"../output/{output_folder_name}/PDF_qg_linear_" + file_name.replace(".nc", "") + ".png",
#     dpi=300,
#     bbox_inches="tight"
# )

# #PDF of qg values on log scale

# fig, ax = plt.subplots(figsize=(8, 5), dpi=300)

# qg_vals = df['qg'].dropna()
# qg_vals = qg_vals[qg_vals > 0] #since log of zero or negative is undefined

# if len(qg_vals) == 0:
#     print(f"No valid qg values for {file_name}, skipping PDF plot.")
#     plt.close()
# else:
#     bins = np.geomspace(qg_vals.min(), qg_vals.max(), 50)  

#     counts, bin_edges = np.histogram(qg_vals, bins=bins)

    
#     log_bin_widths = np.diff(np.log10(bin_edges))        
#     pdf = counts / (counts.sum() * log_bin_widths)       

#     ax.stairs(
#         pdf,
#         bin_edges,
#         fill=True,
#         color='steelblue',
#         edgecolor='black',
#         linewidth=0.4,
#         alpha=0.8
#     )

#     ax.set_xlabel(r'$q_g$ (kg/kg) in log$_{10}$ scale', fontsize=12, fontweight='bold')
#     # ax.set_ylabel('Probability Density', fontsize=12, fontweight='bold')
#     plt.ylabel(r'Probability Density (per log$_{10}$ unit)')
#     ax.set_title(f'PDF of Specific Mass of Graupel (qg)\n{file_name.replace(".nc", "")}',
#                 fontsize=12, fontweight='bold', pad=12)

#     ax.set_xscale('log')
#     ax.grid(True, alpha=0.3, linestyle=':', linewidth=0.5)
#     plt.tight_layout()
#     plt.savefig(
#         f"../output/{output_folder_name}/PDF_qg_" + file_name.replace(".nc", "") + ".png",
#         dpi=300,
#         bbox_inches="tight"
#     )

# #Difference plot

# #Create a dataframe of test data for ease of access
# test_df = df.loc[X_test.index, ['lat', 'altitude_kms', 'qg']].copy()
# test_df['qg_frac_true'] = y_test
# test_df['qg_frac_pred'] = y_pred

# #Set cells having qg<1e-6 to nan for better visualization (threshold from Michibata, 2024)
# graupel_mask = test_df['qg'] < 1e-6
# test_df.loc[graupel_mask, 'qg_frac_true'] = np.nan
# test_df.loc[graupel_mask, 'qg_frac_pred'] = np.nan

# # #Create a dataframe of test data for ease of access
# # test_df = df.loc[X_test.index, ['lat', 'altitude_kms']].copy()
# # test_df['qg_frac_true'] = y_test
# # test_df['qg_frac_pred'] = y_pred

# #Pivot Table to make 2D grid
# def make_pivot(df, value_col):
#     return df.sort_values(['lat', 'altitude_kms']).pivot_table(
#         index='altitude_kms', columns='lat', values=value_col
#     )

# pivot_true = make_pivot(test_df, 'qg_frac_true')
# pivot_pred = make_pivot(test_df, 'qg_frac_pred')
# pivot_diff = pivot_true - pivot_pred

# #Check to see if the pivot table has sufficient data to plot
# if pivot_true.shape[0] < 2 or pivot_true.shape[1] < 2:
#     print(f"Skipping difference plot for {file_name}: insufficient data after graupel mask (qg >= 1e-6).")
#     plt.close('all')
#     continue


# fig, axes = plt.subplots(3, 1, figsize=(14, 12))

# vmin, vmax = 0, 1

# cf1 = axes[0].contourf(pivot_true.columns, pivot_true.index, pivot_true.values,
#                         levels=np.linspace(vmin, vmax, 50), cmap='GnBu')
# plt.colorbar(cf1, ax=axes[0], label='Graupel fraction')
# # axes[0].invert_yaxis()
# axes[0].set_title('True (y_test)')

# cf2 = axes[1].contourf(pivot_pred.columns, pivot_pred.index, pivot_pred.values,
#                         levels=np.linspace(vmin, vmax, 50), cmap='GnBu')
# plt.colorbar(cf2, ax=axes[1], label='Graupel fraction')
# # axes[1].invert_yaxis()
# axes[1].set_title('Predicted (y_pred)')

# # diff_max = np.nanmax(np.abs(pivot_diff.values))
# diff_max = 1
# cf3 = axes[2].contourf(pivot_diff.columns, pivot_diff.index, pivot_diff.values,
#                         levels=np.linspace(-diff_max, diff_max, 50), cmap='RdBu_r')
# plt.colorbar(cf3, ax=axes[2], label='True - Predicted')
# # axes[2].invert_yaxis()
# axes[2].set_xlabel('Latitude') 
# axes[2].set_title('Difference (True - Predicted)')


# for ax in axes:
#     ax.set_ylabel('Altitude (km)')
#     ax.set_ylim(0, 16.1)

# # stats_text = f'$R^2$ = {r2_sklearn:.3f}\nWeighted $R^2$ = {weighted_r2:.3f}\nRMSE = {rmse_TEST:.3f}'
# stats_text = f'Weighted $R^2$ = {weighted_r2:.3f}\nRMSE = {rmse_TEST:.3f}'
# props = dict(boxstyle='round', facecolor='white', alpha=0.95, edgecolor='gray')
# axes[2].text(0.98, 0.98, stats_text, transform=axes[2].transAxes, fontsize=10,
#             verticalalignment='top', horizontalalignment='right', bbox=props)

# fig.suptitle(file_name.replace(".nc", ""), fontsize=12, fontweight='bold', y=1.01)
# plt.tight_layout()
# plt.savefig(
#     f"../output/{output_folder_name}/Graupel_fraction_comparison_" + file_name.replace(".nc", "") + ".png",
#     dpi=300,
#     bbox_inches="tight",
# )
# # plt.show()
# Out:
# Prediction- Elapsed time: 0.0372 minutes
# max value of the fraction:  1.1944193
# min value of the fraction:  -0.33227372
# Out-of-range count =  16697161
# Out-of-range count percent =  28.718056350691747  %
# MSE_Test:  0.012778332
# RMSE_TEST: 0.11304128915071487
# mae_TEST: 0.04277876019477844
# R² score:  0.9162843227386475
# Weighted RMSE_TEST: 0.11229330617506245
# Weighted MAE_TEST: 0.05677241164994613
# Weighted R² score:  0.9298657907299066

# %%
print(f"{total_weight_cloud_liquid_water:.4e}, {total_weight_cloud_ice:.4e}, {total_weight_rain:.4e}, {total_weight_snow:.4e}, {total_weight_graupel:.4e}")
# Out:
# 7.1953e+12, 1.2094e+12, 1.8382e+12, 3.2225e+12, 8.0213e+11

# %%
# #Note down R2's of the hydrometeors first and then compute the total R2
# R2_l = 
# R2_i = 
# R2_r = 
# R2_s = 
# R2_g = 

# R2_total = (
#     total_weight_cloud_liquid_water * R2_l
#     + total_weight_cloud_ice * R2_i
#     + total_weight_rain * R2_r
#     + total_weight_snow * R2_s
#     + total_weight_graupel * R2_g
# ) / (
#     total_weight_cloud_liquid_water
#     + total_weight_cloud_ice
#     + total_weight_rain
#     + total_weight_snow
#     + total_weight_graupel
# )
# print("Total Weighted R² Score:", R2_total)

# %%
#Feature importance plot
importance = model.feature_importances_

#Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

#Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

#Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)

bars = ax.barh(names, importances, color='red', edgecolor='black', linewidth=0.8)


ax.set_xlabel("Feature Importance (%)", fontsize=12, fontweight='bold')
ax.set_ylabel("Features", fontsize=12, fontweight='bold')
#ax.set_title(r"XGBoost Feature Importance: Ice-Phase Hydrometeor Fraction $\mathbf{\left(\frac{q_g}{q_s + q_g}\right)}$", 
ax.set_title(r"Feature Importances for $\mathbf{\frac{q_s}{qr +qs +qg}}$ Prediction (XGB)", 
            fontsize=13, fontweight='bold', pad=15)

ax.invert_yaxis() #Highest importance at the top

#Add percentage values on bars
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    ax.text(
        width + 1.5,
        y,
        f"{width:.2f}%",
        va="center",
        fontsize=9,
        fontweight='bold'
    )
ax.set_xlim(0, 105)

ax.grid(True, axis='x', alpha=0.3, linestyle=':', linewidth=0.5, zorder=0)

plt.tight_layout()
plt.savefig(f"../output/{output_folder_name}/FeatureImportance.png",
    dpi=300, bbox_inches='tight')

plt.show()
# Out:
# T: 72.7805 %
# ql+qi: 12.0400 %
# RH: 6.6685 %
# qr+qg+qs: 4.3226 %
# P: 1.0363 %
# upward_air_velocity: 1.0267 %
# lat: 0.7712 %
# lon: 0.6225 %
# zonal_wind: 0.4068 %
# meridional_wind: 0.3248 %

# %%
overall_end_time = time.time()
overall_elapsed_time = overall_end_time - overall_start_time
print(f"Overall Elapsed time: {overall_elapsed_time/60:.4f} minutes")
# Out:
# Overall Elapsed time: 13.3121 minutes
