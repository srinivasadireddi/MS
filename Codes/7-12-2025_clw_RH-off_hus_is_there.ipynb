# %%
#7-12-25
#clw prediction with RH off and hus is there
#12 inputs and 1 output
#Mass-weighted random sampling
#data fraction from every height = 0.001 (0.1%) before mass-weighted random sampling #0.01% after mass-weighted rand sampling
#for ht in range(36, 91, 5) 
# start_time = 1979-01-12T00:00:00 
# end_time = 1979-01-12T00:00:00 


import time
overall_start_time = time.time()
import os
import sys

import numpy as np
import pandas as pd
#%matplotlib inline  #won't work for .py
import matplotlib.pyplot as plt
import xarray as xr

# import json_file_editer as JFE
from File_management import json_file_editer as JFE
from Calculation import job_manager 
from Tools import dataset_init
from Log_management import Log

import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

#random forest
import warnings
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

warnings.filterwarnings('ignore')

#ISLP
from matplotlib.pyplot import subplots
from statsmodels.datasets import get_rdataset
import sklearn.model_selection as skm
from ISLP import load_data, confusion_table
from ISLP.models import ModelSpec as MS

from sklearn.tree import (DecisionTreeClassifier as DTC,
 DecisionTreeRegressor as DTR,
 plot_tree,
 export_text)
from sklearn.metrics import (accuracy_score,
 log_loss)
from sklearn.ensemble import \
 (RandomForestRegressor as RF,
 GradientBoostingRegressor as GBR)
from ISLP.bart import BART

#################################################################
Log.init_log(os.path.join('./output'), filename=f"Log_ML.txt")
Log.add_to_log("Log nicely initialized ")

options_json=JFE.get_json_data("options.json")
options_json["Header"]["status"]
chunks = {}
myJob = job_manager.JobManager(options_json)
ds = dataset_init.ds_init_3d(myJob, chunks={})
# Out:
# The job folder path : ./output/Log_ML.txt
# 2025 Dec 07 18:29:31 > Log nicely initialized
# 2025 Dec 07 18:29:31 > (DI0010) making data from P-O files requires small differences in the code, hardly automisable.
# 2025 Dec 07 18:29:31 > (DI0020) Starting PO dataset creation from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0001
# 2025 Dec 07 18:29:31 > (DI0021) Found 8 time-varying files in date range
# 2025 Dec 07 18:29:31 > (DI0022) Loading vertical grid data from /work/mh0066/m301130/projects/scheme_comparison/icon-mpim/build/experiments/pod0001/pod0001_atm_vgrid_ml.nc
# 2025 Dec 07 18:29:31 > (DI0023) Grid variables available: ['clon_bnds', 'clat_bnds', 'height_bnds', 'height_2_bnds', 'zghalf', 'zg', 'dzghalf', 'clon', 'clat', 'height', 'height_2']
# 2025 Dec 07 18:29:31 > (DI0024) Dimensions in vgrid: FrozenMappingWarningOnValuesAccess({'ncells': 20971520, 'vertices': 3, 'height': 60, 'bnds': 2, 'height_2': 60})
# 2025 Dec 07 18:29:31 > (DI0037) Loading horizontal grid data from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2025 Dec 07 18:29:32 > (DI0039) Successfully loaded cell areas from /pool/data/ICON/grids/public/mpim/0055/icon_grid_0055_R02B09_G.nc
# 2025 Dec 07 18:29:32 > (DI0019) Combining 5 time-varying datasets
# 2025 Dec 07 18:29:35 > (DI0018) Merging time-varying data with vertical grid data
# 2025 Dec 07 18:29:35 > (DI0017) Common dimensions: {'bnds', 'height_2', 'height', 'ncells'}
# 2025 Dec 07 18:29:36 > (DI0016) Successfully merged with vertical grid data
# 2025 Dec 07 18:29:36 > (DI0044) Merging with horizontal grid data (cell areas)
# 2025 Dec 07 18:29:36 > (DI0049) Renamed 'cell' dimension to 'ncells'
# 2025 Dec 07 18:29:36 > (DI0050) After renaming - common dimensions: {'bnds', 'height_2', 'height', 'ncells'}
# 2025 Dec 07 18:29:38 > (DI0046) Successfully merged cell area data
# 2025 Dec 07 18:29:38 > (DI0033) Selected variables: ['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi', 'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'ta', 'wa', 'rho', 'dzghalf', 'ua', 'va', 'pfull']
# 2025 Dec 07 18:29:38 > (DI0035) Final dataset shape: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2025 Dec 07 18:29:38 > (DI0036) Final dataset variables: ['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi', 'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'ta', 'wa', 'rho', 'dzghalf', 'ua', 'va', 'pfull', 'time', 'height', 'height_2']
# 2025 Dec 07 18:29:38 > (DI0100) ========== Final Dataset for scheme_comparison Information ==========
# 2025 Dec 07 18:29:38 > (DI0101) Dimensions: {'ncells': 20971520, 'time': 1, 'height': 61, 'height_2': 61}
# 2025 Dec 07 18:29:38 > (DI0102) Coordinates:
# 2025 Dec 07 18:29:38 >   clon: (20971520,) float64
# 2025 Dec 07 18:29:38 >   clat: (20971520,) float64
# 2025 Dec 07 18:29:38 >   time: (1,) datetime64[ns]
# 2025 Dec 07 18:29:38 >   height: (61,) float64
# 2025 Dec 07 18:29:38 >   height_2: (61,) float64
# 2025 Dec 07 18:29:38 > (DI0103) Data Variables:
# 2025 Dec 07 18:29:38 >   cell_area: (20971520,) float64 (ncells)
# 2025 Dec 07 18:29:38 >     Units: m2
# 2025 Dec 07 18:29:38 >     Description: area of grid cell
# 2025 Dec 07 18:29:38 >   pr: (1, 20971520) float32 (time, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg m-2 s-1
# 2025 Dec 07 18:29:38 >     Description: precipitation flux
# 2025 Dec 07 18:29:38 >   tas: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: K
# 2025 Dec 07 18:29:38 >     Description: temperature in 2m
# 2025 Dec 07 18:29:38 >   clivi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg m-2
# 2025 Dec 07 18:29:38 >     Description: cloud ice path
# 2025 Dec 07 18:29:38 >   cllvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg m-2
# 2025 Dec 07 18:29:38 >     Description: cloud liquid water path
# 2025 Dec 07 18:29:38 >   qgvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg m-2
# 2025 Dec 07 18:29:38 >     Description: graupel path
# 2025 Dec 07 18:29:38 >   qrvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg m-2
# 2025 Dec 07 18:29:38 >     Description: rain path
# 2025 Dec 07 18:29:38 >   qsvi: (1, 20971520) float32 (time, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg m-2
# 2025 Dec 07 18:29:38 >     Description: snow path
# 2025 Dec 07 18:29:38 >   clw: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg kg-1
# 2025 Dec 07 18:29:38 >     Description: specific cloud water content
# 2025 Dec 07 18:29:38 >   cli: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg kg-1
# 2025 Dec 07 18:29:38 >     Description: specific cloud ice content
# 2025 Dec 07 18:29:38 >   qr: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg kg-1
# 2025 Dec 07 18:29:38 >     Description: specific rain content
# 2025 Dec 07 18:29:38 >   qg: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg kg-1
# 2025 Dec 07 18:29:38 >     Description: specific graupel content
# 2025 Dec 07 18:29:38 >   qs: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg kg-1
# 2025 Dec 07 18:29:38 >     Description: specific snow content
# 2025 Dec 07 18:29:38 >   hus: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg kg-1
# 2025 Dec 07 18:29:38 >     Description: Specific humidity
# 2025 Dec 07 18:29:38 >   ta: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: K
# 2025 Dec 07 18:29:38 >     Description: Temperature
# 2025 Dec 07 18:29:38 >   wa: (1, 61, 20971520) float32 (time, height_2, ncells)
# 2025 Dec 07 18:29:38 >     Units: m s-1
# 2025 Dec 07 18:29:38 >     Description: Vertical velocity
# 2025 Dec 07 18:29:38 >   rho: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: kg m-3
# 2025 Dec 07 18:29:38 >     Description: density
# 2025 Dec 07 18:29:38 >   dzghalf: (61, 20971520) float32 (height, ncells)
# 2025 Dec 07 18:29:38 >     Units: -
# 2025 Dec 07 18:29:38 >     Description: metrics functional determinant
# 2025 Dec 07 18:29:38 >   ua: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: m s-1
# 2025 Dec 07 18:29:38 >     Description: Zonal wind
# 2025 Dec 07 18:29:38 >   va: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: m s-1
# 2025 Dec 07 18:29:38 >     Description: Meridional wind
# 2025 Dec 07 18:29:38 >   pfull: (1, 61, 20971520) float32 (time, height, ncells)
# 2025 Dec 07 18:29:38 >     Units: Pa
# 2025 Dec 07 18:29:38 >     Description: Pressure
# 2025 Dec 07 18:29:38 > (DI0104) Estimated memory usage: 67.66 GB
# 2025 Dec 07 18:29:38 > (DI0105) Time range: 1979-01-12T00:00:00.000000000 to 1979-01-12T00:00:00.000000000 (1 steps)
# 2025 Dec 07 18:29:38 > (DI0107) ========== End Final Dataset for scheme_comparison Information ==========

# %%
seed = 1
sample_frac = 0.001

ht=31
data=ds.sel(height=ht, height_2=ht) 

total = data['clw'] + data['cli']
data['clw/(clw+cli)'] = data['clw'].where(total != 0, 0) / total.where(total != 0, 1)
data['cli/(clw+cli)'] = data['cli'].where(total != 0, 0) / total.where(total != 0, 1)

total_precipitates = data['qr'] + data['qs']+ data['qg']
data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

# %%
df = data.to_dataframe() #.sample(frac=1, random_state=seed) #frac=sample_frac

# %%
# df = data.to_dataframe().sample(frac=sample_frac, random_state=seed)

dfs = [df]  
# for ht in range(32, 91, 5): #(32, 91, 5)
for ht in range(36, 91, 5): #(32, 91, 5)
    data = ds.sel(height=ht, height_2=ht)

    total = data['clw'] + data['cli']
    data['clw/(clw+cli)'] = data['clw'].where(total != 0, 0) / total.where(total != 0, 1)
    data['cli/(clw+cli)'] = data['cli'].where(total != 0, 0) / total.where(total != 0, 1)

    total_precipitates = data['qr'] + data['qs']+ data['qg']
    data['qr/(qr+qs+qg)'] = data['qr'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qs/(qr+qs+qg)'] = data['qs'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)
    data['qg/(qr+qs+qg)'] = data['qg'].where(total_precipitates != 0, 0) / total_precipitates.where(total_precipitates != 0, 1)

    df_sampled=data.to_dataframe() #.sample(frac=1, random_state= seed+ht) #frac=sample_frac
    dfs.append(df_sampled) 
    print(f"Last value of clon in df with height {ht} is", df_sampled['clon'].iloc[-1])

df = pd.concat(dfs, ignore_index=True)

# print('length of dfs: ',len(dfs))
# print('len of dfs[0]: ', len(dfs[0]))
prod= len(dfs[0]) * len(dfs)
print("Expected length of df: ", prod)
print('Final length of df: ', len(df))
# Out:
# Last value of clon in df with height 36 is 1.3343108942333097
# Last value of clon in df with height 41 is 1.3343108942333097
# Last value of clon in df with height 46 is 1.3343108942333097
# Last value of clon in df with height 51 is 1.3343108942333097
# Last value of clon in df with height 56 is 1.3343108942333097
# Last value of clon in df with height 61 is 1.3343108942333097
# Last value of clon in df with height 66 is 1.3343108942333097
# Last value of clon in df with height 71 is 1.3343108942333097
# Last value of clon in df with height 76 is 1.3343108942333097
# Last value of clon in df with height 81 is 1.3343108942333097
# Last value of clon in df with height 86 is 1.3343108942333097
# Expected length of df:  251658240
# Final length of df:  251658240

# %%
threshold = 5e-12
df_new = df[(df['cli'] + df['clw'] + df['qr'] + df['qg'] + df['qs']) >= threshold]
# print('df- After threshold-1:')
# print(df_new)
if df_new.empty:
    df_new = df

df = df_new
# print('df after threshold-2:\n', df)

# %%
#RH from SH
def RH_from_SH(pfull, hus, ta, T_0= 273.16):
    RH = 0.26 * pfull * hus / np.exp(17.67 * (ta - T_0) / (ta - 29.65))
    return RH

# %%
df['RH']=RH_from_SH(df['pfull'], df['hus'], df['ta'])

# %%
count=0
for i in df['RH']:
    if i>100 or i<0:
        count+=1
print("incorrect count = ", count)
print("incorrect count percent = ", 100*count/len(df['RH']))
# Out:
# incorrect count =  600516
# incorrect count percent =  0.9964409504582096

# %%
df['RH']= df['RH'].clip(lower=0, upper=100)

# %%
df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2',
#        'clw/(clw+cli)', 'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)',
#        'qg/(qr+qs+qg)', 'RH'],
#       dtype='object')

# %%
col=df.pop('RH')
df.insert(16, 'RH', col) #hus is at 15th position
#df.pop('hus')

df['clw+cli']=df['clw']+df['cli']

col=df.pop('clw+cli')
df.insert(26, 'clw+cli', col) 

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'clw/(clw+cli)', 'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)',
#        'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
#Include 'cloud liquid water path + cloud ice path' as a feature.

df['cllvi+clivi']=df['cllvi']+df['clivi']

col=df.pop('cllvi+clivi')
df.insert(27, 'cllvi+clivi', col) 

# df.to_csv("df.csv", index=False)
df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'clw/(clw+cli)', 'cli/(clw+cli)', 'qr/(qr+qs+qg)',
#        'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
# m_ci_j=dzghalf*rho*cell_area*(clw+cli)

#NOte df['m_ci'] actually refers to mass of clw+cli+qr+qg+qs

df['m_ci']=df['dzghalf']*df['rho']*df['cell_area']* (df['clw']+df['cli'])

col=df.pop('m_ci')
df.insert(28, 'm_ci', col) 

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'clw/(clw+cli)', 'cli/(clw+cli)',
#        'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
df = df.sort_values(by='m_ci', ascending=False)
df
# Out:
#                clon      clat     cell_area            pr  tas         clivi  \
# 173018403  1.264630  0.200923  2.519046e+07  2.310373e-02  NaN  4.870968e-02
# 178331472  0.825232 -0.056076  2.449930e+07  5.511520e-03  NaN  9.715237e-02
# 178357692  0.876807 -0.026469  2.462740e+07  2.554483e-03  NaN  3.428403e-02
# 173127265  1.057304  0.014077  2.504704e+07  1.274372e-04  NaN  3.352847e-02
# 173888996  2.391355  0.154133  2.512132e+07  2.953777e-04  NaN  1.094382e+00
# ...             ...       ...           ...           ...  ...           ...
# 165690009  2.962672 -0.779177  2.447760e+07  2.600152e-04  NaN  9.714869e-13
# 190111978  2.552930  1.139143  2.483062e+07  8.775741e-07  NaN  1.052750e-04
# 130791420 -0.052830  0.641521  2.485616e+07 -3.575020e-11  NaN  3.850443e-03
# 172180428 -0.081149  0.772181  2.503839e+07  3.858223e-23  NaN  1.086859e-11
# 117791307 -0.941300 -0.248711  2.459375e+07 -9.067990e-10  NaN  7.719256e-05
#
#                cllvi          qgvi          qrvi          qsvi  ...  height  \
# 173018403  12.394000  1.291498e-02  3.781074e+00  4.946395e-02  ...    71.0
# 178331472   9.922813  3.872866e-01  6.738925e-01  2.041255e+00  ...    71.0
# 178357692  12.130489  2.575640e-01  7.173981e-01  1.736938e+00  ...    71.0
# 173127265   7.683826  1.751549e-02  1.452845e+00  3.264293e-01  ...    71.0
# 173888996  13.368296  1.342168e+00  9.153035e-02  2.658636e-01  ...    71.0
# ...              ...           ...           ...           ...  ...     ...
# 165690009   0.096638  6.952541e-03  3.750780e-02  2.008666e-02  ...    66.0
# 190111978   0.000000  2.257420e-06  4.948886e-13  5.412655e-04  ...    76.0
# 130791420   0.000000  5.758945e-02  2.932783e-03  8.455849e-02  ...    61.0
# 172180428   0.000000  4.168618e-13  1.318311e-13  3.174403e-09  ...    71.0
# 117791307   0.443900  7.608230e-03  1.934370e-05  1.995408e-04  ...    56.0
#
#            height_2   clw+cli   cllvi+clivi          m_ci  clw/(clw+cli)  \
# 173018403      71.0  0.006901  1.244271e+01  4.725382e+07            1.0
# 178331472      71.0  0.006849  1.001997e+01  4.586084e+07            1.0
# 178357692      71.0  0.006236  1.216477e+01  4.202169e+07            1.0
# 173127265      71.0  0.005629  7.717355e+00  3.837297e+07            1.0
# 173888996      71.0  0.005447  1.446268e+01  3.725688e+07            1.0
# ...             ...       ...           ...           ...            ...
# 165690009      66.0  0.000000  9.663792e-02  0.000000e+00            0.0
# 190111978      76.0  0.000000  1.052750e-04  0.000000e+00            0.0
# 130791420      61.0  0.000000  3.850443e-03  0.000000e+00            0.0
# 172180428      71.0  0.000000  1.086859e-11  0.000000e+00            0.0
# 117791307      56.0  0.000000  4.439768e-01  0.000000e+00            0.0
#
#            cli/(clw+cli)  qr/(qr+qs+qg)  qs/(qr+qs+qg)  qg/(qr+qs+qg)
# 173018403   1.659342e-11   9.999998e-01   8.197219e-11   2.700181e-07
# 178331472   6.750338e-13   9.531906e-01   3.427915e-04   4.646663e-02
# 178357692   4.198563e-14   9.651676e-01   2.995607e-02   4.876297e-03
# 173127265   5.658931e-14   1.000000e+00   3.799317e-13   4.257812e-09
# 173888996   2.321638e-14   1.000000e+00   7.289859e-11   2.218930e-16
# ...                  ...            ...            ...            ...
# 165690009   0.000000e+00   5.571829e-06   9.999944e-01   1.291128e-12
# 190111978   0.000000e+00   8.630832e-07   9.999991e-01   0.000000e+00
# 130791420   0.000000e+00   3.920931e-10   1.000000e+00   5.089654e-10
# 172180428   0.000000e+00   9.984026e-07   9.999990e-01   8.604236e-09
# 117791307   0.000000e+00   6.861970e-12   1.000000e+00   2.993956e-11
#
# [60266090 rows x 34 columns]

# %%
df = df.reset_index(drop=True)
df['m_ci']
# Out:
# 0           4.725382e+07
# 1           4.586084e+07
# 2           4.202169e+07
# 3           3.837297e+07
# 4           3.725688e+07
#                 ...
# 60266085    0.000000e+00
# 60266086    0.000000e+00
# 60266087    0.000000e+00
# 60266088    0.000000e+00
# 60266089    0.000000e+00
# Name: m_ci, Length: 60266090, dtype: float64

# %%
total_mass = df['m_ci'].sum()
total_mass #kg #prevsly: np.float64(6506367837186.283)
# Out:
# np.float64(12708451574497.826)

# %%
df['cum_mass'] = df['m_ci'].cumsum()

col=df.pop('cum_mass')
df.insert(29, 'cum_mass', col) 

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'cum_mass', 'clw/(clw+cli)', 'cli/(clw+cli)',
#        'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
#Adding another column; qr+qg+qs and use it later as an input feature

df['qr+qg+qs'] = df['qr'] + df['qg'] + df['qs']

col=df.pop('qr+qg+qs')
df.insert(30, 'qr+qg+qs', col)

df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'cum_mass', 'qr+qg+qs', 'clw/(clw+cli)',
#        'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
n_samples= int(np.floor(len(df) * 0.1)) #we are taking a way smaller dataset because of this 
# n_samples= int(np.floor(len(df))) 
np.random.seed(29)

random_values = np.random.uniform(0, total_mass, size=n_samples)

print('Random values: ', random_values)

indices= np.searchsorted(df['cum_mass'].values, random_values)

df_orig=df

df = df.iloc[indices].reset_index(drop=True)
# Out:
# Random values:  [1.09770519e+13 3.62071366e+12 9.30975260e+11 ... 7.07288734e+12
#  8.75907370e+12 3.30531817e+12]

# %%
df.columns #RH is at index 16 originally
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'RH', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'cum_mass', 'qr+qg+qs', 'clw/(clw+cli)',
#        'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
df.pop('RH')
# Out:
# 0          70.365059
# 1          99.156296
# 2          97.107628
# 3          99.672958
# 4          99.708252
#              ...
# 6026604    99.346764
# 6026605    99.642548
# 6026606    99.837761
# 6026607    99.880440
# 6026608    99.217064
# Name: RH, Length: 6026609, dtype: float32

# %%
df.columns
# Out:
# Index(['clon', 'clat', 'cell_area', 'pr', 'tas', 'clivi', 'cllvi', 'qgvi',
#        'qrvi', 'qsvi', 'clw', 'cli', 'qr', 'qg', 'qs', 'hus', 'ta', 'wa',
#        'rho', 'dzghalf', 'ua', 'va', 'pfull', 'height', 'height_2', 'clw+cli',
#        'cllvi+clivi', 'm_ci', 'cum_mass', 'qr+qg+qs', 'clw/(clw+cli)',
#        'cli/(clw+cli)', 'qr/(qr+qs+qg)', 'qs/(qr+qs+qg)', 'qg/(qr+qs+qg)'],
#       dtype='object')

# %%
X = df.iloc[:, [0,1,15,16,17,20,21,22,25,26,29]].values 

y = df.iloc[:, [-5]].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

cols= [0,1,15,16,17,20,21,22,25,26,29]
feature_names=df.columns[cols].tolist()
print(feature_names)
# Out:
# ['clon', 'clat', 'hus', 'ta', 'wa', 'ua', 'va', 'pfull', 'clw+cli', 'cllvi+clivi', 'qr+qg+qs']

# %% [markdown]
# XGB

# %%
# best_parameters= grid_search.best_params_

best_n_estimators=100 #best_parameters['n_estimators']
best_min_child_weight=30 #best_parameters['min_child_weight']
best_max_depth=10 #best_parameters['max_depth']
best_learning_rate=0.1 #best_parameters['learning_rate']

# %%
#XGBoost

# fit model
model = XGBRegressor(n_estimators=best_n_estimators, min_child_weight= best_min_child_weight, max_depth=best_max_depth, learning_rate=best_learning_rate, n_jobs=-1, random_state=0) #verbosity=3 (optional)

##Training
training_start_time = time.time()
model.fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

##Prediction
prediction_start_time = time.time()
y_pred = model.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
# Out:
# Training- Elapsed time: 0.1414 minutes
# Prediction- Elapsed time: 0.0019 minutes

# %%
print("max: ", np.max(y_pred))
print("min: ", np.min(y_pred))
# Out:
# max:  1.2575046
# min:  -0.17246407

# %%
y_pred = np.clip(y_pred, 0, 1)

y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
#Error Analysis on TEST data
#mse
mse= np.mean((y_test- y_pred)**2)
print('MSE_Test: ', mse)

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score: ", r2_sklearn)
# Out:
# MSE_Test:  0.00040755325
# RMSE_TEST: 0.020187947899103165
# mae_TEST: 0.0015912509988993406
# R² score:  0.9944741725921631

# %%
import matplotlib.pyplot as plt

# ---- Your existing logic ----
importance = model.feature_importances_

# Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

# Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Cloud\ water\ fraction}$ determination using $\mathbf{XGBoost}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis range
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# hus: 91.5684 %
# ta: 4.8876 %
# clw+cli: 2.4734 %
# qr+qg+qs: 0.4927 %
# wa: 0.1398 %
# pfull: 0.1386 %
# clat: 0.0736 %
# cllvi+clivi: 0.0722 %
# clon: 0.0639 %
# ua: 0.0497 %
# va: 0.0403 %

# %%
plt.figure(figsize=(8,6))
plt.hexbin(
    y_test.flatten(), 
    y_pred.flatten(), 
    gridsize=40,  # smaller → finer grid
    cmap='viridis', 
    bins='log'  # logarithmic scaling helps emphasize dense areas
)
plt.colorbar(label='log10(N)')
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color='red', lw=2
)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (XGB)")
plt.show()

# %%
ruko yaha!

# %% [markdown]
# MLR

# %%
#continue from here
#overall MLR code
X = df.iloc[:, [0,1,15,16,17,20,21,22,25,26,29]].values 
# X = df.iloc[:, [15,16,17,18,21,22,23,26,27,30]].values 
y = df.iloc[:, [-5]].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)
cols= [0,1,15,16,17,20,21,22,25,26,29]
feature_names=df.columns[cols].tolist()

from sklearn import linear_model

regr=linear_model.LinearRegression()
regr.fit(X_train,y_train)

y_predicted = regr.predict(X_test)
y_predicted = np.clip(y_predicted, 0, 1)

#Error Analysis on TEST data
#MSE_test
mse_TEST= np.mean((y_test- y_predicted)**2)
print(f'MSE_TEST: {mse_TEST}')

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_predicted)**2))
print(f'RMSE_TEST: {rmse_TEST}')
# print(f'MSE_TEST: {(rmse_TEST)**2}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_predicted))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_predicted)
print("R² score:", r2_sklearn)

#Coefficient
coef_list= regr.coef_[0]

coef_table = pd.DataFrame(
{
    'Feature': feature_names,
    'Coefficient': coef_list
}
)

#Sort by absolute coeff val

coef_table['abs(Coefficient)'] = coef_table['Coefficient'].abs()
coef_table.sort_values(by='abs(Coefficient)', ascending=False, inplace=True)
print(coef_table)
# Out:
# MSE_TEST: 0.009349066402933107
# RMSE_TEST: 0.09669057039304871
# mae_TEST: 0.03597740222021983
# R² score: 0.8732399505021009
#         Feature  Coefficient  abs(Coefficient)
# 11     qr+qg+qs    32.376954         32.376954
# 9       clw+cli    27.780402         27.780402
# 2           hus     7.531663          7.531663
# 3            RH     0.031721          0.031721
# 5            wa    -0.026905          0.026905
# 1          clat    -0.017129          0.017129
# 10  cllvi+clivi     0.006058          0.006058
# 4            ta    -0.002442          0.002442
# 7            va     0.000476          0.000476
# 0          clon     0.000149          0.000149
# 6            ua    -0.000049          0.000049
# 8         pfull     0.000001          0.000001

# %%
pairs = [(name, abs(coef)) for name, coef in zip(feature_names, coef_list)]
pairs.sort(key=lambda x: x[1], reverse=True)

for name, coef in pairs:
    print(f"{name}:{coef:.6f}")
# Out:
# qr+qg+qs:32.376954
# clw+cli:27.780402
# hus:7.531663
# RH:0.031721
# wa:0.026905
# clat:0.017129
# cllvi+clivi:0.006058
# ta:0.002442
# va:0.000476
# clon:0.000149
# ua:0.000049
# pfull:0.000001

# %%
pairs = [(name, abs(coef)) for name, coef in zip(feature_names, coef_list)]
total = sum(c for _, c in pairs)

pairs.sort(key=lambda x: x[1], reverse=True)

for name, coef in pairs:
    pct = (coef / total) * 100   #normalized percentage
    print(f"{name}: {pct:.4f} %")
# Out:
# qr+qg+qs: 47.7720 %
# clw+cli: 40.9898 %
# hus: 11.1129 %
# RH: 0.0468 %
# wa: 0.0397 %
# clat: 0.0253 %
# cllvi+clivi: 0.0089 %
# ta: 0.0036 %
# va: 0.0007 %
# clon: 0.0002 %
# ua: 0.0001 %
# pfull: 0.0000 %

# %%
pairs = [(name, abs(coef)) for name, coef in zip(feature_names, coef_list)]
total = sum(c for _, c in pairs)

#Sort by importance (descending)
pairs.sort(key=lambda x: x[1], reverse=True)

names = []
importances = []

for name, coef in pairs:
    pct = (coef / total) * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

#Bar plot
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")

#Modify title accordingly
plt.title(r"$\mathbf{Cloud\ water\ fraction}$ determination using $\mathbf{Multi\ Linear\ Regression}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of bars
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,        #small space after the bar
        y,
        f"{width:.2f}%",
        va="center"
    )

plt.xlim(0, 100)
plt.tight_layout()
plt.show()
# Out:
# qr+qg+qs: 47.7720 %
# clw+cli: 40.9898 %
# hus: 11.1129 %
# RH: 0.0468 %
# wa: 0.0397 %
# clat: 0.0253 %
# cllvi+clivi: 0.0089 %
# ta: 0.0036 %
# va: 0.0007 %
# clon: 0.0002 %
# ua: 0.0001 %
# pfull: 0.0000 %

# %%
# import seaborn as sns

# plt.figure(figsize=(8,6))
# sns.scatterplot(x=y_test.flatten(), y=y_predicted.flatten(), alpha=0.7)
# plt.xlabel("Actual Values")
# plt.ylabel("Predicted Values")
# plt.title("Actual vs Predicted Values (MLR)")
# # Add a perfect prediction line
# plt.plot([y_test.min(), y_test.max()],
#          [y_test.min(), y_test.max()],
#          color='red', lw=2)
# plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hexbin(
    y_test.flatten(), 
    y_predicted.flatten(), 
    gridsize=40,  # smaller → finer grid
    cmap='viridis', 
    bins='log'  # logarithmic scaling helps emphasize dense areas
)
plt.colorbar(label='log10(N)')
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color='red', lw=2
)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (MLR)")
plt.show()

# %%
##ft 16 ('RH') and -5 ('clw/(clw+cli)')
# df['RH']

# %%
df['clw/(clw+cli)']
# Out:
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 6026604    1.0
# 6026605    1.0
# 6026606    1.0
# 6026607    1.0
# 6026608    1.0
# Name: clw/(clw+cli), Length: 6026609, dtype: float32

# %%
# plt.plot(df['RH'], df['clw/(clw+cli)']) #error in plotting probably because of huge size of data

# %%
plt.scatter(df['RH'][::100], df['clw/(clw+cli)'][::100], s=2)
plt.xlabel("RH")
plt.ylabel("clw / (clw + cli)")
plt.title("Scatter Plot: RH vs clw/(clw+cli)")
plt.show()

# %%
plt.scatter(df['RH'][::100], df['clw/(clw+cli)'][::100], s=2)
plt.xlim(95,100)
plt.xlabel("RH")
plt.ylabel("clw / (clw + cli)")
plt.title("Scatter Plot: RH vs clw/(clw+cli)")
plt.show()

# %%
plt.hexbin(
    df['RH'][::100],
    df['clw/(clw+cli)'][::100],
    gridsize=60,    # adjust resolution (smaller = finer)
    cmap='viridis', # color map
    bins='log'      # use log scale for density
)
plt.colorbar(label='log10(N points)')
# plt.xlim(95, 100)
plt.xlabel("RH")
plt.ylabel("clw / (clw + cli)")
plt.title("Hexbin Density Plot: clw/(clw+cli) vs RH")
plt.show()

# %%
#clw frac v/s ta
plt.hexbin(
    df['ta'][::100],
    df['clw/(clw+cli)'][::100],
    gridsize=60,    # adjust resolution (smaller = finer)
    cmap='viridis', # color map
    bins='log'      # use log scale for density
)
plt.colorbar(label='log10(N points)')
# plt.xlim(95, 100)
plt.xlabel("temperature")
plt.ylabel("clw / (clw + cli)")
plt.title("Hexbin Density Plot: clw/(clw+cli) vs ta")
plt.show()

# %%
#clw frac v/s ta
plt.hexbin(
    df['ta'][::100],
    df['clw/(clw+cli)'][::100],
    gridsize=60,    # adjust resolution (smaller = finer)
    cmap='viridis', # color map
    bins='log'      # use log scale for density
)
plt.colorbar(label='log10(N points)')
plt.xlim(260, 280)
plt.xlabel("temperature")
plt.ylabel("clw / (clw + cli)")
plt.title("Hexbin Density Plot: ta vs clw/(clw+cli)")
plt.show()

# %%
# print("Description of the df:\n")
# print(df[['cli', 'clw', 'qr', 'qg', 'qs']].describe())
# print(df[['cli', 'clw', 'qr', 'qg', 'qs']].isna().sum())
# print("Description ends\n")

# split data into X and y
# X = df.iloc[:, [15,16]].values # RH, ta
X = df.iloc[:, [0,1,15,16,17,20,21,22,25,26,29]].values 

y = df.iloc[:, [-5]].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

cols= [0,1,15,16,17,20,21,22,25,26,29]
feature_names=df.columns[cols].tolist()
print(feature_names)
# Out:
# ['clon', 'clat', 'hus', 'RH', 'ta', 'wa', 'ua', 'va', 'pfull', 'clw+cli', 'cllvi+clivi', 'qr+qg+qs']

# %%
#This is df and not X_train
# print('RH min: ', df['RH'].min())
# print('RH max: ', df['RH'].max())
# print('\n')
print('ta min: ', df['ta'].min())
print('ta max: ', df['ta'].max())
print('\n')
print('pfull min: ', df['pfull'].min())
print('pfull max: ', df['pfull'].max())
print('\n')
print('wa min: ', df['wa'].min())
print('wa max: ', df['wa'].max())
print('\n')
# Out:
# ta min:  181.94577
# ta max:  298.29633
#
#
# pfull min:  11028.059
# pfull max:  99298.86
#
#
# wa min:  -5.7521772
# wa max:  27.104033

# %%
print(len(y_train))
print(len(y_test))
# Out:
# 4821287
# 1205322

# %% [markdown]
# Decision Tree

# %%
# # #Medium
# # #Use Cross-Validation
# # #best depth acc. to val data

# train_r2_scores=[]
# val_r2_scores=[]
# depths=range(1,11) #This seemed a reasonable depth range which is obtained from trial and error and articles online
# for depth in depths:
#     tree=DTR(max_depth=depth, random_state=1)
#     #train
#     tree.fit(X_train,y_train)
#     train_score=tree.score(X_train, y_train)
#     train_r2_scores.append(train_score)
#     # print(f"Depth {depth}: Training R2 score = {train_score} ") 

#     #val
    
#     val_scores= cross_val_score(tree, X_train, y_train, cv=5, scoring='r2')
#     # print(f"Depth {depth}: Mean Validation R2 score = {val_scores.mean()} ") #val_scores.mean(): .4f
#     val_r2_scores.append(val_scores.mean())

# #print(type(val_scores)) #<class 'numpy.ndarray'>
# #print(val_scores)
# max_val_r2_score=max(val_r2_scores)
# bestDepth=depths[val_r2_scores.index(max_val_r2_score)]
# print(f"\nMax. Validation R2 score: {max_val_r2_score} is at depth (bestDepth): {bestDepth}") #Validation R2 score is different from Test R2 score

# #Plotting
# plt.figure() #figsize=(8,5)
# plt.plot(depths, train_r2_scores, marker='o', label='Training R2')
# plt.plot(depths, val_r2_scores, marker='s', label='Validation R2')
# plt.xlabel("Tree Depth")
# plt.ylabel("R2 score")
# plt.title("Decision Tree Performance vs Depth")
# plt.legend()
# plt.grid(True)
# plt.show()

# #time taken = 64 mins 51 seconds

# %%
# #to find the best Depth and the best number of min samples in leaf
# depths = range(1, 11) #range(1, 21)
# min_samples_in_leaf = range(1, 41) #range(1,51)

# train_r2_scores = []
# val_r2_scores = []
# param_combinations = []

# best_val_score = -np.inf
# best_depth = None
# best_min_samples_leaf = None

# for depth in depths:
#     for min_samples in min_samples_in_leaf:
#         tree = DTR(max_depth=depth, min_samples_leaf=min_samples, random_state=1)

#         tree.fit(X_train, y_train)
#         train_score = tree.score(X_train, y_train)
      
#         val_scores = cross_val_score(tree, X_train, y_train, cv=5, scoring='r2')
#         val_mean = val_scores.mean()
       
#         train_r2_scores.append(train_score)
#         val_r2_scores.append(val_mean)
#         param_combinations.append((depth, min_samples))

#         if val_mean > best_val_score:
#             best_val_score = val_mean
#             best_depth = depth
#             best_min_samples_leaf = min_samples

# print(f"\nBest Validation R2 Score: {best_val_score: }")
# print(f"Best Parameters: max_depth={best_depth}, min_samples_leaf={best_min_samples_leaf}")

# #took 48 mins to run
# #eg: max_depth=14, min_samples_leaf=40

# %%
# #Plot

# param_combinations = np.array(param_combinations)
# depths_arr = param_combinations[:, 0]
# min_samples_arr = param_combinations[:, 1]
# val_r2_scores = np.array(val_r2_scores)


# plt.figure(figsize=(10, 6))
# plt.tricontourf(depths_arr, min_samples_arr, val_r2_scores, levels=20, cmap='viridis')
# plt.colorbar(label="Mean CV (Validation) R2 Score")
# plt.xlabel("Tree Depth")
# plt.ylabel("Min Samples in Leaf")
# plt.title("Decision Tree Cross-Validation Performance Grid Search")
# plt.show()

# %%
#Pathway-1
best_depth= 10 #14
best_min_samples_leaf=30 #40

reg=DTR(max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, random_state=0)

##Training
training_start_time = time.time()
reg.fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

ax=subplots(figsize=(12,12))[1]
plot_tree(reg, feature_names=feature_names, ax=ax)
# Out:
# Training- Elapsed time: 1.7956 minutes
# [Text(0.2778962146422629, 0.9545454545454546, 'RH <= 96.495\nsquared_error = 0.074\nsamples = 4821287\nvalue = 0.919'),
#  Text(0.12281613976705491, 0.8636363636363636, 'ta <= 268.89\nsquared_error = 0.012\nsamples = 386954\nvalue = 0.012'),
#  Text(0.2003561772046589, 0.9090909090909092, 'True  '),
#  Text(0.0834026622296173, 0.7727272727272727, 'RH <= 95.198\nsquared_error = 0.003\nsamples = 383464\nvalue = 0.004'),
#  Text(0.04679700499168053, 0.6818181818181818, 'ta <= 265.683\nsquared_error = 0.001\nsamples = 379212\nvalue = 0.002'),
#  Text(0.03036605657237937, 0.5909090909090909, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 377818\nvalue = 0.001'),
#  Text(0.02870216306156406, 0.5, 'squared_error = 0.247\nsamples = 31\nvalue = 0.451'),
#  Text(0.032029950083194675, 0.5, 'RH <= 92.855\nsquared_error = 0.001\nsamples = 377787\nvalue = 0.001'),
#  Text(0.018302828618968387, 0.4090909090909091, 'ta <= 264.093\nsquared_error = 0.0\nsamples = 370395\nvalue = 0.0'),
#  Text(0.010815307820299502, 0.3181818181818182, 'ta <= 259.503\nsquared_error = 0.0\nsamples = 369565\nvalue = 0.0'),
#  Text(0.0066555740432612314, 0.22727272727272727, 'ta <= 254.67\nsquared_error = 0.0\nsamples = 360478\nvalue = 0.0'),
#  Text(0.0033277870216306157, 0.13636363636363635, 'RH <= 91.345\nsquared_error = 0.0\nsamples = 333009\nvalue = 0.0'),
#  Text(0.0016638935108153079, 0.045454545454545456, 'squared_error = 0.0\nsamples = 331843\nvalue = 0.0'),
#  Text(0.004991680532445923, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1166\nvalue = 0.003'),
#  Text(0.009983361064891847, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 27469\nvalue = 0.001'),
#  Text(0.008319467554076539, 0.045454545454545456, 'squared_error = 0.111\nsamples = 54\nvalue = 0.137'),
#  Text(0.011647254575707155, 0.045454545454545456, 'squared_error = 0.0\nsamples = 27415\nvalue = 0.001'),
#  Text(0.014975041597337771, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.003\nsamples = 9087\nvalue = 0.005'),
#  Text(0.013311148086522463, 0.13636363636363635, 'squared_error = 0.185\nsamples = 32\nvalue = 0.253'),
#  Text(0.016638935108153077, 0.13636363636363635, 'pfull <= 85435.711\nsquared_error = 0.002\nsamples = 9055\nvalue = 0.004'),
#  Text(0.014975041597337771, 0.045454545454545456, 'squared_error = 0.001\nsamples = 8171\nvalue = 0.001'),
#  Text(0.018302828618968387, 0.045454545454545456, 'squared_error = 0.013\nsamples = 884\nvalue = 0.026'),
#  Text(0.025790349417637273, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.025\nsamples = 830\nvalue = 0.039'),
#  Text(0.021630615640599003, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.139\nsamples = 87\nvalue = 0.234'),
#  Text(0.019966722129783693, 0.13636363636363635, 'squared_error = 0.078\nsamples = 57\nvalue = 0.129'),
#  Text(0.02329450915141431, 0.13636363636363635, 'squared_error = 0.195\nsamples = 30\nvalue = 0.432'),
#  Text(0.029950083194675542, 0.22727272727272727, 'pfull <= 84608.539\nsquared_error = 0.007\nsamples = 743\nvalue = 0.017'),
#  Text(0.026622296173044926, 0.13636363636363635, 'wa <= 0.057\nsquared_error = 0.001\nsamples = 600\nvalue = 0.003'),
#  Text(0.024958402662229616, 0.045454545454545456, 'squared_error = 0.0\nsamples = 498\nvalue = 0.0'),
#  Text(0.028286189683860232, 0.045454545454545456, 'squared_error = 0.006\nsamples = 102\nvalue = 0.016'),
#  Text(0.033277870216306155, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.026\nsamples = 143\nvalue = 0.074'),
#  Text(0.03161397670549085, 0.045454545454545456, 'squared_error = 0.037\nsamples = 79\nvalue = 0.12'),
#  Text(0.03494176372712146, 0.045454545454545456, 'squared_error = 0.006\nsamples = 64\nvalue = 0.017'),
#  Text(0.045757071547420966, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.017\nsamples = 7392\nvalue = 0.023'),
#  Text(0.04159733777038269, 0.3181818181818182, 'pfull <= 94162.184\nsquared_error = 0.01\nsamples = 7330\nvalue = 0.016'),
#  Text(0.03826955074875208, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.006\nsamples = 7077\nvalue = 0.009'),
#  Text(0.036605657237936774, 0.13636363636363635, 'squared_error = 0.191\nsamples = 40\nvalue = 0.272'),
#  Text(0.03993344425956739, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.005\nsamples = 7037\nvalue = 0.007'),
#  Text(0.03826955074875208, 0.045454545454545456, 'squared_error = 0.05\nsamples = 364\nvalue = 0.069'),
#  Text(0.04159733777038269, 0.045454545454545456, 'squared_error = 0.002\nsamples = 6673\nvalue = 0.004'),
#  Text(0.04492512479201331, 0.22727272727272727, 'clat <= -0.244\nsquared_error = 0.092\nsamples = 253\nvalue = 0.207'),
#  Text(0.04326123128119801, 0.13636363636363635, 'squared_error = 0.108\nsamples = 38\nvalue = 0.489'),
#  Text(0.04658901830282862, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.072\nsamples = 215\nvalue = 0.157'),
#  Text(0.04492512479201331, 0.045454545454545456, 'squared_error = 0.105\nsamples = 108\nvalue = 0.236'),
#  Text(0.048252911813643926, 0.045454545454545456, 'squared_error = 0.027\nsamples = 107\nvalue = 0.077'),
#  Text(0.04991680532445923, 0.3181818181818182, 'wa <= 3.499\nsquared_error = 0.045\nsamples = 62\nvalue = 0.865'),
#  Text(0.048252911813643926, 0.22727272727272727, 'squared_error = 0.066\nsamples = 31\nvalue = 0.755'),
#  Text(0.051580698835274545, 0.22727272727272727, 'squared_error = 0.0\nsamples = 31\nvalue = 0.975'),
#  Text(0.0632279534109817, 0.5909090909090909, 'qr+qg+qs <= 0.0\nsquared_error = 0.149\nsamples = 1394\nvalue = 0.229'),
#  Text(0.05324459234608985, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.142\nsamples = 191\nvalue = 0.805'),
#  Text(0.051580698835274545, 0.4090909090909091, 'squared_error = 0.224\nsamples = 59\nvalue = 0.461'),
#  Text(0.05490848585690516, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.029\nsamples = 132\nvalue = 0.959'),
#  Text(0.05324459234608985, 0.3181818181818182, 'squared_error = 0.089\nsamples = 39\nvalue = 0.881'),
#  Text(0.056572379367720464, 0.3181818181818182, 'pfull <= 94004.805\nsquared_error = 0.001\nsamples = 93\nvalue = 0.991'),
#  Text(0.05490848585690516, 0.22727272727272727, 'cllvi+clivi <= 0.741\nsquared_error = 0.0\nsamples = 63\nvalue = 0.998'),
#  Text(0.05324459234608985, 0.13636363636363635, 'squared_error = 0.0\nsamples = 30\nvalue = 0.996'),
#  Text(0.056572379367720464, 0.13636363636363635, 'squared_error = 0.0\nsamples = 33\nvalue = 1.0'),
#  Text(0.05823627287853577, 0.22727272727272727, 'squared_error = 0.002\nsamples = 30\nvalue = 0.977'),
#  Text(0.07321131447587355, 0.5, 'pfull <= 80704.609\nsquared_error = 0.089\nsamples = 1203\nvalue = 0.137'),
#  Text(0.06156405990016639, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.031\nsamples = 646\nvalue = 0.035'),
#  Text(0.059900166389351084, 0.3181818181818182, 'squared_error = 0.217\nsamples = 38\nvalue = 0.335'),
#  Text(0.0632279534109817, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.013\nsamples = 608\nvalue = 0.017'),
#  Text(0.06156405990016639, 0.22727272727272727, 'squared_error = 0.073\nsamples = 49\nvalue = 0.095'),
#  Text(0.064891846921797, 0.22727272727272727, 'ta <= 267.174\nsquared_error = 0.007\nsamples = 559\nvalue = 0.01'),
#  Text(0.06156405990016639, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 391\nvalue = 0.001'),
#  Text(0.059900166389351084, 0.045454545454545456, 'squared_error = 0.0\nsamples = 348\nvalue = 0.0'),
#  Text(0.0632279534109817, 0.045454545454545456, 'squared_error = 0.002\nsamples = 43\nvalue = 0.009'),
#  Text(0.06821963394342762, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.023\nsamples = 168\nvalue = 0.029'),
#  Text(0.06655574043261231, 0.045454545454545456, 'squared_error = 0.009\nsamples = 138\nvalue = 0.012'),
#  Text(0.06988352745424292, 0.045454545454545456, 'squared_error = 0.08\nsamples = 30\nvalue = 0.107'),
#  Text(0.08485856905158069, 0.4090909090909091, 'cllvi+clivi <= 0.07\nsquared_error = 0.131\nsamples = 557\nvalue = 0.255'),
#  Text(0.07986688851913477, 0.3181818181818182, 'clat <= 0.958\nsquared_error = 0.095\nsamples = 391\nvalue = 0.182'),
#  Text(0.07820299500831947, 0.22727272727272727, 'pfull <= 92932.527\nsquared_error = 0.08\nsamples = 339\nvalue = 0.149'),
#  Text(0.07487520798668885, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.039\nsamples = 203\nvalue = 0.068'),
#  Text(0.07321131447587355, 0.045454545454545456, 'squared_error = 0.021\nsamples = 145\nvalue = 0.042'),
#  Text(0.07653910149750416, 0.045454545454545456, 'squared_error = 0.077\nsamples = 58\nvalue = 0.134'),
#  Text(0.08153078202995008, 0.13636363636363635, 'RH <= 92.593\nsquared_error = 0.117\nsamples = 136\nvalue = 0.27'),
#  Text(0.07986688851913477, 0.045454545454545456, 'squared_error = 0.041\nsamples = 55\nvalue = 0.1'),
#  Text(0.08319467554076539, 0.045454545454545456, 'squared_error = 0.135\nsamples = 81\nvalue = 0.385'),
#  Text(0.08153078202995008, 0.22727272727272727, 'squared_error = 0.147\nsamples = 52\nvalue = 0.393'),
#  Text(0.08985024958402663, 0.3181818181818182, 'clon <= 0.041\nsquared_error = 0.173\nsamples = 166\nvalue = 0.429'),
#  Text(0.08652246256239601, 0.22727272727272727, 'hus <= 0.003\nsquared_error = 0.161\nsamples = 88\nvalue = 0.592'),
#  Text(0.08485856905158069, 0.13636363636363635, 'squared_error = 0.122\nsamples = 44\nvalue = 0.348'),
#  Text(0.08818635607321132, 0.13636363636363635, 'squared_error = 0.081\nsamples = 44\nvalue = 0.836'),
#  Text(0.09317803660565724, 0.22727272727272727, 'ua <= 8.949\nsquared_error = 0.123\nsamples = 78\nvalue = 0.245'),
#  Text(0.09151414309484193, 0.13636363636363635, 'squared_error = 0.06\nsamples = 48\nvalue = 0.105'),
#  Text(0.09484193011647254, 0.13636363636363635, 'squared_error = 0.142\nsamples = 30\nvalue = 0.469'),
#  Text(0.12000831946755408, 0.6818181818181818, 'clw+cli <= 0.0\nsquared_error = 0.146\nsamples = 4252\nvalue = 0.205'),
#  Text(0.10815307820299501, 0.5909090909090909, 'pfull <= 93848.711\nsquared_error = 0.045\nsamples = 3527\nvalue = 0.058'),
#  Text(0.10149750415973377, 0.5, 'qr+qg+qs <= 0.0\nsquared_error = 0.021\nsamples = 3272\nvalue = 0.027'),
#  Text(0.09816971713810316, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.224\nsamples = 60\nvalue = 0.374'),
#  Text(0.09650582362728785, 0.3181818181818182, 'squared_error = 0.0\nsamples = 30\nvalue = 0.003'),
#  Text(0.09983361064891846, 0.3181818181818182, 'squared_error = 0.173\nsamples = 30\nvalue = 0.745'),
#  Text(0.1048252911813644, 0.4090909090909091, 'wa <= 1.128\nsquared_error = 0.015\nsamples = 3212\nvalue = 0.02'),
#  Text(0.10316139767054909, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.012\nsamples = 3182\nvalue = 0.016'),
#  Text(0.10149750415973377, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.01\nsamples = 3152\nvalue = 0.014'),
#  Text(0.09816971713810316, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.069\nsamples = 217\nvalue = 0.095'),
#  Text(0.09650582362728785, 0.045454545454545456, 'squared_error = 0.037\nsamples = 187\nvalue = 0.052'),
#  Text(0.09983361064891846, 0.045454545454545456, 'squared_error = 0.189\nsamples = 30\nvalue = 0.365'),
#  Text(0.1048252911813644, 0.13636363636363635, 'clat <= 1.103\nsquared_error = 0.005\nsamples = 2935\nvalue = 0.008'),
#  Text(0.10316139767054909, 0.045454545454545456, 'squared_error = 0.003\nsamples = 2864\nvalue = 0.006'),
#  Text(0.1064891846921797, 0.045454545454545456, 'squared_error = 0.044\nsamples = 71\nvalue = 0.08'),
#  Text(0.1048252911813644, 0.22727272727272727, 'squared_error = 0.181\nsamples = 30\nvalue = 0.289'),
#  Text(0.1064891846921797, 0.3181818181818182, 'squared_error = 0.166\nsamples = 30\nvalue = 0.428'),
#  Text(0.11480865224625623, 0.5, 'qr+qg+qs <= 0.0\nsquared_error = 0.172\nsamples = 255\nvalue = 0.461'),
#  Text(0.11148086522462562, 0.4090909090909091, 'ta <= 260.811\nsquared_error = 0.15\nsamples = 162\nvalue = 0.619'),
#  Text(0.10981697171381032, 0.3181818181818182, 'squared_error = 0.051\nsamples = 34\nvalue = 0.146'),
#  Text(0.11314475873544093, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.102\nsamples = 128\nvalue = 0.744'),
#  Text(0.10981697171381032, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.055\nsamples = 67\nvalue = 0.897'),
#  Text(0.10815307820299501, 0.13636363636363635, 'squared_error = 0.104\nsamples = 30\nvalue = 0.802'),
#  Text(0.11148086522462562, 0.13636363636363635, 'squared_error = 0.002\nsamples = 37\nvalue = 0.974'),
#  Text(0.11647254575707154, 0.22727272727272727, 'cllvi+clivi <= 0.043\nsquared_error = 0.099\nsamples = 61\nvalue = 0.576'),
#  Text(0.11480865224625623, 0.13636363636363635, 'squared_error = 0.101\nsamples = 30\nvalue = 0.416'),
#  Text(0.11813643926788686, 0.13636363636363635, 'squared_error = 0.048\nsamples = 31\nvalue = 0.731'),
#  Text(0.11813643926788686, 0.4090909090909091, 'va <= -1.653\nsquared_error = 0.091\nsamples = 93\nvalue = 0.185'),
#  Text(0.11647254575707154, 0.3181818181818182, 'squared_error = 0.113\nsamples = 34\nvalue = 0.332'),
#  Text(0.11980033277870217, 0.3181818181818182, 'squared_error = 0.059\nsamples = 59\nvalue = 0.101'),
#  Text(0.13186356073211314, 0.5909090909090909, 'ta <= 243.212\nsquared_error = 0.025\nsamples = 725\nvalue = 0.919'),
#  Text(0.12479201331114809, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.055\nsamples = 187\nvalue = 0.761'),
#  Text(0.12312811980033278, 0.4090909090909091, 'squared_error = 0.082\nsamples = 41\nvalue = 0.426'),
#  Text(0.1264559068219634, 0.4090909090909091, 'wa <= 1.806\nsquared_error = 0.007\nsamples = 146\nvalue = 0.855'),
#  Text(0.12312811980033278, 0.3181818181818182, 'clw+cli <= 0.001\nsquared_error = 0.006\nsamples = 75\nvalue = 0.816'),
#  Text(0.12146422628951747, 0.22727272727272727, 'squared_error = 0.004\nsamples = 35\nvalue = 0.776'),
#  Text(0.12479201331114809, 0.22727272727272727, 'squared_error = 0.005\nsamples = 40\nvalue = 0.85'),
#  Text(0.129783693843594, 0.3181818181818182, 'ta <= 242.009\nsquared_error = 0.005\nsamples = 71\nvalue = 0.896'),
#  Text(0.1281198003327787, 0.22727272727272727, 'squared_error = 0.005\nsamples = 31\nvalue = 0.846'),
#  Text(0.1314475873544093, 0.22727272727272727, 'squared_error = 0.002\nsamples = 40\nvalue = 0.935'),
#  Text(0.1389351081530782, 0.5, 'hus <= 0.001\nsquared_error = 0.002\nsamples = 538\nvalue = 0.974'),
#  Text(0.13477537437603992, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.004\nsamples = 183\nvalue = 0.931'),
#  Text(0.13311148086522462, 0.3181818181818182, 'squared_error = 0.009\nsamples = 35\nvalue = 0.865'),
#  Text(0.13643926788685523, 0.3181818181818182, 'wa <= 3.001\nsquared_error = 0.001\nsamples = 148\nvalue = 0.947'),
#  Text(0.13477537437603992, 0.22727272727272727, 'clw+cli <= 0.001\nsquared_error = 0.001\nsamples = 111\nvalue = 0.938'),
#  Text(0.13311148086522462, 0.13636363636363635, 'squared_error = 0.001\nsamples = 55\nvalue = 0.926'),
#  Text(0.13643926788685523, 0.13636363636363635, 'squared_error = 0.0\nsamples = 56\nvalue = 0.95'),
#  Text(0.13810316139767054, 0.22727272727272727, 'squared_error = 0.0\nsamples = 37\nvalue = 0.972'),
#  Text(0.14309484193011648, 0.4090909090909091, 'ta <= 249.816\nsquared_error = 0.0\nsamples = 355\nvalue = 0.996'),
#  Text(0.14143094841930118, 0.3181818181818182, 'squared_error = 0.0\nsamples = 35\nvalue = 0.968'),
#  Text(0.1447587354409318, 0.3181818181818182, 'hus <= 0.002\nsquared_error = 0.0\nsamples = 320\nvalue = 0.999'),
#  Text(0.14143094841930118, 0.22727272727272727, 'clon <= -1.411\nsquared_error = 0.0\nsamples = 69\nvalue = 0.996'),
#  Text(0.13976705490848584, 0.13636363636363635, 'squared_error = 0.0\nsamples = 36\nvalue = 0.994'),
#  Text(0.14309484193011648, 0.13636363636363635, 'squared_error = 0.0\nsamples = 33\nvalue = 0.998'),
#  Text(0.1480865224625624, 0.22727272727272727, 'ta <= 257.654\nsquared_error = 0.0\nsamples = 251\nvalue = 1.0'),
#  Text(0.1464226289517471, 0.13636363636363635, 'squared_error = 0.0\nsamples = 35\nvalue = 0.999'),
#  Text(0.1497504159733777, 0.13636363636363635, 'hus <= 0.003\nsquared_error = 0.0\nsamples = 216\nvalue = 1.0'),
#  Text(0.1480865224625624, 0.045454545454545456, 'squared_error = 0.0\nsamples = 142\nvalue = 1.0'),
#  Text(0.15141430948419302, 0.045454545454545456, 'squared_error = 0.0\nsamples = 74\nvalue = 1.0'),
#  Text(0.1622296173044925, 0.7727272727272727, 'ta <= 270.272\nsquared_error = 0.041\nsamples = 3490\nvalue = 0.953'),
#  Text(0.15224625623960067, 0.6818181818181818, 'qr+qg+qs <= 0.0\nsquared_error = 0.213\nsamples = 309\nvalue = 0.587'),
#  Text(0.1464226289517471, 0.5909090909090909, 'clw+cli <= 0.0\nsquared_error = 0.065\nsamples = 120\nvalue = 0.919'),
#  Text(0.1447587354409318, 0.5, 'squared_error = 0.189\nsamples = 30\nvalue = 0.692'),
#  Text(0.1480865224625624, 0.5, 'pfull <= 94499.895\nsquared_error = 0.0\nsamples = 90\nvalue = 0.995'),
#  Text(0.1464226289517471, 0.4090909090909091, 'squared_error = 0.0\nsamples = 56\nvalue = 0.999'),
#  Text(0.1497504159733777, 0.4090909090909091, 'squared_error = 0.0\nsamples = 34\nvalue = 0.988'),
#  Text(0.15806988352745424, 0.5909090909090909, 'clw+cli <= 0.0\nsquared_error = 0.193\nsamples = 189\nvalue = 0.377'),
#  Text(0.15474209650582363, 0.5, 'RH <= 92.738\nsquared_error = 0.066\nsamples = 79\nvalue = 0.08'),
#  Text(0.15307820299500832, 0.4090909090909091, 'squared_error = 0.149\nsamples = 30\nvalue = 0.199'),
#  Text(0.15640599001663893, 0.4090909090909091, 'squared_error = 0.001\nsamples = 49\nvalue = 0.007'),
#  Text(0.16139767054908485, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.176\nsamples = 110\nvalue = 0.59'),
#  Text(0.15973377703826955, 0.4090909090909091, 'RH <= 93.836\nsquared_error = 0.183\nsamples = 74\nvalue = 0.463'),
#  Text(0.15806988352745424, 0.3181818181818182, 'squared_error = 0.132\nsamples = 37\nvalue = 0.699'),
#  Text(0.16139767054908485, 0.3181818181818182, 'squared_error = 0.123\nsamples = 37\nvalue = 0.227'),
#  Text(0.16306156405990016, 0.4090909090909091, 'squared_error = 0.06\nsamples = 36\nvalue = 0.85'),
#  Text(0.17221297836938437, 0.6818181818181818, 'ta <= 271.792\nsquared_error = 0.01\nsamples = 3181\nvalue = 0.989'),
#  Text(0.16638935108153077, 0.5909090909090909, 'clw+cli <= 0.0\nsquared_error = 0.102\nsamples = 226\nvalue = 0.868'),
#  Text(0.16472545757071547, 0.5, 'squared_error = 0.244\nsamples = 47\nvalue = 0.493'),
#  Text(0.16805324459234608, 0.5, 'va <= 4.83\nsquared_error = 0.018\nsamples = 179\nvalue = 0.967'),
#  Text(0.16638935108153077, 0.4090909090909091, 'ua <= -2.482\nsquared_error = 0.001\nsamples = 132\nvalue = 0.99'),
#  Text(0.16472545757071547, 0.3181818181818182, 'squared_error = 0.002\nsamples = 58\nvalue = 0.98'),
#  Text(0.16805324459234608, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 74\nvalue = 0.997'),
#  Text(0.16638935108153077, 0.22727272727272727, 'squared_error = 0.0\nsamples = 41\nvalue = 1.0'),
#  Text(0.16971713810316139, 0.22727272727272727, 'squared_error = 0.0\nsamples = 33\nvalue = 0.994'),
#  Text(0.16971713810316139, 0.4090909090909091, 'squared_error = 0.062\nsamples = 47\nvalue = 0.904'),
#  Text(0.17803660565723795, 0.5909090909090909, 'ta <= 272.511\nsquared_error = 0.001\nsamples = 2955\nvalue = 0.998'),
#  Text(0.17470881863560733, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.033\nsamples = 106\nvalue = 0.957'),
#  Text(0.17304492512479203, 0.4090909090909091, 'squared_error = 0.103\nsamples = 30\nvalue = 0.865'),
#  Text(0.17637271214642264, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.001\nsamples = 76\nvalue = 0.993'),
#  Text(0.17470881863560733, 0.3181818181818182, 'squared_error = 0.002\nsamples = 30\nvalue = 0.984'),
#  Text(0.17803660565723795, 0.3181818181818182, 'squared_error = 0.0\nsamples = 46\nvalue = 0.999'),
#  Text(0.18136439267886856, 0.5, 'ta <= 272.78\nsquared_error = 0.0\nsamples = 2849\nvalue = 1.0'),
#  Text(0.17970049916805325, 0.4090909090909091, 'squared_error = 0.003\nsamples = 30\nvalue = 0.981'),
#  Text(0.18302828618968386, 0.4090909090909091, 'ta <= 273.184\nsquared_error = 0.0\nsamples = 2819\nvalue = 1.0'),
#  Text(0.18136439267886856, 0.3181818181818182, 'squared_error = 0.0\nsamples = 54\nvalue = 0.997'),
#  Text(0.18469217970049917, 0.3181818181818182, 'clat <= 0.768\nsquared_error = 0.0\nsamples = 2765\nvalue = 1.0'),
#  Text(0.18136439267886856, 0.22727272727272727, 'hus <= 0.004\nsquared_error = 0.0\nsamples = 2700\nvalue = 1.0'),
#  Text(0.17970049916805325, 0.13636363636363635, 'squared_error = 0.0\nsamples = 53\nvalue = 1.0'),
#  Text(0.18302828618968386, 0.13636363636363635, 'ta <= 275.162\nsquared_error = 0.0\nsamples = 2647\nvalue = 1.0'),
#  Text(0.18136439267886856, 0.045454545454545456, 'squared_error = 0.0\nsamples = 140\nvalue = 1.0'),
#  Text(0.18469217970049917, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2507\nvalue = 1.0'),
#  Text(0.18801996672212978, 0.22727272727272727, 'ta <= 274.62\nsquared_error = 0.0\nsamples = 65\nvalue = 1.0'),
#  Text(0.18635607321131448, 0.13636363636363635, 'squared_error = 0.0\nsamples = 30\nvalue = 1.0'),
#  Text(0.1896838602329451, 0.13636363636363635, 'squared_error = 0.0\nsamples = 35\nvalue = 1.0'),
#  Text(0.43297628951747086, 0.8636363636363636, 'RH <= 97.423\nsquared_error = 0.001\nsamples = 4434333\nvalue = 0.998'),
#  Text(0.35543625207986684, 0.9090909090909092, '  False'),
#  Text(0.2437603993344426, 0.7727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.167\nsamples = 9080\nvalue = 0.736'),
#  Text(0.20923460898502497, 0.6818181818181818, 'ta <= 269.642\nsquared_error = 0.18\nsamples = 2716\nvalue = 0.261'),
#  Text(0.20382695507487522, 0.5909090909090909, 'qr+qg+qs <= 0.0\nsquared_error = 0.077\nsamples = 2219\nvalue = 0.104'),
#  Text(0.19800332778702162, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.221\nsamples = 172\nvalue = 0.562'),
#  Text(0.194675540765391, 0.4090909090909091, 'ta <= 266.178\nsquared_error = 0.192\nsamples = 92\nvalue = 0.293'),
#  Text(0.1930116472545757, 0.3181818181818182, 'pfull <= 85967.512\nsquared_error = 0.061\nsamples = 61\nvalue = 0.079'),
#  Text(0.1913477537437604, 0.22727272727272727, 'squared_error = 0.0\nsamples = 31\nvalue = 0.001'),
#  Text(0.194675540765391, 0.22727272727272727, 'squared_error = 0.112\nsamples = 30\nvalue = 0.16'),
#  Text(0.19633943427620631, 0.3181818181818182, 'squared_error = 0.183\nsamples = 31\nvalue = 0.714'),
#  Text(0.20133111480865223, 0.4090909090909091, 'hus <= 0.002\nsquared_error = 0.075\nsamples = 80\nvalue = 0.871'),
#  Text(0.19966722129783693, 0.3181818181818182, 'squared_error = 0.138\nsamples = 31\nvalue = 0.689'),
#  Text(0.20299500831946754, 0.3181818181818182, 'squared_error = 0.001\nsamples = 49\nvalue = 0.987'),
#  Text(0.2096505823627288, 0.5, 'wa <= 0.986\nsquared_error = 0.046\nsamples = 2047\nvalue = 0.066'),
#  Text(0.2079866888519135, 0.4090909090909091, 'pfull <= 96250.57\nsquared_error = 0.04\nsamples = 1995\nvalue = 0.055'),
#  Text(0.20632279534109818, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.036\nsamples = 1962\nvalue = 0.048'),
#  Text(0.20049916805324458, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.027\nsamples = 1848\nvalue = 0.038'),
#  Text(0.19717138103161397, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.097\nsamples = 154\nvalue = 0.164'),
#  Text(0.19550748752079866, 0.045454545454545456, 'squared_error = 0.046\nsamples = 107\nvalue = 0.078'),
#  Text(0.19883527454242927, 0.045454545454545456, 'squared_error = 0.156\nsamples = 47\nvalue = 0.359'),
#  Text(0.20382695507487522, 0.13636363636363635, 'clat <= 1.094\nsquared_error = 0.02\nsamples = 1694\nvalue = 0.026'),
#  Text(0.2021630615640599, 0.045454545454545456, 'squared_error = 0.017\nsamples = 1661\nvalue = 0.022'),
#  Text(0.20549084858569053, 0.045454545454545456, 'squared_error = 0.114\nsamples = 33\nvalue = 0.23'),
#  Text(0.21214642262895175, 0.22727272727272727, 'RH <= 97.265\nsquared_error = 0.145\nsamples = 114\nvalue = 0.224'),
#  Text(0.21048252911813645, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.088\nsamples = 84\nvalue = 0.129'),
#  Text(0.20881863560732114, 0.045454545454545456, 'squared_error = 0.13\nsamples = 31\nvalue = 0.255'),
#  Text(0.21214642262895175, 0.045454545454545456, 'squared_error = 0.048\nsamples = 53\nvalue = 0.056'),
#  Text(0.21381031613976706, 0.13636363636363635, 'squared_error = 0.213\nsamples = 30\nvalue = 0.488'),
#  Text(0.2096505823627288, 0.3181818181818182, 'squared_error = 0.102\nsamples = 33\nvalue = 0.466'),
#  Text(0.2113144758735441, 0.4090909090909091, 'squared_error = 0.119\nsamples = 52\nvalue = 0.467'),
#  Text(0.2146422628951747, 0.5909090909090909, 'ta <= 270.8\nsquared_error = 0.034\nsamples = 497\nvalue = 0.963'),
#  Text(0.2129783693843594, 0.5, 'squared_error = 0.177\nsamples = 59\nvalue = 0.754'),
#  Text(0.21630615640599002, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.008\nsamples = 438\nvalue = 0.991'),
#  Text(0.2146422628951747, 0.4090909090909091, 'squared_error = 0.102\nsamples = 30\nvalue = 0.874'),
#  Text(0.21797004991680533, 0.4090909090909091, 'hus <= 0.003\nsquared_error = 0.0\nsamples = 408\nvalue = 1.0'),
#  Text(0.21630615640599002, 0.3181818181818182, 'squared_error = 0.0\nsamples = 30\nvalue = 0.998'),
#  Text(0.21963394342762063, 0.3181818181818182, 'ta <= 273.61\nsquared_error = 0.0\nsamples = 378\nvalue = 1.0'),
#  Text(0.21797004991680533, 0.22727272727272727, 'squared_error = 0.0\nsamples = 50\nvalue = 1.0'),
#  Text(0.22129783693843594, 0.22727272727272727, 'hus <= 0.005\nsquared_error = 0.0\nsamples = 328\nvalue = 1.0'),
#  Text(0.21963394342762063, 0.13636363636363635, 'squared_error = 0.0\nsamples = 30\nvalue = 1.0'),
#  Text(0.22296173044925124, 0.13636363636363635, 'squared_error = 0.0\nsamples = 298\nvalue = 1.0'),
#  Text(0.2782861896838602, 0.6818181818181818, 'hus <= 0.001\nsquared_error = 0.024\nsamples = 6364\nvalue = 0.939'),
#  Text(0.25207986688851913, 0.5909090909090909, 'clw+cli <= 0.0\nsquared_error = 0.057\nsamples = 1092\nvalue = 0.726'),
#  Text(0.2391846921797005, 0.5, 'wa <= 2.171\nsquared_error = 0.07\nsamples = 399\nvalue = 0.546'),
#  Text(0.23377703826955074, 0.4090909090909091, 'ta <= 240.966\nsquared_error = 0.057\nsamples = 299\nvalue = 0.464'),
#  Text(0.22961730449251247, 0.3181818181818182, 'wa <= 1.219\nsquared_error = 0.046\nsamples = 126\nvalue = 0.36'),
#  Text(0.22795341098169716, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.04\nsamples = 96\nvalue = 0.319'),
#  Text(0.22628951747088186, 0.13636363636363635, 'squared_error = 0.037\nsamples = 38\nvalue = 0.243'),
#  Text(0.22961730449251247, 0.13636363636363635, 'squared_error = 0.036\nsamples = 58\nvalue = 0.368'),
#  Text(0.23128119800332778, 0.22727272727272727, 'squared_error = 0.044\nsamples = 30\nvalue = 0.492'),
#  Text(0.23793677204658903, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.052\nsamples = 173\nvalue = 0.54'),
#  Text(0.23460898502495842, 0.22727272727272727, 'pfull <= 30277.052\nsquared_error = 0.052\nsamples = 74\nvalue = 0.417'),
#  Text(0.23294509151414308, 0.13636363636363635, 'squared_error = 0.047\nsamples = 44\nvalue = 0.345'),
#  Text(0.23627287853577372, 0.13636363636363635, 'squared_error = 0.041\nsamples = 30\nvalue = 0.521'),
#  Text(0.24126455906821964, 0.22727272727272727, 'pfull <= 30272.868\nsquared_error = 0.032\nsamples = 99\nvalue = 0.632'),
#  Text(0.23960066555740434, 0.13636363636363635, 'wa <= 1.002\nsquared_error = 0.031\nsamples = 65\nvalue = 0.57'),
#  Text(0.23793677204658903, 0.045454545454545456, 'squared_error = 0.036\nsamples = 33\nvalue = 0.508'),
#  Text(0.24126455906821964, 0.045454545454545456, 'squared_error = 0.017\nsamples = 32\nvalue = 0.633'),
#  Text(0.24292845257903495, 0.13636363636363635, 'squared_error = 0.011\nsamples = 34\nvalue = 0.753'),
#  Text(0.24459234608985025, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.026\nsamples = 100\nvalue = 0.792'),
#  Text(0.24292845257903495, 0.3181818181818182, 'squared_error = 0.035\nsamples = 35\nvalue = 0.69'),
#  Text(0.24625623960066556, 0.3181818181818182, 'qr+qg+qs <= 0.002\nsquared_error = 0.012\nsamples = 65\nvalue = 0.847'),
#  Text(0.24459234608985025, 0.22727272727272727, 'squared_error = 0.017\nsamples = 32\nvalue = 0.8'),
#  Text(0.24792013311148087, 0.22727272727272727, 'squared_error = 0.003\nsamples = 33\nvalue = 0.892'),
#  Text(0.26497504159733776, 0.5, 'wa <= 1.078\nsquared_error = 0.02\nsamples = 693\nvalue = 0.83'),
#  Text(0.2562396006655574, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.024\nsamples = 222\nvalue = 0.706'),
#  Text(0.2529118136439268, 0.3181818181818182, 'ta <= 240.494\nsquared_error = 0.02\nsamples = 60\nvalue = 0.589'),
#  Text(0.2512479201331115, 0.22727272727272727, 'squared_error = 0.02\nsamples = 30\nvalue = 0.536'),
#  Text(0.2545757071547421, 0.22727272727272727, 'squared_error = 0.015\nsamples = 30\nvalue = 0.643'),
#  Text(0.259567387687188, 0.3181818181818182, 'pfull <= 29990.908\nsquared_error = 0.019\nsamples = 162\nvalue = 0.749'),
#  Text(0.2579034941763727, 0.22727272727272727, 'squared_error = 0.023\nsamples = 35\nvalue = 0.618'),
#  Text(0.2612312811980033, 0.22727272727272727, 'clw+cli <= 0.001\nsquared_error = 0.011\nsamples = 127\nvalue = 0.785'),
#  Text(0.259567387687188, 0.13636363636363635, 'ta <= 241.75\nsquared_error = 0.012\nsamples = 91\nvalue = 0.758'),
#  Text(0.2579034941763727, 0.045454545454545456, 'squared_error = 0.01\nsamples = 52\nvalue = 0.718'),
#  Text(0.2612312811980033, 0.045454545454545456, 'squared_error = 0.008\nsamples = 39\nvalue = 0.811'),
#  Text(0.2628951747088186, 0.13636363636363635, 'squared_error = 0.004\nsamples = 36\nvalue = 0.852'),
#  Text(0.2737104825291181, 0.4090909090909091, 'wa <= 2.259\nsquared_error = 0.007\nsamples = 471\nvalue = 0.889'),
#  Text(0.26622296173044924, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.009\nsamples = 190\nvalue = 0.84'),
#  Text(0.26455906821963393, 0.22727272727272727, 'squared_error = 0.012\nsamples = 41\nvalue = 0.749'),
#  Text(0.26788685524126454, 0.22727272727272727, 'ta <= 240.691\nsquared_error = 0.006\nsamples = 149\nvalue = 0.865'),
#  Text(0.26622296173044924, 0.13636363636363635, 'squared_error = 0.009\nsamples = 43\nvalue = 0.817'),
#  Text(0.26955074875207985, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.003\nsamples = 106\nvalue = 0.884'),
#  Text(0.26788685524126454, 0.045454545454545456, 'squared_error = 0.006\nsamples = 30\nvalue = 0.853'),
#  Text(0.27121464226289516, 0.045454545454545456, 'squared_error = 0.001\nsamples = 76\nvalue = 0.897'),
#  Text(0.281198003327787, 0.3181818181818182, 'ta <= 241.371\nsquared_error = 0.003\nsamples = 281\nvalue = 0.921'),
#  Text(0.2778702163061564, 0.22727272727272727, 'wa <= 3.748\nsquared_error = 0.003\nsamples = 121\nvalue = 0.894'),
#  Text(0.2762063227953411, 0.13636363636363635, 'clw+cli <= 0.001\nsquared_error = 0.003\nsamples = 76\nvalue = 0.874'),
#  Text(0.27454242928452577, 0.045454545454545456, 'squared_error = 0.003\nsamples = 45\nvalue = 0.854'),
#  Text(0.2778702163061564, 0.045454545454545456, 'squared_error = 0.001\nsamples = 31\nvalue = 0.903'),
#  Text(0.2795341098169717, 0.13636363636363635, 'squared_error = 0.002\nsamples = 45\nvalue = 0.928'),
#  Text(0.28452579034941766, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.001\nsamples = 160\nvalue = 0.942'),
#  Text(0.28286189683860236, 0.13636363636363635, 'squared_error = 0.002\nsamples = 55\nvalue = 0.924'),
#  Text(0.28618968386023297, 0.13636363636363635, 'wa <= 4.083\nsquared_error = 0.0\nsamples = 105\nvalue = 0.952'),
#  Text(0.28452579034941766, 0.045454545454545456, 'squared_error = 0.0\nsamples = 69\nvalue = 0.943'),
#  Text(0.2878535773710483, 0.045454545454545456, 'squared_error = 0.0\nsamples = 36\nvalue = 0.968'),
#  Text(0.30449251247920134, 0.5909090909090909, 'clw+cli <= 0.0\nsquared_error = 0.006\nsamples = 5272\nvalue = 0.983'),
#  Text(0.2895174708818636, 0.5, 'wa <= 0.19\nsquared_error = 0.109\nsamples = 184\nvalue = 0.837'),
#  Text(0.2878535773710483, 0.4090909090909091, 'ta <= 267.116\nsquared_error = 0.0\nsamples = 126\nvalue = 0.992'),
#  Text(0.28618968386023297, 0.3181818181818182, 'squared_error = 0.001\nsamples = 30\nvalue = 0.969'),
#  Text(0.2895174708818636, 0.3181818181818182, 'hus <= 0.003\nsquared_error = 0.0\nsamples = 96\nvalue = 1.0'),
#  Text(0.2878535773710483, 0.22727272727272727, 'squared_error = 0.0\nsamples = 30\nvalue = 0.999'),
#  Text(0.2911813643926789, 0.22727272727272727, 'ta <= 272.338\nsquared_error = 0.0\nsamples = 66\nvalue = 1.0'),
#  Text(0.2895174708818636, 0.13636363636363635, 'squared_error = 0.0\nsamples = 34\nvalue = 1.0'),
#  Text(0.2928452579034942, 0.13636363636363635, 'squared_error = 0.0\nsamples = 32\nvalue = 1.0'),
#  Text(0.2911813643926789, 0.4090909090909091, 'squared_error = 0.18\nsamples = 58\nvalue = 0.501'),
#  Text(0.3194675540765391, 0.5, 'hus <= 0.001\nsquared_error = 0.002\nsamples = 5088\nvalue = 0.988'),
#  Text(0.30615640599001664, 0.4090909090909091, 'wa <= 1.727\nsquared_error = 0.009\nsamples = 541\nvalue = 0.917'),
#  Text(0.3011647254575707, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.015\nsamples = 156\nvalue = 0.827'),
#  Text(0.2978369384359401, 0.22727272727272727, 'clon <= 2.589\nsquared_error = 0.017\nsamples = 70\nvalue = 0.753'),
#  Text(0.2961730449251248, 0.13636363636363635, 'squared_error = 0.008\nsamples = 31\nvalue = 0.854'),
#  Text(0.2995008319467554, 0.13636363636363635, 'squared_error = 0.01\nsamples = 39\nvalue = 0.672'),
#  Text(0.30449251247920134, 0.22727272727272727, 'ta <= 243.269\nsquared_error = 0.005\nsamples = 86\nvalue = 0.888'),
#  Text(0.30282861896838603, 0.13636363636363635, 'squared_error = 0.004\nsamples = 32\nvalue = 0.837'),
#  Text(0.30615640599001664, 0.13636363636363635, 'squared_error = 0.002\nsamples = 54\nvalue = 0.918'),
#  Text(0.31114808652246256, 0.3181818181818182, 'cllvi+clivi <= 0.891\nsquared_error = 0.002\nsamples = 385\nvalue = 0.954'),
#  Text(0.30948419301164726, 0.22727272727272727, 'squared_error = 0.006\nsamples = 51\nvalue = 0.903'),
#  Text(0.31281198003327787, 0.22727272727272727, 'wa <= 4.302\nsquared_error = 0.001\nsamples = 334\nvalue = 0.962'),
#  Text(0.30948419301164726, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.001\nsamples = 165\nvalue = 0.947'),
#  Text(0.30782029950083195, 0.045454545454545456, 'squared_error = 0.002\nsamples = 31\nvalue = 0.915'),
#  Text(0.31114808652246256, 0.045454545454545456, 'squared_error = 0.0\nsamples = 134\nvalue = 0.955'),
#  Text(0.3161397670549085, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 169\nvalue = 0.976'),
#  Text(0.3144758735440932, 0.045454545454545456, 'squared_error = 0.0\nsamples = 71\nvalue = 0.968'),
#  Text(0.3178036605657238, 0.045454545454545456, 'squared_error = 0.0\nsamples = 98\nvalue = 0.982'),
#  Text(0.33277870216306155, 0.4090909090909091, 'ta <= 255.43\nsquared_error = 0.0\nsamples = 4547\nvalue = 0.997'),
#  Text(0.324459234608985, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.004\nsamples = 436\nvalue = 0.977'),
#  Text(0.3227953410981697, 0.22727272727272727, 'squared_error = 0.036\nsamples = 30\nvalue = 0.87'),
#  Text(0.3261231281198003, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.001\nsamples = 406\nvalue = 0.985'),
#  Text(0.3227953410981697, 0.13636363636363635, 'wa <= 0.439\nsquared_error = 0.001\nsamples = 132\nvalue = 0.974'),
#  Text(0.3211314475873544, 0.045454545454545456, 'squared_error = 0.002\nsamples = 51\nvalue = 0.96'),
#  Text(0.324459234608985, 0.045454545454545456, 'squared_error = 0.0\nsamples = 81\nvalue = 0.982'),
#  Text(0.32945091514143093, 0.13636363636363635, 'ta <= 245.676\nsquared_error = 0.0\nsamples = 274\nvalue = 0.99'),
#  Text(0.3277870216306156, 0.045454545454545456, 'squared_error = 0.0\nsamples = 61\nvalue = 0.978'),
#  Text(0.33111480865224624, 0.045454545454545456, 'squared_error = 0.0\nsamples = 213\nvalue = 0.994'),
#  Text(0.3410981697171381, 0.3181818181818182, 'clat <= 1.083\nsquared_error = 0.0\nsamples = 4111\nvalue = 0.999'),
#  Text(0.33943427620632277, 0.22727272727272727, 'hus <= 0.003\nsquared_error = 0.0\nsamples = 4064\nvalue = 0.999'),
#  Text(0.33610648918469216, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 663\nvalue = 0.996'),
#  Text(0.33444259567387685, 0.045454545454545456, 'squared_error = 0.001\nsamples = 52\nvalue = 0.985'),
#  Text(0.33777038269550747, 0.045454545454545456, 'squared_error = 0.0\nsamples = 611\nvalue = 0.997'),
#  Text(0.3427620632279534, 0.13636363636363635, 'hus <= 0.003\nsquared_error = 0.0\nsamples = 3401\nvalue = 1.0'),
#  Text(0.3410981697171381, 0.045454545454545456, 'squared_error = 0.0\nsamples = 692\nvalue = 0.999'),
#  Text(0.34442595673876875, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2709\nvalue = 1.0'),
#  Text(0.3427620632279534, 0.22727272727272727, 'squared_error = 0.0\nsamples = 47\nvalue = 0.982'),
#  Text(0.6221921797004991, 0.7727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.001\nsamples = 4425253\nvalue = 0.998'),
#  Text(0.44992720465890185, 0.6818181818181818, 'RH <= 98.747\nsquared_error = 0.062\nsamples = 35198\nvalue = 0.908'),
#  Text(0.3855033277870216, 0.5909090909090909, 'qr+qg+qs <= 0.0\nsquared_error = 0.197\nsamples = 4732\nvalue = 0.525'),
#  Text(0.360648918469218, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.084\nsamples = 1783\nvalue = 0.849'),
#  Text(0.3527454242928453, 0.4090909090909091, 'ta <= 269.193\nsquared_error = 0.221\nsamples = 281\nvalue = 0.515'),
#  Text(0.34941763727121466, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.121\nsamples = 169\nvalue = 0.213'),
#  Text(0.34775374376039936, 0.22727272727272727, 'squared_error = 0.177\nsamples = 30\nvalue = 0.53'),
#  Text(0.35108153078202997, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.083\nsamples = 139\nvalue = 0.145'),
#  Text(0.34941763727121466, 0.13636363636363635, 'pfull <= 86666.562\nsquared_error = 0.054\nsamples = 103\nvalue = 0.091'),
#  Text(0.34775374376039936, 0.045454545454545456, 'squared_error = 0.028\nsamples = 73\nvalue = 0.045'),
#  Text(0.35108153078202997, 0.045454545454545456, 'squared_error = 0.099\nsamples = 30\nvalue = 0.204'),
#  Text(0.3527454242928453, 0.13636363636363635, 'squared_error = 0.133\nsamples = 36\nvalue = 0.298'),
#  Text(0.3560732113144759, 0.3181818181818182, 'hus <= 0.005\nsquared_error = 0.025\nsamples = 112\nvalue = 0.971'),
#  Text(0.3544093178036606, 0.22727272727272727, 'squared_error = 0.085\nsamples = 30\nvalue = 0.894'),
#  Text(0.3577371048252912, 0.22727272727272727, 'squared_error = -0.0\nsamples = 82\nvalue = 1.0'),
#  Text(0.3685524126455907, 0.4090909090909091, 'hus <= 0.001\nsquared_error = 0.034\nsamples = 1502\nvalue = 0.911'),
#  Text(0.3627287853577371, 0.3181818181818182, 'RH <= 98.444\nsquared_error = 0.099\nsamples = 69\nvalue = 0.542'),
#  Text(0.3610648918469218, 0.22727272727272727, 'squared_error = 0.102\nsamples = 38\nvalue = 0.418'),
#  Text(0.3643926788685524, 0.22727272727272727, 'squared_error = 0.053\nsamples = 31\nvalue = 0.693'),
#  Text(0.37437603993344426, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.023\nsamples = 1433\nvalue = 0.929'),
#  Text(0.36772046589018303, 0.22727272727272727, 'hus <= 0.002\nsquared_error = 0.003\nsamples = 996\nvalue = 0.974'),
#  Text(0.3643926788685524, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.008\nsamples = 269\nvalue = 0.927'),
#  Text(0.3627287853577371, 0.045454545454545456, 'squared_error = 0.022\nsamples = 37\nvalue = 0.836'),
#  Text(0.36605657237936773, 0.045454545454545456, 'squared_error = 0.004\nsamples = 232\nvalue = 0.941'),
#  Text(0.37104825291181365, 0.13636363636363635, 'ta <= 264.763\nsquared_error = 0.001\nsamples = 727\nvalue = 0.992'),
#  Text(0.36938435940099834, 0.045454545454545456, 'squared_error = 0.002\nsamples = 136\nvalue = 0.969'),
#  Text(0.37271214642262895, 0.045454545454545456, 'squared_error = 0.0\nsamples = 591\nvalue = 0.997'),
#  Text(0.3810316139767055, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.054\nsamples = 437\nvalue = 0.825'),
#  Text(0.3777038269550749, 0.13636363636363635, 'ta <= 264.624\nsquared_error = 0.134\nsamples = 92\nvalue = 0.595'),
#  Text(0.37603993344425957, 0.045454545454545456, 'squared_error = 0.123\nsamples = 57\nvalue = 0.447'),
#  Text(0.3793677204658902, 0.045454545454545456, 'squared_error = 0.059\nsamples = 35\nvalue = 0.836'),
#  Text(0.3843594009983361, 0.13636363636363635, 'ta <= 266.657\nsquared_error = 0.015\nsamples = 345\nvalue = 0.887'),
#  Text(0.3826955074875208, 0.045454545454545456, 'squared_error = 0.015\nsamples = 282\nvalue = 0.864'),
#  Text(0.3860232945091514, 0.045454545454545456, 'squared_error = 0.0\nsamples = 63\nvalue = 0.99'),
#  Text(0.4103577371048253, 0.5, 'RH <= 98.165\nsquared_error = 0.164\nsamples = 2949\nvalue = 0.329'),
#  Text(0.3968386023294509, 0.4090909090909091, 'ta <= 271.462\nsquared_error = 0.088\nsamples = 1176\nvalue = 0.131'),
#  Text(0.3951747088186356, 0.3181818181818182, 'ta <= 254.248\nsquared_error = 0.064\nsamples = 1136\nvalue = 0.101'),
#  Text(0.389351081530782, 0.22727272727272727, 'RH <= 97.735\nsquared_error = 0.095\nsamples = 129\nvalue = 0.361'),
#  Text(0.3876871880199667, 0.13636363636363635, 'squared_error = 0.031\nsamples = 31\nvalue = 0.08'),
#  Text(0.3910149750415973, 0.13636363636363635, 'hus <= 0.001\nsquared_error = 0.082\nsamples = 98\nvalue = 0.449'),
#  Text(0.389351081530782, 0.045454545454545456, 'squared_error = 0.083\nsamples = 55\nvalue = 0.362'),
#  Text(0.39267886855241263, 0.045454545454545456, 'squared_error = 0.06\nsamples = 43\nvalue = 0.561'),
#  Text(0.40099833610648916, 0.22727272727272727, 'pfull <= 94246.32\nsquared_error = 0.05\nsamples = 1007\nvalue = 0.068'),
#  Text(0.39767054908485855, 0.13636363636363635, 'wa <= 0.468\nsquared_error = 0.029\nsamples = 897\nvalue = 0.037'),
#  Text(0.39600665557404324, 0.045454545454545456, 'squared_error = 0.018\nsamples = 866\nvalue = 0.025'),
#  Text(0.39933444259567386, 0.045454545454545456, 'squared_error = 0.214\nsamples = 31\nvalue = 0.364'),
#  Text(0.4043261231281198, 0.13636363636363635, 'cllvi+clivi <= 0.053\nsquared_error = 0.156\nsamples = 110\nvalue = 0.319'),
#  Text(0.40266222961730447, 0.045454545454545456, 'squared_error = 0.08\nsamples = 60\nvalue = 0.126'),
#  Text(0.4059900166389351, 0.045454545454545456, 'squared_error = 0.149\nsamples = 50\nvalue = 0.551'),
#  Text(0.3985024958402662, 0.3181818181818182, 'squared_error = 0.0\nsamples = 40\nvalue = 0.998'),
#  Text(0.4238768718801997, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.171\nsamples = 1773\nvalue = 0.461'),
#  Text(0.415973377703827, 0.3181818181818182, 'wa <= 0.193\nsquared_error = 0.148\nsamples = 561\nvalue = 0.244'),
#  Text(0.41264559068219636, 0.22727272727272727, 'ta <= 270.561\nsquared_error = 0.109\nsamples = 458\nvalue = 0.164'),
#  Text(0.41098169717138106, 0.13636363636363635, 'ta <= 263.985\nsquared_error = 0.072\nsamples = 428\nvalue = 0.115'),
#  Text(0.40931780366056575, 0.045454545454545456, 'squared_error = 0.127\nsamples = 115\nvalue = 0.314'),
#  Text(0.41264559068219636, 0.045454545454545456, 'squared_error = 0.031\nsamples = 313\nvalue = 0.042'),
#  Text(0.41430948419301167, 0.13636363636363635, 'squared_error = 0.114\nsamples = 30\nvalue = 0.863'),
#  Text(0.4193011647254576, 0.22727272727272727, 'wa <= 0.492\nsquared_error = 0.169\nsamples = 103\nvalue = 0.6'),
#  Text(0.4176372712146423, 0.13636363636363635, 'RH <= 98.508\nsquared_error = 0.167\nsamples = 63\nvalue = 0.464'),
#  Text(0.415973377703827, 0.045454545454545456, 'squared_error = 0.137\nsamples = 30\nvalue = 0.289'),
#  Text(0.4193011647254576, 0.045454545454545456, 'squared_error = 0.141\nsamples = 33\nvalue = 0.624'),
#  Text(0.4209650582362729, 0.13636363636363635, 'squared_error = 0.099\nsamples = 40\nvalue = 0.814'),
#  Text(0.4317803660565724, 0.3181818181818182, 'ta <= 269.543\nsquared_error = 0.15\nsamples = 1212\nvalue = 0.561'),
#  Text(0.4276206322795341, 0.22727272727272727, 'wa <= 0.48\nsquared_error = 0.146\nsamples = 1130\nvalue = 0.529'),
#  Text(0.4242928452579035, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.141\nsamples = 990\nvalue = 0.483'),
#  Text(0.4226289517470882, 0.045454545454545456, 'squared_error = 0.075\nsamples = 306\nvalue = 0.683'),
#  Text(0.4259567387687188, 0.045454545454545456, 'squared_error = 0.145\nsamples = 684\nvalue = 0.393'),
#  Text(0.43094841930116473, 0.13636363636363635, 'ta <= 261.259\nsquared_error = 0.055\nsamples = 140\nvalue = 0.86'),
#  Text(0.4292845257903494, 0.045454545454545456, 'squared_error = 0.082\nsamples = 59\nvalue = 0.754'),
#  Text(0.43261231281198004, 0.045454545454545456, 'squared_error = 0.021\nsamples = 81\nvalue = 0.937'),
#  Text(0.43594009983361065, 0.22727272727272727, 'cllvi+clivi <= 0.138\nsquared_error = 0.0\nsamples = 82\nvalue = 0.996'),
#  Text(0.43427620632279534, 0.13636363636363635, 'squared_error = 0.0\nsamples = 33\nvalue = 0.991'),
#  Text(0.43760399334442596, 0.13636363636363635, 'squared_error = 0.0\nsamples = 49\nvalue = 1.0'),
#  Text(0.514351081530782, 0.5909090909090909, 'RH <= 98.939\nsquared_error = 0.015\nsamples = 30466\nvalue = 0.967'),
#  Text(0.4667221297836938, 0.5, 'qr+qg+qs <= 0.0\nsquared_error = 0.064\nsamples = 4285\nvalue = 0.835'),
#  Text(0.44717138103161397, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.013\nsamples = 1808\nvalue = 0.947'),
#  Text(0.44093178036605657, 0.3181818181818182, 'hus <= 0.002\nsquared_error = 0.003\nsamples = 1049\nvalue = 0.98'),
#  Text(0.43926788685524126, 0.22727272727272727, 'squared_error = 0.024\nsamples = 30\nvalue = 0.827'),
#  Text(0.4425956738768719, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.002\nsamples = 1019\nvalue = 0.984'),
#  Text(0.44093178036605657, 0.13636363636363635, 'squared_error = 0.023\nsamples = 51\nvalue = 0.923'),
#  Text(0.4442595673876872, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 968\nvalue = 0.988'),
#  Text(0.4425956738768719, 0.045454545454545456, 'squared_error = 0.0\nsamples = 660\nvalue = 0.994'),
#  Text(0.4459234608985025, 0.045454545454545456, 'squared_error = 0.002\nsamples = 308\nvalue = 0.974'),
#  Text(0.45341098169717137, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.023\nsamples = 759\nvalue = 0.901'),
#  Text(0.4492512479201331, 0.22727272727272727, 'ua <= 3.24\nsquared_error = 0.08\nsamples = 67\nvalue = 0.701'),
#  Text(0.4475873544093178, 0.13636363636363635, 'squared_error = 0.048\nsamples = 37\nvalue = 0.792'),
#  Text(0.4509151414309484, 0.13636363636363635, 'squared_error = 0.096\nsamples = 30\nvalue = 0.588'),
#  Text(0.45757071547420963, 0.22727272727272727, 'hus <= 0.002\nsquared_error = 0.013\nsamples = 692\nvalue = 0.921'),
#  Text(0.454242928452579, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.029\nsamples = 104\nvalue = 0.778'),
#  Text(0.4525790349417637, 0.045454545454545456, 'squared_error = 0.012\nsamples = 70\nvalue = 0.836'),
#  Text(0.4559068219633943, 0.045454545454545456, 'squared_error = 0.042\nsamples = 34\nvalue = 0.66'),
#  Text(0.46089850249584025, 0.13636363636363635, 'hus <= 0.003\nsquared_error = 0.006\nsamples = 588\nvalue = 0.946'),
#  Text(0.45923460898502494, 0.045454545454545456, 'squared_error = 0.008\nsamples = 306\nvalue = 0.921'),
#  Text(0.46256239600665555, 0.045454545454545456, 'squared_error = 0.003\nsamples = 282\nvalue = 0.972'),
#  Text(0.4862728785357737, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.085\nsamples = 2477\nvalue = 0.754'),
#  Text(0.4750415973377704, 0.3181818181818182, 'RH <= 98.869\nsquared_error = 0.091\nsamples = 2058\nvalue = 0.714'),
#  Text(0.47088186356073214, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.106\nsamples = 934\nvalue = 0.625'),
#  Text(0.46755407653910147, 0.13636363636363635, 'ta <= 267.868\nsquared_error = 0.137\nsamples = 266\nvalue = 0.463'),
#  Text(0.46589018302828616, 0.045454545454545456, 'squared_error = 0.127\nsamples = 234\nvalue = 0.508'),
#  Text(0.46921797004991683, 0.045454545454545456, 'squared_error = 0.091\nsamples = 32\nvalue = 0.138'),
#  Text(0.47420965058236275, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.08\nsamples = 668\nvalue = 0.69'),
#  Text(0.47254575707154745, 0.045454545454545456, 'squared_error = 0.09\nsamples = 81\nvalue = 0.487'),
#  Text(0.47587354409317806, 0.045454545454545456, 'squared_error = 0.072\nsamples = 587\nvalue = 0.718'),
#  Text(0.47920133111480867, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.066\nsamples = 1124\nvalue = 0.788'),
# ...
#  Text(0.7587354409317804, 0.045454545454545456, 'squared_error = 0.002\nsamples = 130\nvalue = 0.978'),
#  Text(0.7637271214642263, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.011\nsamples = 2143\nvalue = 0.925'),
#  Text(0.762063227953411, 0.045454545454545456, 'squared_error = 0.011\nsamples = 1837\nvalue = 0.916'),
#  Text(0.7653910149750416, 0.045454545454545456, 'squared_error = 0.003\nsamples = 306\nvalue = 0.982'),
#  Text(0.7803660565723793, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 33336\nvalue = 0.99'),
#  Text(0.7737104825291181, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 11727\nvalue = 0.98'),
#  Text(0.7703826955074875, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.0\nsamples = 6193\nvalue = 0.989'),
#  Text(0.7687188019966722, 0.045454545454545456, 'squared_error = 0.0\nsamples = 4526\nvalue = 0.987'),
#  Text(0.7720465890183028, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1667\nvalue = 0.994'),
#  Text(0.7770382695507487, 0.13636363636363635, 'ta <= 249.476\nsquared_error = 0.002\nsamples = 5534\nvalue = 0.971'),
#  Text(0.7753743760399334, 0.045454545454545456, 'squared_error = 0.028\nsamples = 31\nvalue = 0.843'),
#  Text(0.778702163061564, 0.045454545454545456, 'squared_error = 0.002\nsamples = 5503\nvalue = 0.971'),
#  Text(0.7870216306156406, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 21609\nvalue = 0.996'),
#  Text(0.78369384359401, 0.13636363636363635, 'ta <= 255.747\nsquared_error = 0.0\nsamples = 7235\nvalue = 0.992'),
#  Text(0.7820299500831946, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1109\nvalue = 0.982'),
#  Text(0.7853577371048253, 0.045454545454545456, 'squared_error = 0.0\nsamples = 6126\nvalue = 0.993'),
#  Text(0.7903494176372712, 0.13636363636363635, 'ta <= 251.794\nsquared_error = 0.0\nsamples = 14374\nvalue = 0.997'),
#  Text(0.7886855241264559, 0.045454545454545456, 'squared_error = 0.0\nsamples = 283\nvalue = 0.986'),
#  Text(0.7920133111480865, 0.045454545454545456, 'squared_error = 0.0\nsamples = 14091\nvalue = 0.998'),
#  Text(0.8946547420965059, 0.5909090909090909, 'ta <= 266.456\nsquared_error = 0.0\nsamples = 4338217\nvalue = 1.0'),
#  Text(0.8425540765391015, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.003\nsamples = 99300\nvalue = 0.988'),
#  Text(0.8182196339434277, 0.4090909090909091, 'qr+qg+qs <= 0.0\nsquared_error = 0.046\nsamples = 4492\nvalue = 0.895'),
#  Text(0.8069883527454242, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.004\nsamples = 3303\nvalue = 0.966'),
#  Text(0.800332778702163, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 2466\nvalue = 0.984'),
#  Text(0.7970049916805324, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 1459\nvalue = 0.994'),
#  Text(0.7953410981697171, 0.045454545454545456, 'squared_error = 0.0\nsamples = 930\nvalue = 0.996'),
#  Text(0.7986688851913477, 0.045454545454545456, 'squared_error = 0.0\nsamples = 529\nvalue = 0.989'),
#  Text(0.8036605657237936, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.001\nsamples = 1007\nvalue = 0.97'),
#  Text(0.8019966722129783, 0.045454545454545456, 'squared_error = 0.001\nsamples = 411\nvalue = 0.954'),
#  Text(0.8053244592346089, 0.045454545454545456, 'squared_error = 0.001\nsamples = 596\nvalue = 0.98'),
#  Text(0.8136439267886856, 0.22727272727272727, 'hus <= 0.002\nsquared_error = 0.01\nsamples = 837\nvalue = 0.913'),
#  Text(0.8103161397670549, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.016\nsamples = 292\nvalue = 0.862'),
#  Text(0.8086522462562395, 0.045454545454545456, 'squared_error = 0.006\nsamples = 206\nvalue = 0.9'),
#  Text(0.8119800332778702, 0.045454545454545456, 'squared_error = 0.027\nsamples = 86\nvalue = 0.771'),
#  Text(0.8169717138103162, 0.13636363636363635, 'hus <= 0.004\nsquared_error = 0.005\nsamples = 545\nvalue = 0.94'),
#  Text(0.8153078202995009, 0.045454545454545456, 'squared_error = 0.005\nsamples = 463\nvalue = 0.931'),
#  Text(0.8186356073211315, 0.045454545454545456, 'squared_error = 0.0\nsamples = 82\nvalue = 0.989'),
#  Text(0.829450915141431, 0.3181818181818182, 'RH <= 98.618\nsquared_error = 0.109\nsamples = 1189\nvalue = 0.7'),
#  Text(0.8252911813643927, 0.22727272727272727, 'clat <= -0.485\nsquared_error = 0.131\nsamples = 130\nvalue = 0.175'),
#  Text(0.8236272878535774, 0.13636363636363635, 'va <= -2.497\nsquared_error = 0.027\nsamples = 87\nvalue = 0.041'),
#  Text(0.8219633943427621, 0.045454545454545456, 'squared_error = 0.0\nsamples = 53\nvalue = 0.0'),
#  Text(0.8252911813643927, 0.045454545454545456, 'squared_error = 0.062\nsamples = 34\nvalue = 0.106'),
#  Text(0.826955074875208, 0.13636363636363635, 'squared_error = 0.232\nsamples = 43\nvalue = 0.446'),
#  Text(0.8336106489184693, 0.22727272727272727, 'clat <= -0.796\nsquared_error = 0.069\nsamples = 1059\nvalue = 0.764'),
#  Text(0.8302828618968386, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.081\nsamples = 353\nvalue = 0.641'),
#  Text(0.8286189683860233, 0.045454545454545456, 'squared_error = 0.068\nsamples = 71\nvalue = 0.386'),
#  Text(0.831946755407654, 0.045454545454545456, 'squared_error = 0.064\nsamples = 282\nvalue = 0.705'),
#  Text(0.8369384359400999, 0.13636363636363635, 'hus <= 0.004\nsquared_error = 0.051\nsamples = 706\nvalue = 0.826'),
#  Text(0.8352745424292846, 0.045454545454545456, 'squared_error = 0.059\nsamples = 526\nvalue = 0.786'),
#  Text(0.8386023294509152, 0.045454545454545456, 'squared_error = 0.011\nsamples = 180\nvalue = 0.942'),
#  Text(0.8668885191347754, 0.4090909090909091, 'clw+cli <= 0.0\nsquared_error = 0.001\nsamples = 94808\nvalue = 0.993'),
#  Text(0.8535773710482529, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.005\nsamples = 11289\nvalue = 0.968'),
#  Text(0.8469217970049917, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 8900\nvalue = 0.985'),
#  Text(0.8435940099833611, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 6752\nvalue = 0.991'),
#  Text(0.8419301164725458, 0.045454545454545456, 'squared_error = 0.0\nsamples = 4073\nvalue = 0.996'),
#  Text(0.8452579034941764, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2679\nvalue = 0.984'),
#  Text(0.8502495840266223, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.002\nsamples = 2148\nvalue = 0.963'),
#  Text(0.848585690515807, 0.045454545454545456, 'squared_error = 0.004\nsamples = 477\nvalue = 0.927'),
#  Text(0.8519134775374376, 0.045454545454545456, 'squared_error = 0.001\nsamples = 1671\nvalue = 0.974'),
#  Text(0.8602329450915142, 0.22727272727272727, 'pfull <= 84722.027\nsquared_error = 0.017\nsamples = 2389\nvalue = 0.907'),
#  Text(0.8569051580698835, 0.13636363636363635, 'hus <= 0.004\nsquared_error = 0.014\nsamples = 1824\nvalue = 0.93'),
#  Text(0.8552412645590682, 0.045454545454545456, 'squared_error = 0.017\nsamples = 1283\nvalue = 0.911'),
#  Text(0.8585690515806988, 0.045454545454545456, 'squared_error = 0.002\nsamples = 541\nvalue = 0.976'),
#  Text(0.8635607321131448, 0.13636363636363635, 'cllvi+clivi <= 0.116\nsquared_error = 0.02\nsamples = 565\nvalue = 0.834'),
#  Text(0.8618968386023295, 0.045454545454545456, 'squared_error = 0.021\nsamples = 374\nvalue = 0.797'),
#  Text(0.8652246256239601, 0.045454545454545456, 'squared_error = 0.009\nsamples = 191\nvalue = 0.907'),
#  Text(0.8801996672212978, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 83519\nvalue = 0.996'),
#  Text(0.8735440931780366, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 19369\nvalue = 0.99'),
#  Text(0.870216306156406, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 14535\nvalue = 0.994'),
#  Text(0.8685524126455907, 0.045454545454545456, 'squared_error = 0.0\nsamples = 9102\nvalue = 0.997'),
#  Text(0.8718801996672213, 0.045454545454545456, 'squared_error = 0.0\nsamples = 5433\nvalue = 0.99'),
#  Text(0.8768718801996672, 0.13636363636363635, 'hus <= 0.002\nsquared_error = 0.001\nsamples = 4834\nvalue = 0.977'),
#  Text(0.8752079866888519, 0.045454545454545456, 'squared_error = 0.002\nsamples = 899\nvalue = 0.951'),
#  Text(0.8785357737104825, 0.045454545454545456, 'squared_error = 0.001\nsamples = 3935\nvalue = 0.983'),
#  Text(0.8868552412645591, 0.22727272727272727, 'hus <= 0.002\nsquared_error = 0.0\nsamples = 64150\nvalue = 0.998'),
#  Text(0.8835274542429284, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 12415\nvalue = 0.995'),
#  Text(0.8818635607321131, 0.045454545454545456, 'squared_error = 0.0\nsamples = 9905\nvalue = 0.996'),
#  Text(0.8851913477537438, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2510\nvalue = 0.99'),
#  Text(0.8901830282861897, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 51735\nvalue = 0.999'),
#  Text(0.8885191347753744, 0.045454545454545456, 'squared_error = 0.0\nsamples = 16762\nvalue = 0.997'),
#  Text(0.891846921797005, 0.045454545454545456, 'squared_error = 0.0\nsamples = 34973\nvalue = 0.999'),
#  Text(0.9467554076539102, 0.5, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 4238917\nvalue = 1.0'),
#  Text(0.9201331114808652, 0.4090909090909091, 'ta <= 268.939\nsquared_error = 0.002\nsamples = 45136\nvalue = 0.993'),
#  Text(0.9068219633943427, 0.3181818181818182, 'qr+qg+qs <= 0.0\nsquared_error = 0.01\nsamples = 5897\nvalue = 0.956'),
#  Text(0.9001663893510815, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 3325\nvalue = 0.99'),
#  Text(0.8968386023294509, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 2543\nvalue = 0.996'),
#  Text(0.8951747088186356, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1955\nvalue = 0.998'),
#  Text(0.8985024958402662, 0.045454545454545456, 'squared_error = 0.0\nsamples = 588\nvalue = 0.99'),
#  Text(0.9034941763727121, 0.13636363636363635, 'cllvi+clivi <= 0.123\nsquared_error = 0.002\nsamples = 782\nvalue = 0.97'),
#  Text(0.9018302828618968, 0.045454545454545456, 'squared_error = 0.002\nsamples = 446\nvalue = 0.957'),
#  Text(0.9051580698835274, 0.045454545454545456, 'squared_error = 0.001\nsamples = 336\nvalue = 0.986'),
#  Text(0.913477537437604, 0.22727272727272727, 'hus <= 0.003\nsquared_error = 0.02\nsamples = 2572\nvalue = 0.913'),
#  Text(0.9101497504159733, 0.13636363636363635, 'clat <= -1.08\nsquared_error = 0.05\nsamples = 418\nvalue = 0.79'),
#  Text(0.908485856905158, 0.045454545454545456, 'squared_error = 0.071\nsamples = 157\nvalue = 0.677'),
#  Text(0.9118136439267887, 0.045454545454545456, 'squared_error = 0.025\nsamples = 261\nvalue = 0.858'),
#  Text(0.9168053244592346, 0.13636363636363635, 'hus <= 0.004\nsquared_error = 0.01\nsamples = 2154\nvalue = 0.937'),
#  Text(0.9151414309484193, 0.045454545454545456, 'squared_error = 0.013\nsamples = 1354\nvalue = 0.914'),
#  Text(0.9184692179700499, 0.045454545454545456, 'squared_error = 0.003\nsamples = 800\nvalue = 0.976'),
#  Text(0.9334442595673876, 0.3181818181818182, 'ta <= 270.34\nsquared_error = 0.0\nsamples = 39239\nvalue = 0.998'),
#  Text(0.9267886855241264, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.002\nsamples = 3111\nvalue = 0.984'),
#  Text(0.9234608985024958, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 1689\nvalue = 0.996'),
#  Text(0.9217970049916805, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1350\nvalue = 0.998'),
#  Text(0.9251247920133111, 0.045454545454545456, 'squared_error = 0.001\nsamples = 339\nvalue = 0.988'),
#  Text(0.930116472545757, 0.13636363636363635, 'clat <= -0.847\nsquared_error = 0.003\nsamples = 1422\nvalue = 0.969'),
#  Text(0.9284525790349417, 0.045454545454545456, 'squared_error = 0.004\nsamples = 663\nvalue = 0.951'),
#  Text(0.9317803660565723, 0.045454545454545456, 'squared_error = 0.001\nsamples = 759\nvalue = 0.985'),
#  Text(0.940099833610649, 0.22727272727272727, 'ta <= 271.632\nsquared_error = 0.0\nsamples = 36128\nvalue = 0.999'),
#  Text(0.9367720465890182, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 3124\nvalue = 0.995'),
#  Text(0.9351081530782029, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1644\nvalue = 0.999'),
#  Text(0.9384359400998337, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1480\nvalue = 0.991'),
#  Text(0.9434276206322796, 0.13636363636363635, 'ta <= 272.775\nsquared_error = 0.0\nsamples = 33004\nvalue = 1.0'),
#  Text(0.9417637271214643, 0.045454545454545456, 'squared_error = 0.0\nsamples = 3118\nvalue = 0.999'),
#  Text(0.9450915141430949, 0.045454545454545456, 'squared_error = 0.0\nsamples = 29886\nvalue = 1.0'),
#  Text(0.9733777038269551, 0.4090909090909091, 'ta <= 268.503\nsquared_error = 0.0\nsamples = 4193781\nvalue = 1.0'),
#  Text(0.9600665557404326, 0.3181818181818182, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 119244\nvalue = 0.998'),
#  Text(0.9534109816971714, 0.22727272727272727, 'qr+qg+qs <= 0.0\nsquared_error = 0.001\nsamples = 8686\nvalue = 0.985'),
#  Text(0.9500831946755408, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 5414\nvalue = 0.996'),
#  Text(0.9484193011647255, 0.045454545454545456, 'squared_error = 0.0\nsamples = 4439\nvalue = 0.998'),
#  Text(0.9517470881863561, 0.045454545454545456, 'squared_error = 0.0\nsamples = 975\nvalue = 0.987'),
#  Text(0.956738768718802, 0.13636363636363635, 'clat <= -0.84\nsquared_error = 0.003\nsamples = 3272\nvalue = 0.968'),
#  Text(0.9550748752079867, 0.045454545454545456, 'squared_error = 0.005\nsamples = 741\nvalue = 0.934'),
#  Text(0.9584026622296173, 0.045454545454545456, 'squared_error = 0.002\nsamples = 2531\nvalue = 0.978'),
#  Text(0.9667221297836939, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 110558\nvalue = 0.999'),
#  Text(0.9633943427620633, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 11976\nvalue = 0.995'),
#  Text(0.961730449251248, 0.045454545454545456, 'squared_error = 0.0\nsamples = 7374\nvalue = 0.999'),
#  Text(0.9650582362728786, 0.045454545454545456, 'squared_error = 0.0\nsamples = 4602\nvalue = 0.989'),
#  Text(0.9700499168053245, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 98582\nvalue = 0.999'),
#  Text(0.9683860232945092, 0.045454545454545456, 'squared_error = 0.0\nsamples = 19799\nvalue = 0.998'),
#  Text(0.9717138103161398, 0.045454545454545456, 'squared_error = 0.0\nsamples = 78783\nvalue = 1.0'),
#  Text(0.9866888519134775, 0.3181818181818182, 'ta <= 270.248\nsquared_error = 0.0\nsamples = 4074537\nvalue = 1.0'),
#  Text(0.9800332778702163, 0.22727272727272727, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 108308\nvalue = 0.999'),
#  Text(0.9767054908485857, 0.13636363636363635, 'qr+qg+qs <= 0.0\nsquared_error = 0.0\nsamples = 7331\nvalue = 0.994'),
#  Text(0.9750415973377704, 0.045454545454545456, 'squared_error = 0.0\nsamples = 4336\nvalue = 0.998'),
#  Text(0.978369384359401, 0.045454545454545456, 'squared_error = 0.001\nsamples = 2995\nvalue = 0.988'),
#  Text(0.9833610648918469, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 100977\nvalue = 1.0'),
#  Text(0.9816971713810316, 0.045454545454545456, 'squared_error = 0.0\nsamples = 9952\nvalue = 0.999'),
#  Text(0.9850249584026622, 0.045454545454545456, 'squared_error = 0.0\nsamples = 91025\nvalue = 1.0'),
#  Text(0.9933444259567388, 0.22727272727272727, 'hus <= 0.004\nsquared_error = 0.0\nsamples = 3966229\nvalue = 1.0'),
#  Text(0.9900166389351082, 0.13636363636363635, 'clw+cli <= 0.0\nsquared_error = 0.0\nsamples = 13017\nvalue = 0.999'),
#  Text(0.9883527454242929, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1632\nvalue = 0.997'),
#  Text(0.9916805324459235, 0.045454545454545456, 'squared_error = 0.0\nsamples = 11385\nvalue = 1.0'),
#  Text(0.9966722129783694, 0.13636363636363635, 'ta <= 272.031\nsquared_error = 0.0\nsamples = 3953212\nvalue = 1.0'),
#  Text(0.9950083194675541, 0.045454545454545456, 'squared_error = 0.0\nsamples = 91214\nvalue = 1.0'),
#  Text(0.9983361064891847, 0.045454545454545456, 'squared_error = 0.0\nsamples = 3861998\nvalue = 1.0')]

# %%
#Prediction
prediction_start_time = time.time()
y_pred = reg.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
# Out:
# Prediction- Elapsed time: 0.0009 minutes

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
#Error Analysis on TEST data
#MSE_test
mse_TEST= np.mean((y_test- y_pred)**2)
print(f'MSE_TEST: {mse_TEST}')

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')
# print(f'MSE_TEST: {(rmse_TEST)**2}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score before CCP:", r2_sklearn)
# Out:
# MSE_TEST: 0.000312904981420865
# RMSE_TEST: 0.01768912042530281
# mae_TEST: 0.0012446560379774448
# R² score before CCP: 0.9957574532874637

# %%
# #Pathway-1
# #This seems more robust because it uses CV and not test data to determine the best ccp_alpha

# ccp_path = reg.cost_complexity_pruning_path(X_train, y_train)

# kfold = skm.KFold(5,
# shuffle=True,
# random_state=10)

# grid = skm.GridSearchCV(reg,
# {'ccp_alpha': ccp_path.ccp_alphas},
# refit=True,
# cv=kfold,
# scoring='r2',
# n_jobs=-1)

# G = grid.fit(X_train, y_train)

# best_ = grid.best_estimator_
# print(best_)

# depth = best_.get_depth()
# print(depth)

# %%
# #Pathway-1
# #Plot the best tree
# ax= subplots(figsize=(12,12))[1]
# plot_tree(G.best_estimator_, feature_names=feature_names, ax=ax) #after ccp

# %%
# # ##Prediction
# prediction_start_time = time.time()
# y_pred = best_.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# #########################################
# print('size of y_pred: ', len(y_pred))

# %%
# #Comment this block if you do CCP

# ##Prediction
# prediction_start_time = time.time()
# y_pred = reg.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# #########################################
# print('size of y_pred: ', len(y_pred))

# %%
# #Error Analysis on TEST data
# #MSE_test
# mse_TEST= np.mean((y_test- y_pred)**2)
# print(f'MSE_TEST: {mse_TEST}')

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
# print(f'RMSE_TEST: {rmse_TEST}')
# # print(f'MSE_TEST: {(rmse_TEST)**2}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_pred))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_pred)
# print("R² score:", r2_sklearn)

# %%
# #If CCP:

# # # #DT-feature importances in descending order
# # importance = best_.feature_importances_
# # feature_scores= list(zip(feature_names, importance))
# # feature_scores.sort(key=lambda x: x[1], reverse= True)
# for name, score in feature_scores:
#     pct = score*100
#     print(f'{name}:{pct:.4f} %')

# If no CCP:
## DT-feature importances in descending order
importance = reg.feature_importances_
feature_scores= list(zip(feature_names, importance))
feature_scores.sort(key=lambda x: x[1], reverse= True)
for name, score in feature_scores:
    pct = score*100
    print(f'{name}:{pct:.4f} %')
# Out:
# RH:97.9733 %
# ta:1.0879 %
# clw+cli:0.5948 %
# qr+qg+qs:0.2317 %
# hus:0.0440 %
# pfull:0.0295 %
# wa:0.0230 %
# clat:0.0078 %
# cllvi+clivi:0.0048 %
# clon:0.0016 %
# ua:0.0010 %
# va:0.0006 %

# %%
import matplotlib.pyplot as plt

# Your existing logic
importance = reg.feature_importances_
feature_scores = list(zip(feature_names, importance))
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f'{name}:{pct:.4f} %')

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Cloud\ water\ fraction}$ determination using $\mathbf{Decision\ Tree}$")


# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of each bar
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,   # small space after bar
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis from 0 to 100
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# RH:97.9733 %
# ta:1.0879 %
# clw+cli:0.5948 %
# qr+qg+qs:0.2317 %
# hus:0.0440 %
# pfull:0.0295 %
# wa:0.0230 %
# clat:0.0078 %
# cllvi+clivi:0.0048 %
# clon:0.0016 %
# ua:0.0010 %
# va:0.0006 %

# %%
# best_ccp_alpha= best_.ccp_alpha
# best_ccp_alpha

# %% [markdown]
# Bagging

# %%
#expt with min_sample_leaf = 50, etc.

# %%
# #for loop to see at what n_estimators the validation error converges

# X_train_sub, X_val, y_train_sub, y_val=train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# prev_validation_r2_score=0 #Initialized arbitrarily to 0 to run the first tree in the for loop 
# diff=1 # difference between R2 scores of the previous and the current tree. Initialized arbitrarily to 1 to run the first tree in the for loop 
# upper_bound_n_trees=201
# x_axis= range(1,upper_bound_n_trees)
# threshold= 1E-7 ###1E-7
# train_sub_r2_scores=[]
# validation_r2_scores=[]
# for n_trees in x_axis:
        
#         # print("Diff= ", diff)
#         if(diff<threshold):
#                 print(f"Converged at {n_trees-1} trees")
#                 ideal_n_trees= n_trees-1
#                 break


#         #Bagging
#         model = RandomForestRegressor(n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf ,n_estimators=n_trees, oob_score=True) #can set verbose=2 to see the steps 

#         ##Training
#         model.fit(X_train_sub, y_train_sub)

#         train_sub_r2= model.score(X_train_sub, y_train_sub)
#         validation_r2 = model.score(X_val, y_val)

#         train_sub_r2_scores.append(train_sub_r2)
#         validation_r2_scores.append(validation_r2)

#         diff= abs(validation_r2 - prev_validation_r2_score)
#         prev_validation_r2_score=validation_r2

# n_trees_for_which_max_r2 = x_axis[validation_r2_scores.index(max(validation_r2_scores))]


# print(f"Best number of trees (based on validation data): {n_trees_for_which_max_r2}")
# print(f"Best validation R² score: {max(validation_r2_scores)}")

# if(diff>=threshold):
#                 ideal_n_trees= upper_bound_n_trees-1

# plt.figure(figsize=(8,5))
# plt.plot(range(1, len(train_sub_r2_scores)+1 ), train_sub_r2_scores, marker='o', label='Training R2')
# plt.plot(range(1, len(validation_r2_scores)+1 ), validation_r2_scores, marker='s', label='Validation R2')
# plt.xlabel('Number of Trees')
# plt.ylabel('R2 Score')
# plt.title('R2 score vs number of trees')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
#Bagging
ideal_n_trees=100
model = RandomForestRegressor(n_jobs=-1, random_state=0, max_depth=best_depth, n_estimators=ideal_n_trees, oob_score=True, min_samples_leaf=best_min_samples_leaf) #can set verbose=2 to see the steps 

##Training
training_start_time = time.time()
model.fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

##Prediction
prediction_start_time = time.time()
y_pred = model.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
 

#Error Analysis on TEST data
#MSE_test
MSE_Test = np.mean((y_test - y_pred)**2)
print(f'MSE_Test: {MSE_Test}')

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score (sklearn):", r2_sklearn)
# Out:
# Training- Elapsed time: 4.7428 minutes
# Prediction- Elapsed time: 0.0039 minutes
# MSE_Test: 0.00026679526840206913
# RMSE_TEST: 0.016333868751831855
# mae_TEST: 0.001196667247928036
# R² score (sklearn): 0.9963826354449851

# %%
#Bagging ft. importance in descending order
#Sort indices by importance
sorted_idx = np.argsort(model.feature_importances_)[::-1]

#print("\nAll features sorted by importance:")
for i in sorted_idx:
    print(f"{feature_names[i]}: {model.feature_importances_[i]:.4f}")
# Out:
# RH: 0.9799
# ta: 0.0108
# clw+cli: 0.0057
# qr+qg+qs: 0.0024
# hus: 0.0004
# pfull: 0.0003
# wa: 0.0002
# clat: 0.0001
# cllvi+clivi: 0.0000
# clon: 0.0000
# ua: 0.0000
# va: 0.0000

# %%
#Bagging ft. importance in descending order
#Sort indices by importance
sorted_idx = np.argsort(model.feature_importances_)[::-1]

#print("\nAll features sorted by importance:")
for i in sorted_idx:
    pct=model.feature_importances_[i] * 100
    print(f"{feature_names[i]}: {pct:.4f} %")
# Out:
# RH: 97.9915 %
# ta: 1.0832 %
# clw+cli: 0.5689 %
# qr+qg+qs: 0.2447 %
# hus: 0.0440 %
# pfull: 0.0267 %
# wa: 0.0237 %
# clat: 0.0098 %
# cllvi+clivi: 0.0044 %
# clon: 0.0015 %
# ua: 0.0010 %
# va: 0.0005 %

# %%
sorted_idx = np.argsort(model.feature_importances_)[::-1]

names = []
importances = []

for i in sorted_idx:
    pct = model.feature_importances_[i] * 100
    names.append(feature_names[i])
    importances.append(pct)
    print(f"{feature_names[i]}: {pct:.4f} %")

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Cloud\ water\ fraction}$ determination using $\mathbf{Bagging}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of bars
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis from 0 to 100
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# RH: 97.9915 %
# ta: 1.0832 %
# clw+cli: 0.5689 %
# qr+qg+qs: 0.2447 %
# hus: 0.0440 %
# pfull: 0.0267 %
# wa: 0.0237 %
# clat: 0.0098 %
# cllvi+clivi: 0.0044 %
# clon: 0.0015 %
# ua: 0.0010 %
# va: 0.0005 %

# %%
# # Bagging with CCP

# ideal_n_trees=100
# #I am using the best_ccp_alpha I got from a single Decision Tree using CV
# model = RandomForestRegressor(ccp_alpha=best_ccp_alpha, n_jobs=-1, random_state=0, max_depth=best_depth, n_estimators=ideal_n_trees, oob_score=True, min_samples_leaf=best_min_samples_leaf) #can set verbose=2 to see the steps 

# ##Training
# training_start_time = time.time()
# model.fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

# ##Prediction
# prediction_start_time = time.time()
# y_pred = model.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
 

# #Error Analysis on TEST data
# #MSE_test
# MSE_Test = np.mean((y_test - y_pred)**2)
# print(f'MSE_Test: {MSE_Test}')

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_pred))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_pred)
# print("R² score (sklearn):", r2_sklearn)

# %%
# #Bagging ft. importance in descending order
# #Sort indices by importance
# sorted_idx = np.argsort(model.feature_importances_)[::-1]

# #print("\nAll features sorted by importance:")
# for i in sorted_idx:
#     print(f"{feature_names[i]}: {model.feature_importances_[i]:.4f}")

# %% [markdown]
# Random Forest

# %% [markdown]
# #Bagging Code 2

# %% [markdown]
# Random Forest

# %%
# #ideal num of trees for Random Forest
# #for loop to see at what n_estimators the validation error converges

# X_train_sub, X_val, y_train_sub, y_val=train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# prev_validation_r2_score=0 #Initialized arbitrarily to 0 to run the first tree in the for loop 
# diff=1 # difference between R2 scores of the previous and the current tree. Initialized arbitrarily to 1 to run the first tree in the for loop 
# upper_bound_n_trees=201
# x_axis= range(1,upper_bound_n_trees)
# threshold= 1E-7 #1E-7
# train_sub_r2_scores=[]
# validation_r2_scores=[]
# for n_trees in x_axis:
        
#         # print("Diff= ", diff)
#         if(diff<threshold):
#                 print(f"Converged at {n_trees-1} trees")
#                 ideal_n_trees= n_trees-1
#                 break


#         #Bagging
#         model = RandomForestRegressor(n_jobs=-1, random_state=0, max_features=int(np.sqrt(X_train.shape[1])), max_depth=best_depth, min_samples_leaf=best_min_samples_leaf ,n_estimators=n_trees, oob_score=True) #can set verbose=2 to see the steps 

#         ##Training
#         model.fit(X_train_sub, y_train_sub)

#         train_sub_r2= model.score(X_train_sub, y_train_sub)
#         validation_r2 = model.score(X_val, y_val)

#         train_sub_r2_scores.append(train_sub_r2)
#         validation_r2_scores.append(validation_r2)

#         diff= abs(validation_r2 - prev_validation_r2_score)
#         prev_validation_r2_score=validation_r2

# n_trees_for_which_max_r2 = x_axis[validation_r2_scores.index(max(validation_r2_scores))]


# print(f"Best number of trees (based on validation data): {n_trees_for_which_max_r2}")
# print(f"Best validation R² score: {max(validation_r2_scores)}")

# if(diff>=threshold):
#                 ideal_n_trees= upper_bound_n_trees-1

# plt.figure(figsize=(8,5))
# plt.plot(range(1, len(train_sub_r2_scores)+1 ), train_sub_r2_scores, marker='o', label='Training R2')
# plt.plot(range(1, len(validation_r2_scores)+1 ), validation_r2_scores, marker='s', label='Validation R2')
# plt.xlabel('Number of Trees')
# plt.ylabel('R2 Score')
# plt.title('R2 score vs number of trees')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
#Random Forest
##Training
ideal_n_trees=100

training_start_time = time.time()
RF_condensates = RandomForestRegressor(n_estimators=ideal_n_trees, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
#RF_condensates = RandomForestRegressor(n_estimators=ideal_n_trees, max_features=int( np.floor(0.75 * X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
# RF_condensates = RF(n_estimators=200, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, oob_score=True).fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

##Prediction
prediction_start_time = time.time()
y_hat_RF = RF_condensates.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

print("max: ", np.max(y_hat_RF))
print("min: ", np.min(y_hat_RF))
# Out:
# Training- Elapsed time: 1.7265 minutes
# Prediction- Elapsed time: 0.0040 minutes
# max:  0.9999921202006238
# min:  6.24814186797273e-05

# %%
int( np.floor(0.75 * X_train.shape[1]))
# Out:
# 9

# %%
int(np.sqrt(X_train.shape[1]))
# Out:
# 3

# %%
RF_condensates
# Out:
# RandomForestRegressor(max_depth=10, max_features=3, min_samples_leaf=30,
#                       n_jobs=-1, oob_score=True, random_state=0)

# %%
# List of depths for all trees
tree_depths = [estimator.tree_.max_depth for estimator in RF_condensates.estimators_]

# Average, min, and max depth across the forest
print("Average depth:", sum(tree_depths) / len(tree_depths))
print("Min depth:", min(tree_depths))
print("Max depth:", max(tree_depths))
# Out:
# Average depth: 10.0
# Min depth: 10
# Max depth: 10

# %%
#Error Analysis on TEST data
#mse_Test
mse= np.mean((y_test- y_hat_RF)**2)
print('MSE: ', mse)

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_hat_RF)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_hat_RF))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_hat_RF)
print("R² score: ", r2_sklearn)
# Out:
# MSE:  0.0003051522612472539
# RMSE_TEST: 0.017468607879486387
# mae_TEST: 0.0016345276422137082
# R² score:  0.9958625691515077

# %%
#RF Ft. importance in descending order
importance = RF_condensates.feature_importances_

#Combine ft. names and scores
feature_scores = list(zip(feature_names, importance))

#Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

for name, score in feature_scores:
    print(f'{name}:{score:.6f}')
# Out:
# RH:0.313998
# hus:0.222999
# ta:0.198511
# pfull:0.135687
# clw+cli:0.092045
# cllvi+clivi:0.015733
# clat:0.008588
# qr+qg+qs:0.006580
# ua:0.004216
# wa:0.001153
# va:0.000281
# clon:0.000210

# %%
#RF Ft. importance in descending order
importance = RF_condensates.feature_importances_

#Combine ft. names and scores
feature_scores = list(zip(feature_names, importance))

#Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

for name, score in feature_scores:
    pct= score *100
    print(f'{name}:{pct:.4f} %')
# Out:
# RH:31.3998 %
# hus:22.2999 %
# ta:19.8511 %
# pfull:13.5687 %
# clw+cli:9.2045 %
# cllvi+clivi:1.5733 %
# clat:0.8588 %
# qr+qg+qs:0.6580 %
# ua:0.4216 %
# wa:0.1153 %
# va:0.0281 %
# clon:0.0210 %

# %%
importance = RF_condensates.feature_importances_

# Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

# Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Cloud\ water\ fraction}$ determination using $\mathbf{Random\ Forest}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels at the end of the bars
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis range from 0 to 100
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# RH: 31.3998 %
# hus: 22.2999 %
# ta: 19.8511 %
# pfull: 13.5687 %
# clw+cli: 9.2045 %
# cllvi+clivi: 1.5733 %
# clat: 0.8588 %
# qr+qg+qs: 0.6580 %
# ua: 0.4216 %
# wa: 0.1153 %
# va: 0.0281 %
# clon: 0.0210 %

# %%
# #Random Forest with CCP

# ##Training
# ideal_n_trees=100

# training_start_time = time.time()
# RF_condensates = RandomForestRegressor(ccp_alpha= best_ccp_alpha, n_estimators=ideal_n_trees, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
# #RF_condensates = RandomForestRegressor(n_estimators=ideal_n_trees, max_features=int( np.floor(0.75 * X_train.shape[1])), n_jobs=-1, random_state=0, max_depth=best_depth, min_samples_leaf=best_min_samples_leaf, oob_score=True).fit(X_train, y_train)
# # RF_condensates = RF(n_estimators=200, max_features=int(np.sqrt(X_train.shape[1])), n_jobs=-1, random_state=0, oob_score=True).fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

# ##Prediction
# prediction_start_time = time.time()
# y_hat_RF = RF_condensates.predict(X_test)
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# print("max: ", np.max(y_hat_RF))
# print("min: ", np.min(y_hat_RF))

# #Error Analysis on TEST data
# #mse_Test
# mse= np.mean((y_test- y_hat_RF)**2)
# print('MSE: ', mse)

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_hat_RF)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_hat_RF))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_hat_RF)
# print("R² score: ", r2_sklearn) #old value: 0.9922993421321149

# %%
# #RF Ft. importance in descending order
# importance = RF_condensates.feature_importances_

# #Combine ft. names and scores
# feature_scores = list(zip(feature_names, importance))

# #Sort by score in descending order
# feature_scores.sort(key=lambda x: x[1], reverse=True)

# for name, score in feature_scores:
#     print(f'{name}:{score:.6f}')

# %% [markdown]
# Boosting

# %%
#Method 1: Using GridSearchCV
# from sklearn.model_selection import GridSearchCV

# param_grid ={
#     'n_estimators':[100,200],
#     'learning_rate':[0.01, 0.1, 0.5],
#     'max_depth': [5,7,10,12], #add more depths later
#     'min_samples_leaf' :[10, 30] 
# }

# gb_model= GBR()

# grid_search= GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1)

# grid_search.fit(X_train, y_train)

# best_params = grid_search.best_params_
# best_model = grid_search.best_estimator_

# y_pred_best = best_model.predict(X_test)

# r2_best = r2_score(y_test, y_pred_best)

# print('Best parameters: ', best_params)
# print(f'Best Model R2 score: {r2_best}')

# %%
#Method 2: Best hyperparameters using RandomizedSeachCV

# from sklearn.model_selection import RandomizedSearchCV

# param_dist ={
#     'n_estimators':[100,200],
#     'learning_rate': np.arange(0.01,0.1, 0.5),
#     'max_depth': [5,7,10,12], #add more depths later
#     'min_samples_leaf' :[10, 30] 
# }

# gb_model = GBR()

# random_search= RandomizedSearchCV(estimator=gb_model, param_distributions=param_dist, n_iter=10, cv=5, scoring='r2', n_jobs=-1)

# random_search.fit(X_train, y_train)

# best_params= random_search.best_params_
# best_model= random_search.best_estimator_

# y_pred_best= best_model.predict(X_test)
# r2_best = r2_score(y_test, y_pred_best)

# print("Best parameters: ", best_params)
# print(f"Best Model R2 Score: {r2_best}")

# %%
# #Use this block-1

# #Use grid search's best parameters!
# best_n_trees=100 #best_params['n_estimators']
# best_min_samples_leaf=30 #best_params['min_samples_leaf']
# best_max_depth=10 #best_params['max_depth']
# best_learning_rate= 0.1 #best_params['learning_rate']

# %%
# #Use this block-2

# #Boosting
# boost_condensates=GBR(random_state=0, n_estimators=best_n_trees, learning_rate=best_learning_rate, min_samples_leaf=best_min_samples_leaf, max_depth=best_max_depth)

# ##Training
# training_start_time = time.time()
# boost_condensates.fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes") #73 mins and countiung, then disconnected.
# #Total elapsed time: 163.8 mins

# %%
# #Use this block

# #x axis: boosting iteration number
# test_error = np.zeros_like(boost_condensates.train_score_)
# for idx, y_ in enumerate(boost_condensates.staged_predict(X_test)):
#     ######################################################
#     #####################################################
#     count=0
#     for i in y_:
#         if i>1 or i<0:
#             # print(i)
#             count+=1
#     print(f"Iteration {idx} incorrect count = ", count)
#     print("incorrect count percent = ", 100*count/len(y_))
#     #####################################################
#     y_ = np.clip(y_, 0, 1)
#     ######################################################
#     test_error[idx] = np.mean((y_test- y_)**2)
# plot_idx = np.arange(boost_condensates.train_score_.shape[0])
# ax = subplots(figsize=(8,8))[1]
# ax.plot(plot_idx,
# boost_condensates.train_score_,
# 'b',
# label='Training')

# ax.plot(plot_idx,
# test_error,
# 'r',
# label='Test')
# ax.legend();

# ax.set_xlabel("Total number of trees")
# ax.set_ylabel("Mean Squared Error")

# # print("Shape:", boost_condensates.train_score_.shape) #iterations
# # print("Number of elements:", boost_condensates.train_score_.size)

# %%
# #Use this block-3

# ##Prediction
# prediction_start_time = time.time()
# y_hat_boost = boost_condensates.predict(X_test);
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# y_hat_boost = np.clip(y_hat_boost, 0, 1)
# #Error Analysis on TEST data
# #mse_test
# mse= np.mean((y_test- y_hat_boost)**2)
# print('MSE_Test: ', mse)

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_hat_boost)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_hat_boost))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_hat_boost)
# print("R² score: ", r2_sklearn)

# %%
# #Use this block-4

# #Boosting ft. importance in descending order
# importance = boost_condensates.feature_importances_

# #Combine ft. names and scores
# feature_scores = list(zip(feature_names, importance))

# #Sort by score in descending order
# feature_scores.sort(key=lambda x: x[1], reverse=True)

# for name, score in feature_scores:
#     print(f'{name}:{score:.6f}')

# %%
# #Boosting with CCP

# best_n_trees=100 #best_params['n_estimators']
# best_min_samples_leaf=30 #best_params['min_samples_leaf']
# best_max_depth=12 #best_params['max_depth']
# best_learning_rate= 0.1 #best_params['learning_rate']

# #Boosting
# boost_condensates=GBR(ccp_alpha=best_ccp_alpha, random_state=0, n_estimators=best_n_trees, learning_rate=best_learning_rate, min_samples_leaf=best_min_samples_leaf, max_depth=best_max_depth)

# ##Training
# training_start_time = time.time()
# boost_condensates.fit(X_train, y_train)
# training_end_time = time.time()
# training_elapsed_time = training_end_time - training_start_time
# print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes") #73 mins and countiung, then disconnected.

# #Training- Elapsed time: 150.0770 minutes (compute node)
# #Training- Elapsed time:  minutes (interactive node)

# %%
# #x axis: boosting iteration number
# test_error = np.zeros_like(boost_condensates.train_score_)
# for idx, y_ in enumerate(boost_condensates.staged_predict(X_test)):
#     ######################################################
#     #####################################################
#     count=0
#     for i in y_:
#         if i>1 or i<0:
#             # print(i)
#             count+=1
#     print(f"Iteration {idx} incorrect count = ", count)
#     print("incorrect count percent = ", 100*count/len(y_))
#     #####################################################
#     y_ = np.clip(y_, 0, 1)
#     ######################################################
#     test_error[idx] = np.mean((y_test- y_)**2)
# plot_idx = np.arange(boost_condensates.train_score_.shape[0])
# ax = subplots(figsize=(8,8))[1]
# ax.plot(plot_idx,
# boost_condensates.train_score_,
# 'b',
# label='Training')

# ax.plot(plot_idx,
# test_error,
# 'r',
# label='Test')
# ax.legend();

# ax.set_xlabel("Total number of trees")
# ax.set_ylabel("Mean Squared Error")


# # print("Shape:", boost_condensates.train_score_.shape) #iterations
# # print("Number of elements:", boost_condensates.train_score_.size)

# %%
# ##Prediction
# prediction_start_time = time.time()
# y_hat_boost = boost_condensates.predict(X_test);
# prediction_end_time = time.time()
# prediction_elapsed_time = prediction_end_time - prediction_start_time
# print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")

# y_hat_boost = np.clip(y_hat_boost, 0, 1)
# #Error Analysis on TEST data
# #mse_test
# mse= np.mean((y_test- y_hat_boost)**2)
# print('MSE_Test: ', mse)

# #rmse_test
# rmse_TEST = np.sqrt(np.mean((y_test - y_hat_boost)**2))
# print(f'RMSE_TEST: {rmse_TEST}')

# #mae_TEST
# mae_TEST = np.mean(abs(y_test - y_hat_boost))
# print(f'mae_TEST: {mae_TEST}')

# #R2_test_sklearn
# r2_sklearn = r2_score(y_test, y_hat_boost)
# print("R² score: ", r2_sklearn)

# %%
# #Boosting ft. importance in descending order
# importance = boost_condensates.feature_importances_

# #Combine ft. names and scores
# feature_scores = list(zip(feature_names, importance))

# #Sort by score in descending order
# feature_scores.sort(key=lambda x: x[1], reverse=True)

# for name, score in feature_scores:
#     print(f'{name}:{score:.6f}')

# %% [markdown]
# XGBoost

# %%
# #Method 1: Grid Search
# from sklearn.model_selection import GridSearchCV

# param_grid={
#     'n_estimators': [100, 200],
#     'max_depth': [5, 7, 10, 12],
#     'learning_rate': [0.01, 0.1, 0.2],
#     'min_child_weight': [10, 30]
# }


# xgb_model= xgb.XGBRegressor()

# grid_search= GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')


# grid_search.fit(X_train, y_train)

# print("Best set of hyperparameters: ", grid_search.best_params_)
# print("Best score: ", grid_search.best_score_)

# %%
# #n_estimators, eta/learning_rate, max_depth, min_child_weight?, max_bin (def=256)->increasing this number improves the optimality of splits at the cost of higher computation time.
# #Method 2: Random Search
# import scipy.stats as stats

# param_dist = {
#     'n_estimators': stats.randint(100, 201),
#     'max_depth': stats.randint(5,13),
#     'learning_rate': stats.uniform(0.01, 0.2),
#     'min_child_weight': stats.randint(10, 31)
#     }

# model = XGBRegressor()

# # Set up the random search with 4-fold cross validation
# random_cv = RandomizedSearchCV(random_state=1, estimator=model, param_distributions= param_dist, cv=5, n_iter=100, scoring='r2', n_jobs=-1, return_train_score= True)  #verbose=5

# random_cv.fit(X_train, y_train)

# print("Best set of hyperparameters: ", random_cv.best_params_)
# print("Best score: ", random_cv.best_score_)

# %%
#random_cv.best_estimator_

# %%
# best_parameters= grid_search.best_params_

best_n_estimators=100 #best_parameters['n_estimators']
best_min_child_weight=30 #best_parameters['min_child_weight']
best_max_depth=10 #best_parameters['max_depth']
best_learning_rate=0.1 #best_parameters['learning_rate']

# %%
#XGBoost

# fit model
model = XGBRegressor(n_estimators=best_n_estimators, min_child_weight= best_min_child_weight, max_depth=best_max_depth, learning_rate=best_learning_rate, n_jobs=-1, random_state=0) #verbosity=3 (optional)

##Training
training_start_time = time.time()
model.fit(X_train, y_train)
training_end_time = time.time()
training_elapsed_time = training_end_time - training_start_time
print(f"Training- Elapsed time: {training_elapsed_time/60:.4f} minutes")

##Prediction
prediction_start_time = time.time()
y_pred = model.predict(X_test)
prediction_end_time = time.time()
prediction_elapsed_time = prediction_end_time - prediction_start_time
print(f"Prediction- Elapsed time: {prediction_elapsed_time/60:.4f} minutes")
# Out:
# Training- Elapsed time: 0.1172 minutes
# Prediction- Elapsed time: 0.0018 minutes

# %%
print("max: ", np.max(y_pred))
print("min: ", np.min(y_pred))
# Out:
# max:  1.3701292
# min:  -0.18036012

# %%
# count=0
# for i in y_pred:
#     if i>1 or i<0:
#         # print(i)
#         count+=1
# print("incorrect count = ", count)
# print("incorrect count percent = ", 100*count/len(y_pred))

# %%
y_pred = np.clip(y_pred, 0, 1)

# %%
y_test=y_test.ravel()
y_pred=y_pred.ravel()

# %%
#Error Analysis on TEST data
#mse
mse= np.mean((y_test- y_pred)**2)
print('MSE_Test: ', mse)

#rmse_test
rmse_TEST = np.sqrt(np.mean((y_test - y_pred)**2))
print(f'RMSE_TEST: {rmse_TEST}')

#mae_TEST
mae_TEST = np.mean(abs(y_test - y_pred))
print(f'mae_TEST: {mae_TEST}')

#R2_test_sklearn
r2_sklearn = r2_score(y_test, y_pred)
print("R² score: ", r2_sklearn)
# Out:
# MSE_Test:  0.00018465793
# RMSE_TEST: 0.013588889501988888
# mae_TEST: 0.0009534553391858935
# R² score:  0.9974963068962097

# %%
#xgb feature importance
importance = model.feature_importances_

#Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

#Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

for name, score in feature_scores:
    print(f'{name}:{score:.6f}')
# Out:
# RH:0.983203
# ta:0.008210
# clw+cli:0.004682
# qr+qg+qs:0.001300
# hus:0.000668
# wa:0.000493
# pfull:0.000386
# clat:0.000294
# cllvi+clivi:0.000273
# clon:0.000180
# ua:0.000162
# va:0.000150

# %%
#xgb feature importance
importance = model.feature_importances_

#Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

#Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

for name, score in feature_scores:
    pct = score*100
    print(f'{name}:{pct:.4f} %')
# Out:
# RH:98.3203 %
# ta:0.8210 %
# clw+cli:0.4682 %
# qr+qg+qs:0.1300 %
# hus:0.0668 %
# wa:0.0493 %
# pfull:0.0386 %
# clat:0.0294 %
# cllvi+clivi:0.0273 %
# clon:0.0180 %
# ua:0.0162 %
# va:0.0150 %

# %%
import matplotlib.pyplot as plt

# ---- Your existing logic ----
importance = model.feature_importances_

# Combine feature names and scores
feature_scores = list(zip(feature_names, importance))

# Sort by score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Convert to percentages
names = []
importances = []

for name, score in feature_scores:
    pct = score * 100
    names.append(name)
    importances.append(pct)
    print(f"{name}: {pct:.4f} %")

# ---- Bar plot ----
plt.figure(figsize=(8, 6))
bars = plt.barh(names, importances, color="red")

plt.xlabel("Feature Importance (%)")
plt.ylabel("Features")
plt.title(r"$\mathbf{Cloud\ water\ fraction}$ determination using $\mathbf{XGBoost}$")

# Highest importance at the top
plt.gca().invert_yaxis()

# Add percentage labels
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 0.5,
        y,
        f"{width:.2f}%",
        va="center"
    )

# Set x-axis range
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# RH: 98.3203 %
# ta: 0.8210 %
# clw+cli: 0.4682 %
# qr+qg+qs: 0.1300 %
# hus: 0.0668 %
# wa: 0.0493 %
# pfull: 0.0386 %
# clat: 0.0294 %
# cllvi+clivi: 0.0273 %
# clon: 0.0180 %
# ua: 0.0162 %
# va: 0.0150 %

# %%
# plt.figure(figsize=(8,6))
# sns.scatterplot(x=y_test.flatten(), y=y_pred.flatten(), alpha=0.7)
# plt.xlabel("Actual Values")
# plt.ylabel("Predicted Values")
# plt.title("Actual vs Predicted Values (XGB)")
# # Add a perfect prediction line
# plt.plot([y_test.min(), y_test.max()],
#          [y_test.min(), y_test.max()],
#          color='red', lw=2)
# plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hexbin(
    y_test.flatten(), 
    y_pred.flatten(), 
    gridsize=40,  # smaller → finer grid
    cmap='viridis', 
    bins='log'  # logarithmic scaling helps emphasize dense areas
)
plt.colorbar(label='log10(N)')
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color='red', lw=2
)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (XGB)")
plt.show()

# %% [markdown]
# BART

# %%
#BART

# bart_condensates = BART(random_state=0, burnin=100, ndraw=15)
# bart_condensates.fit(X_train, y_train)

# %%
# yhat_test = bart_condensates.predict(X_test.astype(np.float32))

# yhat_test = np.clip(yhat_test, 0, 1)
# np.mean((y_test- yhat_test)**2)

# %%
# var_inclusion = pd.Series(bart_condensates.variable_inclusion_.mean(0),
#  index=D.columns)
# var_inclusion

# %%
overall_end_time = time.time()

totalElapsedTime=overall_end_time - overall_start_time
print(f"The Total Elapsed Time is: {totalElapsedTime/60:.4f} minutes")
# Out:
# The Total Elapsed Time is: 12.6322 minutes
